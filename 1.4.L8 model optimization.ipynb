# %% [markdown]
# # Landsat

# %% [markdown]
# ## Create GroupKFold splits and save them

# %%
import numpy as np
import json
import os
import pandas as pd

def build_group_kfold_split(groups, n_splits=5, seed=42):
    np.random.seed(seed)

    unique_groups = np.unique(groups)
    np.random.shuffle(unique_groups)

    fold_size = len(unique_groups) // n_splits
    folds = []

    for i in range(n_splits):
        test_groups = unique_groups[i * fold_size:(i + 1) * fold_size]
        train_groups = np.setdiff1d(unique_groups, test_groups)

        train_idx = np.where(np.isin(groups, train_groups))[0].tolist()
        test_idx = np.where(np.isin(groups, test_groups))[0].tolist()

        folds.append({
            "train_idx": train_idx,
            "test_idx": test_idx
        })

    return folds

csv_path = r"data/input/Landsat-8.csv"
df = pd.read_csv(csv_path, encoding="gbk")

# =========================
# Apply identical filtering as Dataset class
# (CRITICAL for consistency between training and split generation)
# =========================

# NDWI
ndwi = (df['SR_B3'] - df['SR_B5']) / (df['SR_B3'] + df['SR_B5'] + 1e-8)
df = df[ndwi > 0.1]

# Remove invalid samples (all features must be non-negative)
x = df.iloc[:, :-2].values
mask = (x >= 0).all(axis=1)
df = df[mask]

# Reset index to ensure continuity
df = df.reset_index(drop=True)

print("Filtered size:", len(df))

# =========================
# Construct group labels
# =========================

groups = np.arange(len(df)) 

folds = build_group_kfold_split(groups, n_splits=5, seed=42)

# save
save_path = r"data/input/Landsat-8/Landsat-8_splits.json"
os.makedirs(os.path.dirname(save_path), exist_ok=True)

with open(save_path, "w") as f:
    json.dump(folds, f, indent=2)

print("Saved split to:", save_path)
# Out:
# Filtered size: 640
# Saved split to: data/input/Landsat-8/Landsat-8_splits.json

# %% [markdown]
# ## Shared loading and evaluation utilities

# %%
import json
import numpy as np

def load_split(path, fold_id=0):
    with open(path, "r") as f:
        folds = json.load(f)

    split = folds[fold_id]

    train_idx = np.array(split["train_idx"])
    test_idx = np.array(split["test_idx"])

    return train_idx, test_idx

# %% [markdown]
# ## CSF-FPE Transformer（Continuous Spectral Fusion with Positional Encoding）

# %%
import os
import torch
import torch.nn as nn
import pandas as pd
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import json
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import copy
import torch.nn.functional as F

DATA_DIR = r"data\input"
SPLIT_PATH = os.path.join(DATA_DIR, "Landsat-8/Landsat-8_splits.json")

# =========================
# ⭐ Dataset selection
# =========================
selected_datasets = ["landsat"]

DATASET_CONFIG = {
    "uav": (0, "UAV.csv"),
    "sentinel": (1, "Sentinel-2.csv"),
    "landsat": (2, "Landsat-8.csv"),
}

# =========================
# 0. Wavelength normalization
# =========================
GLOBAL_LAMBDA_MIN = 350.0
GLOBAL_LAMBDA_MAX = 1002

def normalize_wavelength(x):
    return (x - GLOBAL_LAMBDA_MIN) / (GLOBAL_LAMBDA_MAX - GLOBAL_LAMBDA_MIN)

def normalize_delta(x):
    return (x - GLOBAL_LAMBDA_MIN) / (GLOBAL_LAMBDA_MAX - GLOBAL_LAMBDA_MIN)

# =========================
# ⭐ split loader
# =========================
def load_split(path, fold_id=0):
    with open(path, "r") as f:
        folds = json.load(f)

    split = folds[fold_id]
    return (
        np.array(split["train_idx"]),
        np.array(split["test_idx"])
    )

# =========================
# Dataset
# =========================
class SpectralDataset(Dataset):
    def __init__(self, file_path, dtype, x_mean, x_std):
        df = pd.read_csv(file_path, encoding='gbk')
        self.dtype = dtype

        temp = df.iloc[:, -2].values.astype(np.float32)
        self.x = df.iloc[:, :-2].values.astype(np.float32)
        self.y = df.iloc[:, -1].values.astype(np.float32)

        # NDWI filter
        if dtype == 1:
            ndwi = (df['B3'] - df['B8']) / (df['B3'] + df['B8'] + 1e-8)
            mask = ndwi > 0.1
            self.x, self.y, temp = self.x[mask], self.y[mask], temp[mask]

        elif dtype == 2:
            ndwi = (df['SR_B3'] - df['SR_B5']) / (df['SR_B3'] + df['SR_B5'] + 1e-8)
            mask = ndwi > 0.1
            self.x, self.y, temp = self.x[mask], self.y[mask], temp[mask]

        # clean
        mask = np.all(self.x >= 0, axis=1)
        self.x, self.y, temp = self.x[mask], self.y[mask], temp[mask]

        # global norm
        self.x = (self.x - x_mean) / (x_std + 1e-6)

        # wavelength
        if dtype == 0:
            self.lambda_ = np.arange(350, 1003, 4).astype(np.float32)
            self.delta = np.full_like(self.lambda_, 4.0)
            self.group_id = np.arange(len(self.x)) // 10

        elif dtype == 1:
            bands = [(443,20),(490,65),(560,35),(665,30),(705,15),(740,15),
                     (783,20),(842,115),(865,20),(945,20)]
            self.lambda_ = np.array([b[0] for b in bands], dtype=np.float32)
            self.delta = np.array([b[1] for b in bands], dtype=np.float32)

        else:
            bands = [(443,20),(482,65),(561,75),(655,50),(865,40)]
            self.lambda_ = np.array([b[0] for b in bands], dtype=np.float32)
            self.delta = np.array([b[1] for b in bands], dtype=np.float32)

        self.lambda_ = normalize_wavelength(self.lambda_)
        self.delta = normalize_delta(self.delta)

        self.temp = (temp - temp.mean()) / (temp.std() + 1e-6)

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return {
            "x": torch.tensor(self.x[idx]),
            "lambda": torch.tensor(self.lambda_),
            "delta": torch.tensor(self.delta),
            "y": torch.tensor(self.y[idx]),
            "type": torch.tensor(self.dtype),
            "temp": torch.tensor(self.temp[idx])
        }

# =========================
# Model
# =========================
class SpectralFusionModel(nn.Module):
    def __init__(self, d_model=64, grid_size=16):
        super().__init__()

        self.d_model = d_model

        # =========================
        # 1. Fixed spectral grid
        # =========================
        self.register_buffer(
            "grid",
            torch.linspace(0, 1, grid_size)
        )

        # =========================
        # 2. Fourier Encoding
        # =========================
        self.fourier_B = nn.Parameter(
            torch.logspace(0, 2, d_model // 2)
        )
        self.fourier_scale = nn.Parameter(torch.ones(1))

        # fusion
        self.fusion = nn.Linear(d_model * 2, d_model)

        # =========================
        # 3. Input embedding
        # =========================
        self.input_embed = nn.Sequential(
            nn.Linear(3, d_model),
            nn.ReLU(),
            nn.Linear(d_model, d_model)
        )

        self.temp_embed = nn.Sequential(
            nn.Linear(1, d_model),
            nn.ReLU(),
            nn.Linear(d_model, d_model)
        )

        # =========================
        # 4. FiLM conditioning
        # =========================
        self.film = nn.Sequential(
            nn.Linear(4, d_model // 2),
            nn.SiLU(),
            nn.Linear(d_model // 2, d_model),
            nn.SiLU(),
            nn.Linear(d_model, d_model * 2)
        )

        # =========================
        # 5. Transformer Encoder
        # =========================
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=4,
            batch_first=True
        )
        self.encoder = nn.TransformerEncoder(
            encoder_layer,
            num_layers=2
        )

        # =========================
        # 7. Regression head
        # =========================
        self.head = nn.Sequential(
            nn.Linear(d_model, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

    # =========================
    # Fourier Encoding
    # =========================
    def fourier_encoding(self, x):
        x = x.unsqueeze(-1)  # (B, N, 1)

        proj = x * self.fourier_B * self.fourier_scale

        return torch.cat([
            torch.sin(proj),
            torch.cos(proj)
        ], dim=-1)

    # =========================
    # spectral projection
    # =========================
    def spectral_project(self, z, wl, delta):

        grid = self.grid.to(z.device).unsqueeze(0).unsqueeze(0)

        wl = wl.unsqueeze(-1)
        delta = delta.unsqueeze(-1)

        sigma = delta + 1e-6

        weight = torch.exp(-((wl - grid) ** 2) / (sigma ** 2))
        weight = weight / (weight.sum(dim=1, keepdim=True) + 1e-8)

        return (z.unsqueeze(2) * weight.unsqueeze(-1)).sum(dim=1)

    # =========================
    # forward
    # =========================
    def forward(self, x, wl, delta, dtype, temp):

        # -------------------------
        # 1. input embedding
        # -------------------------
        x = x.unsqueeze(-1)
        wl = wl.unsqueeze(-1)
        delta = delta.unsqueeze(-1)

        inp = torch.cat([x, wl, delta], dim=-1)
        z = self.input_embed(inp)

        # -------------------------
        # 2. FiLM conditioning
        # -------------------------
        cond = torch.stack([
            dtype.float(),
            temp,
            wl.mean(dim=1).squeeze(-1),
            delta.mean(dim=1).squeeze(-1)
        ], dim=1)

        gamma, beta = self.film(cond).chunk(2, dim=1)
        z = gamma.unsqueeze(1) * z + beta.unsqueeze(1)

        # -------------------------
        # 3. spectral projection
        # -------------------------
        z = self.spectral_project(
            z,
            wl.squeeze(-1),
            delta.squeeze(-1)
        )

        # -------------------------
        # 4. Fourier positional encoding
        # -------------------------
        grid = self.grid.unsqueeze(0).expand(z.size(0), -1)

        pos = self.fourier_encoding(grid)

        z = torch.cat([z, pos], dim=-1)
        z = self.fusion(z)

        # -------------------------
        # 5. Transformer + CLS token pooling
        # -------------------------
        B = z.size(0)
        t = self.temp_embed(temp.unsqueeze(-1)).unsqueeze(1)
        z = torch.cat([t, z], dim=1)        # (B,N+1,d)

        z = self.encoder(z)

        z = z[:, 0]  # ⭐ CLS token output

        # -------------------------
        # 6. regression head
        # -------------------------
        return self.head(z).squeeze()

# =========================
# Loss
# =========================
def r2_aware_loss(pred, target):
    mse = torch.mean((pred - target) ** 2)

    pred_c = pred - pred.mean()
    tgt_c = target - target.mean()

    corr = torch.sum(pred_c * tgt_c) / (
        torch.sqrt(torch.sum(pred_c ** 2)) *
        torch.sqrt(torch.sum(tgt_c ** 2)) + 1e-8
    )

    return mse + 0.5 * (1 - corr)

# =========================
# ⭐ evaluation
# =========================
def evaluate(model, loader, device):
    model.eval()
    y_true, y_pred = [], []

    with torch.no_grad():
        for batch in loader:
            pred = model(
                batch["x"].to(device),
                batch["lambda"].to(device),
                batch["delta"].to(device),
                batch["type"].to(device),
                batch["temp"].to(device)
            )

            y_true.extend(batch["y"].cpu().numpy())
            y_pred.extend(pred.cpu().numpy())

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)

    return mse, rmse, mae, r2


# =========================
# ⭐ train with early stopping
# =========================
def train():

    device = "cuda" if torch.cuda.is_available() else "cpu"

    paths = [
        (DATASET_CONFIG[name][0],
         os.path.join(DATA_DIR, DATASET_CONFIG[name][1]))
        for name in selected_datasets
    ]

    # =========================
    # global normalization
    # =========================
    all_x = []
    for _, path in paths:
        df = pd.read_csv(path, encoding='gbk')
        all_x.append(df.iloc[:, :-2].values.astype(np.float32))

    all_x = np.vstack(all_x)
    x_mean = all_x.mean(axis=0)
    x_std = all_x.std(axis=0) + 1e-6

    dataset = SpectralDataset(paths[0][1], paths[0][0], x_mean, x_std)

    # =========================
    # ⭐ 5-fold split
    # =========================
    folds = json.load(open(SPLIT_PATH))

    results = []

    for fold_id in range(5):

        print(f"\n================ FOLD {fold_id} ================")

        train_idx = np.array(folds[fold_id]["train_idx"])
        test_idx  = np.array(folds[fold_id]["test_idx"])

        train_ds = Subset(dataset, train_idx)
        test_ds  = Subset(dataset, test_idx)

        train_loader = DataLoader(train_ds, batch_size=16, shuffle=True)
        test_loader = DataLoader(test_ds, batch_size=16)

        model = SpectralFusionModel().to(device)
        opt = torch.optim.Adam(model.parameters(), lr=3e-4)

        # =========================
        # ⭐ early stopping
        # =========================
        best_loss = float("inf")
        patience = 50
        wait = 0
        best_model = None

        for epoch in range(500):

            model.train()
            total_loss = 0

            for batch in train_loader:
                pred = model(
                    batch["x"].to(device),
                    batch["lambda"].to(device),
                    batch["delta"].to(device),
                    batch["type"].to(device),
                    batch["temp"].to(device)
                )

                loss = r2_aware_loss(pred, batch["y"].to(device))

                opt.zero_grad()
                loss.backward()
                opt.step()

                total_loss += loss.item()

            # =========================
            # ⭐ validation = test here
            # =========================
            mse, rmse, mae, r2 = evaluate(model, test_loader, device)

            print(
                f"Epoch {epoch:03d} | "
                f"TrainLoss {total_loss:.4f} | "
                f"Test RMSE {rmse:.4f} R2 {r2:.4f}"
            )

            # =========================
            # ⭐ save best model
            # =========================
            if rmse < best_loss:
                best_loss = rmse
                best_model = copy.deepcopy(model.state_dict())
                wait = 0

                torch.save(
                    best_model,
                    os.path.join(DATA_DIR, f"Landsat-8/CSF-PE Transformer/best_model_fold{fold_id}.pth")
                )
            else:
                wait += 1
                if wait >= patience:
                    print("Early stopping triggered")
                    break

        # =========================
        # ⭐ final evaluation
        # =========================
        model.load_state_dict(best_model)

        mse, rmse, mae, r2 = evaluate(model, test_loader, device)

        print(f"\n[FOLD {fold_id} FINAL]")
        print(f"MSE: {mse:.4f}")
        print(f"RMSE: {rmse:.4f}")
        print(f"MAE: {mae:.4f}")
        print(f"R2: {r2:.4f}")

        results.append([mse, rmse, mae, r2])

    # =========================
    # ⭐ overall result
    # =========================
    results = np.array(results)

    print("\n================ FINAL 5-FOLD RESULT ================")
    print(f"MSE  : {results[:,0].mean():.4f} ± {results[:,0].std():.4f}")
    print(f"RMSE : {results[:,1].mean():.4f} ± {results[:,1].std():.4f}")
    print(f"MAE  : {results[:,2].mean():.4f} ± {results[:,2].std():.4f}")
    print(f"R2   : {results[:,3].mean():.4f} ± {results[:,3].std():.4f}")

if __name__ == "__main__":
    train()
# Out:
# ================ FOLD 0 ================
# Epoch 000 | TrainLoss 1101.1677 | Test RMSE 4.8990 R2 -6.7836
# Epoch 001 | TrainLoss 584.2857 | Test RMSE 3.2849 R2 -2.4995
# Epoch 002 | TrainLoss 246.0978 | Test RMSE 2.0081 R2 -0.3077
# Epoch 003 | TrainLoss 123.7496 | Test RMSE 1.7414 R2 0.0166
# Epoch 004 | TrainLoss 97.6120 | Test RMSE 1.5747 R2 0.1958
# Epoch 005 | TrainLoss 91.1625 | Test RMSE 1.6101 R2 0.1592
# Epoch 006 | TrainLoss 85.5492 | Test RMSE 1.5648 R2 0.2058
# Epoch 007 | TrainLoss 88.8256 | Test RMSE 1.5506 R2 0.2203
# Epoch 008 | TrainLoss 87.4532 | Test RMSE 1.5274 R2 0.2434
# Epoch 009 | TrainLoss 84.7509 | Test RMSE 1.5240 R2 0.2468
# Epoch 010 | TrainLoss 83.7933 | Test RMSE 1.5367 R2 0.2341
# Epoch 011 | TrainLoss 86.1404 | Test RMSE 1.5248 R2 0.2460
# Epoch 012 | TrainLoss 86.1373 | Test RMSE 1.5458 R2 0.2250
# Epoch 013 | TrainLoss 85.3931 | Test RMSE 1.5291 R2 0.2418
# Epoch 014 | TrainLoss 85.7774 | Test RMSE 1.5266 R2 0.2441
# Epoch 015 | TrainLoss 85.2166 | Test RMSE 1.5439 R2 0.2270
# Epoch 016 | TrainLoss 83.8189 | Test RMSE 1.5333 R2 0.2376
# Epoch 017 | TrainLoss 84.7132 | Test RMSE 1.5248 R2 0.2460
# Epoch 018 | TrainLoss 84.0446 | Test RMSE 1.5438 R2 0.2271
# Epoch 019 | TrainLoss 83.7171 | Test RMSE 1.5372 R2 0.2337
# Epoch 020 | TrainLoss 85.6023 | Test RMSE 1.5315 R2 0.2393
# Epoch 021 | TrainLoss 83.3077 | Test RMSE 1.5299 R2 0.2409
# Epoch 022 | TrainLoss 83.1401 | Test RMSE 1.5322 R2 0.2386
# Epoch 023 | TrainLoss 83.1994 | Test RMSE 1.5269 R2 0.2439
# Epoch 024 | TrainLoss 84.1653 | Test RMSE 1.5463 R2 0.2246
# Epoch 025 | TrainLoss 82.9374 | Test RMSE 1.5972 R2 0.1727
# Epoch 026 | TrainLoss 83.2134 | Test RMSE 1.5388 R2 0.2320
# Epoch 027 | TrainLoss 82.2839 | Test RMSE 1.5299 R2 0.2410
# Epoch 028 | TrainLoss 82.3419 | Test RMSE 1.5250 R2 0.2458
# Epoch 029 | TrainLoss 83.9431 | Test RMSE 1.5320 R2 0.2389
# Epoch 030 | TrainLoss 82.6367 | Test RMSE 1.5527 R2 0.2182
# Epoch 031 | TrainLoss 82.8449 | Test RMSE 1.5361 R2 0.2347
# Epoch 032 | TrainLoss 82.6551 | Test RMSE 1.5483 R2 0.2226
# Epoch 033 | TrainLoss 83.5353 | Test RMSE 1.5645 R2 0.2062
# Epoch 034 | TrainLoss 82.5801 | Test RMSE 1.5222 R2 0.2486
# Epoch 035 | TrainLoss 86.5812 | Test RMSE 1.5213 R2 0.2494
# Epoch 036 | TrainLoss 81.9458 | Test RMSE 1.5639 R2 0.2068
# Epoch 037 | TrainLoss 84.1747 | Test RMSE 1.6797 R2 0.0850
# Epoch 038 | TrainLoss 84.6251 | Test RMSE 1.5505 R2 0.2203
# Epoch 039 | TrainLoss 82.1916 | Test RMSE 1.5178 R2 0.2529
# Epoch 040 | TrainLoss 81.7538 | Test RMSE 1.5291 R2 0.2417
# Epoch 041 | TrainLoss 80.1986 | Test RMSE 1.5107 R2 0.2599
# Epoch 042 | TrainLoss 83.4083 | Test RMSE 1.5625 R2 0.2082
# Epoch 043 | TrainLoss 81.7433 | Test RMSE 1.5383 R2 0.2326
# Epoch 044 | TrainLoss 83.4508 | Test RMSE 1.5588 R2 0.2120
# Epoch 045 | TrainLoss 81.6100 | Test RMSE 1.5310 R2 0.2399
# Epoch 046 | TrainLoss 80.2675 | Test RMSE 1.5193 R2 0.2514
# Epoch 047 | TrainLoss 82.0447 | Test RMSE 1.5392 R2 0.2317
# Epoch 048 | TrainLoss 84.8158 | Test RMSE 1.5800 R2 0.1904
# Epoch 049 | TrainLoss 82.9465 | Test RMSE 1.5613 R2 0.2095
# Epoch 050 | TrainLoss 82.7646 | Test RMSE 1.5309 R2 0.2400
# Epoch 051 | TrainLoss 80.4115 | Test RMSE 1.5178 R2 0.2529
# Epoch 052 | TrainLoss 82.3395 | Test RMSE 1.5193 R2 0.2514
# Epoch 053 | TrainLoss 82.4807 | Test RMSE 1.5297 R2 0.2411
# Epoch 054 | TrainLoss 82.6848 | Test RMSE 1.5260 R2 0.2448
# Epoch 055 | TrainLoss 82.6502 | Test RMSE 1.5246 R2 0.2461
# Epoch 056 | TrainLoss 80.9953 | Test RMSE 1.5413 R2 0.2295
# Epoch 057 | TrainLoss 81.8066 | Test RMSE 1.5269 R2 0.2439
# Epoch 058 | TrainLoss 80.3419 | Test RMSE 1.5531 R2 0.2177
# Epoch 059 | TrainLoss 81.0113 | Test RMSE 1.5349 R2 0.2359
# Epoch 060 | TrainLoss 81.0667 | Test RMSE 1.5188 R2 0.2519
# Epoch 061 | TrainLoss 80.5164 | Test RMSE 1.5154 R2 0.2552
# Epoch 062 | TrainLoss 79.7182 | Test RMSE 1.5659 R2 0.2048
# Epoch 063 | TrainLoss 80.7834 | Test RMSE 1.5076 R2 0.2629
# Epoch 064 | TrainLoss 80.1517 | Test RMSE 1.5194 R2 0.2513
# Epoch 065 | TrainLoss 81.8586 | Test RMSE 1.5416 R2 0.2292
# Epoch 066 | TrainLoss 81.0892 | Test RMSE 1.5405 R2 0.2304
# Epoch 067 | TrainLoss 81.3720 | Test RMSE 1.5126 R2 0.2580
# Epoch 068 | TrainLoss 80.8594 | Test RMSE 1.5103 R2 0.2603
# Epoch 069 | TrainLoss 79.8574 | Test RMSE 1.5235 R2 0.2473
# Epoch 070 | TrainLoss 81.5674 | Test RMSE 1.5135 R2 0.2571
# Epoch 071 | TrainLoss 81.1695 | Test RMSE 1.5474 R2 0.2235
# Epoch 072 | TrainLoss 81.5703 | Test RMSE 1.5350 R2 0.2359
# Epoch 073 | TrainLoss 80.4755 | Test RMSE 1.5317 R2 0.2391
# Epoch 074 | TrainLoss 80.5420 | Test RMSE 1.5465 R2 0.2243
# Epoch 075 | TrainLoss 80.5126 | Test RMSE 1.5663 R2 0.2043
# Epoch 076 | TrainLoss 80.5542 | Test RMSE 1.4958 R2 0.2744
# Epoch 077 | TrainLoss 81.2605 | Test RMSE 1.5139 R2 0.2567
# Epoch 078 | TrainLoss 78.7594 | Test RMSE 1.5330 R2 0.2378
# Epoch 079 | TrainLoss 80.0904 | Test RMSE 1.5130 R2 0.2576
# Epoch 080 | TrainLoss 81.4189 | Test RMSE 1.5362 R2 0.2347
# Epoch 081 | TrainLoss 79.6637 | Test RMSE 1.5204 R2 0.2504
# Epoch 082 | TrainLoss 82.0130 | Test RMSE 1.5169 R2 0.2538
# Epoch 083 | TrainLoss 79.3787 | Test RMSE 1.5392 R2 0.2316
# Epoch 084 | TrainLoss 80.2328 | Test RMSE 1.5221 R2 0.2487
# Epoch 085 | TrainLoss 82.5218 | Test RMSE 1.5361 R2 0.2348
# Epoch 086 | TrainLoss 81.1683 | Test RMSE 1.5495 R2 0.2213
# Epoch 087 | TrainLoss 79.8045 | Test RMSE 1.5182 R2 0.2525
# Epoch 088 | TrainLoss 81.9147 | Test RMSE 1.6087 R2 0.1607
# Epoch 089 | TrainLoss 79.0211 | Test RMSE 1.5790 R2 0.1914
# Epoch 090 | TrainLoss 79.2975 | Test RMSE 1.5309 R2 0.2399
# Epoch 091 | TrainLoss 79.1294 | Test RMSE 1.5651 R2 0.2056
# Epoch 092 | TrainLoss 78.5118 | Test RMSE 1.5556 R2 0.2152
# Epoch 093 | TrainLoss 78.2811 | Test RMSE 1.5477 R2 0.2232
# Epoch 094 | TrainLoss 78.2421 | Test RMSE 1.5161 R2 0.2546
# Epoch 095 | TrainLoss 80.4955 | Test RMSE 1.6192 R2 0.1497
# Epoch 096 | TrainLoss 77.7344 | Test RMSE 1.5128 R2 0.2578
# Epoch 097 | TrainLoss 77.1269 | Test RMSE 1.5341 R2 0.2368
# Epoch 098 | TrainLoss 79.6680 | Test RMSE 1.5281 R2 0.2428
# Epoch 099 | TrainLoss 78.6027 | Test RMSE 1.5314 R2 0.2394
# Epoch 100 | TrainLoss 77.4642 | Test RMSE 1.5355 R2 0.2353
# Epoch 101 | TrainLoss 78.1121 | Test RMSE 1.5487 R2 0.2222
# Epoch 102 | TrainLoss 76.9771 | Test RMSE 1.5863 R2 0.1840
# Epoch 103 | TrainLoss 77.4431 | Test RMSE 1.5557 R2 0.2151
# Epoch 104 | TrainLoss 77.0154 | Test RMSE 1.5740 R2 0.1966
# Epoch 105 | TrainLoss 76.2372 | Test RMSE 1.5260 R2 0.2448
# Epoch 106 | TrainLoss 77.1691 | Test RMSE 1.5285 R2 0.2423
# Epoch 107 | TrainLoss 76.1020 | Test RMSE 1.5297 R2 0.2412
# Epoch 108 | TrainLoss 77.0981 | Test RMSE 1.5271 R2 0.2437
# Epoch 109 | TrainLoss 76.9984 | Test RMSE 1.5419 R2 0.2290
# Epoch 110 | TrainLoss 74.8934 | Test RMSE 1.5368 R2 0.2340
# Epoch 111 | TrainLoss 74.5380 | Test RMSE 1.5455 R2 0.2254
# Epoch 112 | TrainLoss 76.4199 | Test RMSE 1.6182 R2 0.1508
# Epoch 113 | TrainLoss 75.3369 | Test RMSE 1.5649 R2 0.2058
# Epoch 114 | TrainLoss 75.9014 | Test RMSE 1.5809 R2 0.1895
# Epoch 115 | TrainLoss 73.8889 | Test RMSE 1.5644 R2 0.2063
# Epoch 116 | TrainLoss 73.9376 | Test RMSE 1.5846 R2 0.1857
# Epoch 117 | TrainLoss 75.1080 | Test RMSE 1.5433 R2 0.2276
# Epoch 118 | TrainLoss 75.1945 | Test RMSE 1.5702 R2 0.2004
# Epoch 119 | TrainLoss 73.7068 | Test RMSE 1.6157 R2 0.1534
# Epoch 120 | TrainLoss 74.0465 | Test RMSE 1.5708 R2 0.1998
# Epoch 121 | TrainLoss 76.6913 | Test RMSE 1.5878 R2 0.1824
# Epoch 122 | TrainLoss 77.4079 | Test RMSE 1.5568 R2 0.2140
# Epoch 123 | TrainLoss 77.0136 | Test RMSE 1.5504 R2 0.2205
# Epoch 124 | TrainLoss 74.6798 | Test RMSE 1.5819 R2 0.1885
# Epoch 125 | TrainLoss 73.4097 | Test RMSE 1.6728 R2 0.0925
# Epoch 126 | TrainLoss 75.0735 | Test RMSE 1.5600 R2 0.2108
# Early stopping triggered
#
# [FOLD 0 FINAL]
# MSE: 2.2374
# RMSE: 1.4958
# MAE: 1.1914
# R2: 0.2744
#
# ================ FOLD 1 ================
# Epoch 000 | TrainLoss 1069.0510 | Test RMSE 4.6628 R2 -4.7502
# Epoch 001 | TrainLoss 504.3063 | Test RMSE 2.9698 R2 -1.3325
# Epoch 002 | TrainLoss 194.4202 | Test RMSE 2.0079 R2 -0.0662
# Epoch 003 | TrainLoss 113.6853 | Test RMSE 1.9417 R2 0.0029
# Epoch 004 | TrainLoss 101.0831 | Test RMSE 1.8220 R2 0.1220
# Epoch 005 | TrainLoss 84.4226 | Test RMSE 1.7720 R2 0.1695
# Epoch 006 | TrainLoss 80.0148 | Test RMSE 1.8070 R2 0.1364
# Epoch 007 | TrainLoss 80.8800 | Test RMSE 1.7531 R2 0.1872
# Epoch 008 | TrainLoss 79.0860 | Test RMSE 1.8475 R2 0.0973
# Epoch 009 | TrainLoss 80.3199 | Test RMSE 1.7643 R2 0.1768
# Epoch 010 | TrainLoss 79.2526 | Test RMSE 1.7587 R2 0.1819
# Epoch 011 | TrainLoss 79.4311 | Test RMSE 1.9023 R2 0.0429
# Epoch 012 | TrainLoss 80.0720 | Test RMSE 1.7671 R2 0.1741
# Epoch 013 | TrainLoss 78.6162 | Test RMSE 1.7774 R2 0.1645
# Epoch 014 | TrainLoss 78.0645 | Test RMSE 1.7540 R2 0.1863
# Epoch 015 | TrainLoss 78.3995 | Test RMSE 1.7368 R2 0.2022
# Epoch 016 | TrainLoss 78.2272 | Test RMSE 1.8470 R2 0.0978
# Epoch 017 | TrainLoss 82.4718 | Test RMSE 1.8204 R2 0.1235
# Epoch 018 | TrainLoss 79.7393 | Test RMSE 1.7369 R2 0.2021
# Epoch 019 | TrainLoss 78.4092 | Test RMSE 1.7778 R2 0.1641
# Epoch 020 | TrainLoss 78.4160 | Test RMSE 1.7502 R2 0.1899
# Epoch 021 | TrainLoss 76.5882 | Test RMSE 1.7450 R2 0.1946
# Epoch 022 | TrainLoss 77.4908 | Test RMSE 1.7393 R2 0.1999
# Epoch 023 | TrainLoss 76.0747 | Test RMSE 1.7366 R2 0.2024
# Epoch 024 | TrainLoss 76.3377 | Test RMSE 1.8904 R2 0.0549
# Epoch 025 | TrainLoss 78.8898 | Test RMSE 1.8712 R2 0.0740
# Epoch 026 | TrainLoss 78.3246 | Test RMSE 1.7811 R2 0.1610
# Epoch 027 | TrainLoss 76.7344 | Test RMSE 1.7602 R2 0.1806
# Epoch 028 | TrainLoss 77.2301 | Test RMSE 1.7583 R2 0.1824
# Epoch 029 | TrainLoss 76.4021 | Test RMSE 1.7332 R2 0.2055
# Epoch 030 | TrainLoss 76.5821 | Test RMSE 1.7732 R2 0.1685
# Epoch 031 | TrainLoss 77.7236 | Test RMSE 1.7428 R2 0.1967
# Epoch 032 | TrainLoss 77.7621 | Test RMSE 1.7316 R2 0.2070
# Epoch 033 | TrainLoss 78.9599 | Test RMSE 1.7452 R2 0.1945
# Epoch 034 | TrainLoss 78.3643 | Test RMSE 1.7397 R2 0.1995
# Epoch 035 | TrainLoss 76.9553 | Test RMSE 1.8450 R2 0.0997
# Epoch 036 | TrainLoss 77.3502 | Test RMSE 1.8111 R2 0.1325
# Epoch 037 | TrainLoss 76.4382 | Test RMSE 1.7865 R2 0.1559
# Epoch 038 | TrainLoss 75.9544 | Test RMSE 1.7837 R2 0.1585
# Epoch 039 | TrainLoss 76.1303 | Test RMSE 1.7339 R2 0.2049
# Epoch 040 | TrainLoss 75.7182 | Test RMSE 1.7314 R2 0.2071
# Epoch 041 | TrainLoss 76.5337 | Test RMSE 1.7809 R2 0.1611
# Epoch 042 | TrainLoss 75.7693 | Test RMSE 1.7797 R2 0.1623
# Epoch 043 | TrainLoss 76.2144 | Test RMSE 1.7591 R2 0.1816
# Epoch 044 | TrainLoss 75.7814 | Test RMSE 1.7384 R2 0.2008
# Epoch 045 | TrainLoss 76.5330 | Test RMSE 1.7778 R2 0.1641
# Epoch 046 | TrainLoss 78.0346 | Test RMSE 1.7796 R2 0.1624
# Epoch 047 | TrainLoss 75.9674 | Test RMSE 1.8147 R2 0.1290
# Epoch 048 | TrainLoss 78.6893 | Test RMSE 1.8370 R2 0.1075
# Epoch 049 | TrainLoss 74.8793 | Test RMSE 1.7543 R2 0.1860
# Epoch 050 | TrainLoss 74.0555 | Test RMSE 1.7667 R2 0.1745
# Epoch 051 | TrainLoss 77.3142 | Test RMSE 1.8256 R2 0.1185
# Epoch 052 | TrainLoss 79.7978 | Test RMSE 1.7471 R2 0.1927
# Epoch 053 | TrainLoss 74.8595 | Test RMSE 1.7386 R2 0.2005
# Epoch 054 | TrainLoss 74.9317 | Test RMSE 1.8017 R2 0.1415
# Epoch 055 | TrainLoss 75.8978 | Test RMSE 1.7944 R2 0.1484
# Epoch 056 | TrainLoss 78.9389 | Test RMSE 1.8259 R2 0.1183
# Epoch 057 | TrainLoss 75.0118 | Test RMSE 1.7932 R2 0.1496
# Epoch 058 | TrainLoss 77.9384 | Test RMSE 1.7798 R2 0.1622
# Epoch 059 | TrainLoss 74.6664 | Test RMSE 1.7398 R2 0.1994
# Epoch 060 | TrainLoss 76.5963 | Test RMSE 1.7387 R2 0.2005
# Epoch 061 | TrainLoss 76.0849 | Test RMSE 1.7581 R2 0.1826
# Epoch 062 | TrainLoss 77.1878 | Test RMSE 1.7452 R2 0.1945
# Epoch 063 | TrainLoss 73.6899 | Test RMSE 1.7376 R2 0.2015
# Epoch 064 | TrainLoss 77.0215 | Test RMSE 1.7382 R2 0.2010
# Epoch 065 | TrainLoss 77.8928 | Test RMSE 1.7398 R2 0.1994
# Epoch 066 | TrainLoss 76.9553 | Test RMSE 1.7369 R2 0.2021
# Epoch 067 | TrainLoss 76.4296 | Test RMSE 1.7500 R2 0.1901
# Epoch 068 | TrainLoss 75.2703 | Test RMSE 1.7668 R2 0.1744
# Epoch 069 | TrainLoss 75.3843 | Test RMSE 1.8128 R2 0.1309
# Epoch 070 | TrainLoss 76.1150 | Test RMSE 1.7694 R2 0.1720
# Epoch 071 | TrainLoss 78.7475 | Test RMSE 1.7590 R2 0.1817
# Epoch 072 | TrainLoss 73.5505 | Test RMSE 1.7731 R2 0.1685
# Epoch 073 | TrainLoss 75.3175 | Test RMSE 1.7490 R2 0.1910
# Epoch 074 | TrainLoss 76.0464 | Test RMSE 1.7539 R2 0.1864
# Epoch 075 | TrainLoss 76.3315 | Test RMSE 1.7289 R2 0.2095
# Epoch 076 | TrainLoss 76.0467 | Test RMSE 1.7753 R2 0.1665
# Epoch 077 | TrainLoss 75.8947 | Test RMSE 1.7397 R2 0.1995
# Epoch 078 | TrainLoss 74.3428 | Test RMSE 1.7624 R2 0.1785
# Epoch 079 | TrainLoss 75.3727 | Test RMSE 1.7704 R2 0.1710
# Epoch 080 | TrainLoss 74.9248 | Test RMSE 1.7436 R2 0.1960
# Epoch 081 | TrainLoss 75.7802 | Test RMSE 1.7771 R2 0.1647
# Epoch 082 | TrainLoss 76.6614 | Test RMSE 1.8275 R2 0.1167
# Epoch 083 | TrainLoss 75.0090 | Test RMSE 1.8083 R2 0.1351
# Epoch 084 | TrainLoss 74.8379 | Test RMSE 1.8038 R2 0.1394
# Epoch 085 | TrainLoss 75.9251 | Test RMSE 1.7773 R2 0.1646
# Epoch 086 | TrainLoss 74.2802 | Test RMSE 1.7722 R2 0.1693
# Epoch 087 | TrainLoss 74.0603 | Test RMSE 1.7415 R2 0.1979
# Epoch 088 | TrainLoss 76.3084 | Test RMSE 1.7949 R2 0.1480
# Epoch 089 | TrainLoss 74.5736 | Test RMSE 1.7725 R2 0.1691
# Epoch 090 | TrainLoss 75.3583 | Test RMSE 1.7619 R2 0.1789
# Epoch 091 | TrainLoss 74.5594 | Test RMSE 1.7325 R2 0.2061
# Epoch 092 | TrainLoss 77.2791 | Test RMSE 1.7467 R2 0.1931
# Epoch 093 | TrainLoss 73.8581 | Test RMSE 1.7401 R2 0.1992
# Epoch 094 | TrainLoss 74.5079 | Test RMSE 1.7889 R2 0.1536
# Epoch 095 | TrainLoss 75.3608 | Test RMSE 1.7337 R2 0.2051
# Epoch 096 | TrainLoss 76.2513 | Test RMSE 1.7374 R2 0.2017
# Epoch 097 | TrainLoss 75.2475 | Test RMSE 1.8308 R2 0.1135
# Epoch 098 | TrainLoss 74.1069 | Test RMSE 1.7799 R2 0.1622
# Epoch 099 | TrainLoss 74.7714 | Test RMSE 1.7780 R2 0.1639
# Epoch 100 | TrainLoss 74.8472 | Test RMSE 1.7337 R2 0.2051
# Epoch 101 | TrainLoss 75.6554 | Test RMSE 1.7346 R2 0.2042
# Epoch 102 | TrainLoss 75.2301 | Test RMSE 1.8160 R2 0.1278
# Epoch 103 | TrainLoss 75.7930 | Test RMSE 1.7428 R2 0.1967
# Epoch 104 | TrainLoss 73.9996 | Test RMSE 1.7487 R2 0.1912
# Epoch 105 | TrainLoss 75.3498 | Test RMSE 1.7324 R2 0.2062
# Epoch 106 | TrainLoss 75.7386 | Test RMSE 1.8165 R2 0.1273
# Epoch 107 | TrainLoss 74.3412 | Test RMSE 1.8146 R2 0.1292
# Epoch 108 | TrainLoss 76.1362 | Test RMSE 1.7972 R2 0.1458
# Epoch 109 | TrainLoss 74.6634 | Test RMSE 1.7756 R2 0.1662
# Epoch 110 | TrainLoss 74.6317 | Test RMSE 1.7914 R2 0.1513
# Epoch 111 | TrainLoss 74.2219 | Test RMSE 1.7660 R2 0.1752
# Epoch 112 | TrainLoss 72.9035 | Test RMSE 1.7464 R2 0.1934
# Epoch 113 | TrainLoss 74.4695 | Test RMSE 1.7689 R2 0.1725
# Epoch 114 | TrainLoss 74.9117 | Test RMSE 1.7728 R2 0.1688
# Epoch 115 | TrainLoss 74.2079 | Test RMSE 1.7553 R2 0.1852
# Epoch 116 | TrainLoss 75.3115 | Test RMSE 1.7494 R2 0.1906
# Epoch 117 | TrainLoss 76.6442 | Test RMSE 1.7657 R2 0.1755
# Epoch 118 | TrainLoss 76.2534 | Test RMSE 1.7722 R2 0.1694
# Epoch 119 | TrainLoss 75.1511 | Test RMSE 1.7336 R2 0.2051
# Epoch 120 | TrainLoss 74.6937 | Test RMSE 1.7602 R2 0.1806
# Epoch 121 | TrainLoss 72.6315 | Test RMSE 1.7601 R2 0.1806
# Epoch 122 | TrainLoss 73.4937 | Test RMSE 1.7578 R2 0.1828
# Epoch 123 | TrainLoss 73.8283 | Test RMSE 1.7424 R2 0.1970
# Epoch 124 | TrainLoss 76.3378 | Test RMSE 1.7355 R2 0.2034
# Epoch 125 | TrainLoss 73.0082 | Test RMSE 1.7563 R2 0.1842
# Early stopping triggered
#
# [FOLD 1 FINAL]
# MSE: 2.9890
# RMSE: 1.7289
# MAE: 1.2240
# R2: 0.2095
#
# ================ FOLD 2 ================
# Epoch 000 | TrainLoss 1085.9961 | Test RMSE 4.8371 R2 -7.6004
# Epoch 001 | TrainLoss 589.0956 | Test RMSE 3.2433 R2 -2.8665
# Epoch 002 | TrainLoss 250.9250 | Test RMSE 1.9497 R2 -0.3973
# Epoch 003 | TrainLoss 129.9780 | Test RMSE 1.6186 R2 0.0370
# Epoch 004 | TrainLoss 105.5598 | Test RMSE 1.4759 R2 0.1994
# Epoch 005 | TrainLoss 94.1845 | Test RMSE 1.4424 R2 0.2352
# Epoch 006 | TrainLoss 91.3695 | Test RMSE 1.5077 R2 0.1645
# Epoch 007 | TrainLoss 89.9876 | Test RMSE 1.4268 R2 0.2518
# Epoch 008 | TrainLoss 93.1982 | Test RMSE 1.4241 R2 0.2545
# Epoch 009 | TrainLoss 90.3904 | Test RMSE 1.4475 R2 0.2299
# Epoch 010 | TrainLoss 89.2885 | Test RMSE 1.4576 R2 0.2191
# Epoch 011 | TrainLoss 87.5182 | Test RMSE 1.3868 R2 0.2931
# Epoch 012 | TrainLoss 88.7669 | Test RMSE 1.4710 R2 0.2047
# Epoch 013 | TrainLoss 88.0786 | Test RMSE 1.4722 R2 0.2033
# Epoch 014 | TrainLoss 87.6193 | Test RMSE 1.4972 R2 0.1761
# Epoch 015 | TrainLoss 87.6915 | Test RMSE 1.4211 R2 0.2577
# Epoch 016 | TrainLoss 86.8024 | Test RMSE 1.3906 R2 0.2892
# Epoch 017 | TrainLoss 85.3456 | Test RMSE 1.4368 R2 0.2412
# Epoch 018 | TrainLoss 85.4651 | Test RMSE 1.3910 R2 0.2888
# Epoch 019 | TrainLoss 88.6730 | Test RMSE 1.3983 R2 0.2813
# Epoch 020 | TrainLoss 86.3342 | Test RMSE 1.3969 R2 0.2827
# Epoch 021 | TrainLoss 85.9795 | Test RMSE 1.4784 R2 0.1966
# Epoch 022 | TrainLoss 89.7944 | Test RMSE 1.5159 R2 0.1553
# Epoch 023 | TrainLoss 88.2971 | Test RMSE 1.4290 R2 0.2494
# Epoch 024 | TrainLoss 86.2095 | Test RMSE 1.4472 R2 0.2301
# Epoch 025 | TrainLoss 88.1497 | Test RMSE 1.4570 R2 0.2197
# Epoch 026 | TrainLoss 83.9470 | Test RMSE 1.4014 R2 0.2781
# Epoch 027 | TrainLoss 85.4668 | Test RMSE 1.3927 R2 0.2870
# Epoch 028 | TrainLoss 85.9283 | Test RMSE 1.4470 R2 0.2304
# Epoch 029 | TrainLoss 85.5238 | Test RMSE 1.4299 R2 0.2485
# Epoch 030 | TrainLoss 87.9776 | Test RMSE 1.4448 R2 0.2327
# Epoch 031 | TrainLoss 85.7650 | Test RMSE 1.4319 R2 0.2464
# Epoch 032 | TrainLoss 86.9059 | Test RMSE 1.4102 R2 0.2690
# Epoch 033 | TrainLoss 84.4999 | Test RMSE 1.4836 R2 0.1909
# Epoch 034 | TrainLoss 86.6091 | Test RMSE 1.4108 R2 0.2684
# Epoch 035 | TrainLoss 85.8440 | Test RMSE 1.4829 R2 0.1917
# Epoch 036 | TrainLoss 85.3774 | Test RMSE 1.4194 R2 0.2595
# Epoch 037 | TrainLoss 85.4541 | Test RMSE 1.4951 R2 0.1783
# Epoch 038 | TrainLoss 83.8592 | Test RMSE 1.4560 R2 0.2208
# Epoch 039 | TrainLoss 84.0680 | Test RMSE 1.5672 R2 0.0972
# Epoch 040 | TrainLoss 84.9597 | Test RMSE 1.4208 R2 0.2580
# Epoch 041 | TrainLoss 84.5657 | Test RMSE 1.4217 R2 0.2571
# Epoch 042 | TrainLoss 85.9669 | Test RMSE 1.4283 R2 0.2502
# Epoch 043 | TrainLoss 84.9330 | Test RMSE 1.4821 R2 0.1926
# Epoch 044 | TrainLoss 85.3298 | Test RMSE 1.4371 R2 0.2409
# Epoch 045 | TrainLoss 84.3067 | Test RMSE 1.4509 R2 0.2262
# Epoch 046 | TrainLoss 89.3837 | Test RMSE 1.3967 R2 0.2829
# Epoch 047 | TrainLoss 83.8689 | Test RMSE 1.4828 R2 0.1919
# Epoch 048 | TrainLoss 82.9636 | Test RMSE 1.4435 R2 0.2341
# Epoch 049 | TrainLoss 84.4777 | Test RMSE 1.4121 R2 0.2671
# Epoch 050 | TrainLoss 86.0782 | Test RMSE 1.3990 R2 0.2806
# Epoch 051 | TrainLoss 85.5848 | Test RMSE 1.4143 R2 0.2648
# Epoch 052 | TrainLoss 85.6183 | Test RMSE 1.4293 R2 0.2491
# Epoch 053 | TrainLoss 83.4234 | Test RMSE 1.4414 R2 0.2364
# Epoch 054 | TrainLoss 83.4569 | Test RMSE 1.4408 R2 0.2369
# Epoch 055 | TrainLoss 83.6933 | Test RMSE 1.4518 R2 0.2252
# Epoch 056 | TrainLoss 85.4177 | Test RMSE 1.4594 R2 0.2172
# Epoch 057 | TrainLoss 82.3224 | Test RMSE 1.4276 R2 0.2508
# Epoch 058 | TrainLoss 84.2279 | Test RMSE 1.4637 R2 0.2125
# Epoch 059 | TrainLoss 82.8398 | Test RMSE 1.5225 R2 0.1479
# Epoch 060 | TrainLoss 82.9389 | Test RMSE 1.4243 R2 0.2543
# Epoch 061 | TrainLoss 82.9885 | Test RMSE 1.4966 R2 0.1767
# Early stopping triggered
#
# [FOLD 2 FINAL]
# MSE: 1.9233
# RMSE: 1.3868
# MAE: 1.0989
# R2: 0.2931
#
# ================ FOLD 3 ================
# Epoch 000 | TrainLoss 1193.9215 | Test RMSE 5.1922 R2 -7.9287
# Epoch 001 | TrainLoss 705.6714 | Test RMSE 3.8087 R2 -3.8043
# Epoch 002 | TrainLoss 359.3306 | Test RMSE 2.4861 R2 -1.0470
# Epoch 003 | TrainLoss 169.5699 | Test RMSE 1.8079 R2 -0.0825
# Epoch 004 | TrainLoss 110.8216 | Test RMSE 1.5885 R2 0.1643
# Epoch 005 | TrainLoss 91.3600 | Test RMSE 1.6290 R2 0.1212
# Epoch 006 | TrainLoss 89.8586 | Test RMSE 1.5193 R2 0.2355
# Epoch 007 | TrainLoss 85.0721 | Test RMSE 1.5292 R2 0.2255
# Epoch 008 | TrainLoss 84.4318 | Test RMSE 1.5122 R2 0.2427
# Epoch 009 | TrainLoss 87.5212 | Test RMSE 1.6265 R2 0.1238
# Epoch 010 | TrainLoss 85.1645 | Test RMSE 1.6314 R2 0.1185
# Epoch 011 | TrainLoss 85.5802 | Test RMSE 1.5381 R2 0.2165
# Epoch 012 | TrainLoss 86.0082 | Test RMSE 1.5283 R2 0.2264
# Epoch 013 | TrainLoss 83.2506 | Test RMSE 1.5149 R2 0.2400
# Epoch 014 | TrainLoss 83.9592 | Test RMSE 1.5312 R2 0.2235
# Epoch 015 | TrainLoss 85.3011 | Test RMSE 1.5174 R2 0.2374
# Epoch 016 | TrainLoss 83.7248 | Test RMSE 1.5217 R2 0.2331
# Epoch 017 | TrainLoss 83.5143 | Test RMSE 1.5294 R2 0.2253
# Epoch 018 | TrainLoss 84.0948 | Test RMSE 1.5126 R2 0.2423
# Epoch 019 | TrainLoss 83.3635 | Test RMSE 1.5209 R2 0.2339
# Epoch 020 | TrainLoss 84.4313 | Test RMSE 1.5805 R2 0.1727
# Epoch 021 | TrainLoss 84.2805 | Test RMSE 1.5523 R2 0.2020
# Epoch 022 | TrainLoss 82.4808 | Test RMSE 1.5127 R2 0.2422
# Epoch 023 | TrainLoss 83.0100 | Test RMSE 1.5242 R2 0.2305
# Epoch 024 | TrainLoss 84.4883 | Test RMSE 1.5265 R2 0.2282
# Epoch 025 | TrainLoss 82.7625 | Test RMSE 1.5046 R2 0.2502
# Epoch 026 | TrainLoss 86.2153 | Test RMSE 1.5318 R2 0.2229
# Epoch 027 | TrainLoss 82.6202 | Test RMSE 1.5259 R2 0.2289
# Epoch 028 | TrainLoss 82.6126 | Test RMSE 1.5762 R2 0.1772
# Epoch 029 | TrainLoss 81.8257 | Test RMSE 1.4996 R2 0.2552
# Epoch 030 | TrainLoss 83.3474 | Test RMSE 1.5779 R2 0.1754
# Epoch 031 | TrainLoss 84.1245 | Test RMSE 1.5174 R2 0.2375
# Epoch 032 | TrainLoss 82.6474 | Test RMSE 1.5052 R2 0.2496
# Epoch 033 | TrainLoss 82.9983 | Test RMSE 1.5258 R2 0.2290
# Epoch 034 | TrainLoss 82.2133 | Test RMSE 1.5082 R2 0.2467
# Epoch 035 | TrainLoss 83.3792 | Test RMSE 1.5088 R2 0.2461
# Epoch 036 | TrainLoss 83.8466 | Test RMSE 1.5467 R2 0.2077
# Epoch 037 | TrainLoss 85.5363 | Test RMSE 1.5069 R2 0.2480
# Epoch 038 | TrainLoss 83.1017 | Test RMSE 1.4974 R2 0.2575
# Epoch 039 | TrainLoss 81.3449 | Test RMSE 1.5017 R2 0.2531
# Epoch 040 | TrainLoss 81.1065 | Test RMSE 1.5001 R2 0.2547
# Epoch 041 | TrainLoss 81.6073 | Test RMSE 1.5000 R2 0.2548
# Epoch 042 | TrainLoss 82.0460 | Test RMSE 1.5131 R2 0.2418
# Epoch 043 | TrainLoss 81.9626 | Test RMSE 1.5042 R2 0.2506
# Epoch 044 | TrainLoss 81.5822 | Test RMSE 1.5266 R2 0.2282
# Epoch 045 | TrainLoss 81.5713 | Test RMSE 1.5136 R2 0.2412
# Epoch 046 | TrainLoss 80.8458 | Test RMSE 1.5128 R2 0.2421
# Epoch 047 | TrainLoss 81.1864 | Test RMSE 1.4999 R2 0.2550
# Epoch 048 | TrainLoss 79.9714 | Test RMSE 1.5060 R2 0.2489
# Epoch 049 | TrainLoss 79.3475 | Test RMSE 1.5179 R2 0.2370
# Epoch 050 | TrainLoss 81.1488 | Test RMSE 1.6163 R2 0.1348
# Epoch 051 | TrainLoss 82.3619 | Test RMSE 1.5574 R2 0.1967
# Epoch 052 | TrainLoss 80.6417 | Test RMSE 1.5472 R2 0.2072
# Epoch 053 | TrainLoss 81.2317 | Test RMSE 1.5245 R2 0.2302
# Epoch 054 | TrainLoss 81.6850 | Test RMSE 1.5052 R2 0.2497
# Epoch 055 | TrainLoss 80.8931 | Test RMSE 1.4922 R2 0.2626
# Epoch 056 | TrainLoss 80.5532 | Test RMSE 1.5122 R2 0.2426
# Epoch 057 | TrainLoss 79.9931 | Test RMSE 1.4875 R2 0.2672
# Epoch 058 | TrainLoss 81.4752 | Test RMSE 1.5240 R2 0.2307
# Epoch 059 | TrainLoss 80.9584 | Test RMSE 1.5112 R2 0.2436
# Epoch 060 | TrainLoss 80.3098 | Test RMSE 1.5058 R2 0.2490
# Epoch 061 | TrainLoss 80.5017 | Test RMSE 1.4933 R2 0.2615
# Epoch 062 | TrainLoss 83.4691 | Test RMSE 1.5293 R2 0.2254
# Epoch 063 | TrainLoss 80.9905 | Test RMSE 1.5054 R2 0.2494
# Epoch 064 | TrainLoss 82.0195 | Test RMSE 1.4953 R2 0.2595
# Epoch 065 | TrainLoss 78.7933 | Test RMSE 1.6105 R2 0.1410
# Epoch 066 | TrainLoss 82.3112 | Test RMSE 1.5587 R2 0.1953
# Epoch 067 | TrainLoss 80.2701 | Test RMSE 1.4966 R2 0.2582
# Epoch 068 | TrainLoss 79.4661 | Test RMSE 1.4966 R2 0.2582
# Epoch 069 | TrainLoss 80.1156 | Test RMSE 1.5484 R2 0.2059
# Epoch 070 | TrainLoss 79.4524 | Test RMSE 1.5058 R2 0.2490
# Epoch 071 | TrainLoss 78.9550 | Test RMSE 1.5094 R2 0.2455
# Epoch 072 | TrainLoss 81.2416 | Test RMSE 1.5279 R2 0.2268
# Epoch 073 | TrainLoss 81.3287 | Test RMSE 1.5223 R2 0.2325
# Epoch 074 | TrainLoss 78.2776 | Test RMSE 1.5166 R2 0.2382
# Epoch 075 | TrainLoss 81.0636 | Test RMSE 1.5073 R2 0.2476
# Epoch 076 | TrainLoss 81.1326 | Test RMSE 1.4941 R2 0.2607
# Epoch 077 | TrainLoss 80.7092 | Test RMSE 1.5085 R2 0.2464
# Epoch 078 | TrainLoss 78.5482 | Test RMSE 1.6293 R2 0.1208
# Epoch 079 | TrainLoss 81.9598 | Test RMSE 1.5614 R2 0.1925
# Epoch 080 | TrainLoss 78.2153 | Test RMSE 1.5700 R2 0.1836
# Epoch 081 | TrainLoss 80.6478 | Test RMSE 1.5340 R2 0.2207
# Epoch 082 | TrainLoss 79.8075 | Test RMSE 1.5328 R2 0.2219
# Epoch 083 | TrainLoss 78.6260 | Test RMSE 1.5553 R2 0.1989
# Epoch 084 | TrainLoss 79.4661 | Test RMSE 1.5912 R2 0.1614
# Epoch 085 | TrainLoss 80.3868 | Test RMSE 1.5360 R2 0.2186
# Epoch 086 | TrainLoss 79.6293 | Test RMSE 1.5270 R2 0.2277
# Epoch 087 | TrainLoss 80.5949 | Test RMSE 1.5349 R2 0.2198
# Epoch 088 | TrainLoss 79.6596 | Test RMSE 1.5311 R2 0.2236
# Epoch 089 | TrainLoss 78.3831 | Test RMSE 1.5072 R2 0.2477
# Epoch 090 | TrainLoss 77.1825 | Test RMSE 1.5326 R2 0.2221
# Epoch 091 | TrainLoss 76.9405 | Test RMSE 1.5360 R2 0.2187
# Epoch 092 | TrainLoss 76.1394 | Test RMSE 1.5217 R2 0.2331
# Epoch 093 | TrainLoss 77.1180 | Test RMSE 1.5445 R2 0.2100
# Epoch 094 | TrainLoss 78.2813 | Test RMSE 1.5466 R2 0.2078
# Epoch 095 | TrainLoss 78.3687 | Test RMSE 1.5287 R2 0.2260
# Epoch 096 | TrainLoss 78.4770 | Test RMSE 1.5285 R2 0.2262
# Epoch 097 | TrainLoss 77.7968 | Test RMSE 1.5363 R2 0.2183
# Epoch 098 | TrainLoss 76.9854 | Test RMSE 1.5495 R2 0.2048
# Epoch 099 | TrainLoss 76.6232 | Test RMSE 1.5273 R2 0.2274
# Epoch 100 | TrainLoss 76.4261 | Test RMSE 1.5336 R2 0.2211
# Epoch 101 | TrainLoss 78.8071 | Test RMSE 1.5203 R2 0.2346
# Epoch 102 | TrainLoss 78.5610 | Test RMSE 1.5377 R2 0.2169
# Epoch 103 | TrainLoss 77.9181 | Test RMSE 1.5577 R2 0.1964
# Epoch 104 | TrainLoss 74.9834 | Test RMSE 1.5704 R2 0.1832
# Epoch 105 | TrainLoss 76.2345 | Test RMSE 1.5399 R2 0.2146
# Epoch 106 | TrainLoss 76.9373 | Test RMSE 1.5855 R2 0.1675
# Epoch 107 | TrainLoss 76.0746 | Test RMSE 1.5757 R2 0.1778
# Early stopping triggered
#
# [FOLD 3 FINAL]
# MSE: 2.2128
# RMSE: 1.4875
# MAE: 1.1413
# R2: 0.2672
#
# ================ FOLD 4 ================
# Epoch 000 | TrainLoss 1345.0180 | Test RMSE 5.4506 R2 -9.2927
# Epoch 001 | TrainLoss 780.3902 | Test RMSE 3.9914 R2 -4.5195
# Epoch 002 | TrainLoss 387.6074 | Test RMSE 2.5070 R2 -1.1774
# Epoch 003 | TrainLoss 170.1855 | Test RMSE 1.7496 R2 -0.0606
# Epoch 004 | TrainLoss 118.8131 | Test RMSE 1.6995 R2 -0.0006
# Epoch 005 | TrainLoss 112.5965 | Test RMSE 1.6046 R2 0.1079
# Epoch 006 | TrainLoss 93.6890 | Test RMSE 1.5060 R2 0.2142
# Epoch 007 | TrainLoss 89.9535 | Test RMSE 1.5011 R2 0.2193
# Epoch 008 | TrainLoss 91.1812 | Test RMSE 1.4622 R2 0.2593
# Epoch 009 | TrainLoss 87.4167 | Test RMSE 1.4865 R2 0.2345
# Epoch 010 | TrainLoss 85.9267 | Test RMSE 1.4718 R2 0.2496
# Epoch 011 | TrainLoss 85.4766 | Test RMSE 1.4686 R2 0.2528
# Epoch 012 | TrainLoss 85.5219 | Test RMSE 1.4859 R2 0.2350
# Epoch 013 | TrainLoss 85.3846 | Test RMSE 1.4706 R2 0.2507
# Epoch 014 | TrainLoss 85.0288 | Test RMSE 1.5374 R2 0.1812
# Epoch 015 | TrainLoss 89.2592 | Test RMSE 1.4946 R2 0.2261
# Epoch 016 | TrainLoss 86.3331 | Test RMSE 1.4751 R2 0.2461
# Epoch 017 | TrainLoss 86.0996 | Test RMSE 1.4857 R2 0.2352
# Epoch 018 | TrainLoss 85.7990 | Test RMSE 1.4636 R2 0.2579
# Epoch 019 | TrainLoss 85.2714 | Test RMSE 1.4610 R2 0.2605
# Epoch 020 | TrainLoss 84.1154 | Test RMSE 1.4724 R2 0.2490
# Epoch 021 | TrainLoss 84.3511 | Test RMSE 1.4787 R2 0.2425
# Epoch 022 | TrainLoss 86.1871 | Test RMSE 1.4702 R2 0.2512
# Epoch 023 | TrainLoss 85.4859 | Test RMSE 1.4696 R2 0.2517
# Epoch 024 | TrainLoss 83.4490 | Test RMSE 1.4654 R2 0.2560
# Epoch 025 | TrainLoss 83.9946 | Test RMSE 1.5338 R2 0.1850
# Epoch 026 | TrainLoss 85.9531 | Test RMSE 1.4952 R2 0.2255
# Epoch 027 | TrainLoss 85.0343 | Test RMSE 1.4811 R2 0.2401
# Epoch 028 | TrainLoss 86.1592 | Test RMSE 1.4586 R2 0.2630
# Epoch 029 | TrainLoss 84.7370 | Test RMSE 1.4631 R2 0.2584
# Epoch 030 | TrainLoss 84.6054 | Test RMSE 1.4801 R2 0.2410
# Epoch 031 | TrainLoss 84.2998 | Test RMSE 1.4633 R2 0.2582
# Epoch 032 | TrainLoss 82.5795 | Test RMSE 1.4641 R2 0.2574
# Epoch 033 | TrainLoss 86.0481 | Test RMSE 1.4682 R2 0.2532
# Epoch 034 | TrainLoss 86.6042 | Test RMSE 1.5357 R2 0.1829
# Epoch 035 | TrainLoss 83.5738 | Test RMSE 1.4817 R2 0.2394
# Epoch 036 | TrainLoss 81.7061 | Test RMSE 1.4592 R2 0.2623
# Epoch 037 | TrainLoss 83.1537 | Test RMSE 1.5311 R2 0.1879
# Epoch 038 | TrainLoss 82.9715 | Test RMSE 1.4676 R2 0.2538
# Epoch 039 | TrainLoss 83.1282 | Test RMSE 1.4979 R2 0.2227
# Epoch 040 | TrainLoss 82.9554 | Test RMSE 1.4789 R2 0.2423
# Epoch 041 | TrainLoss 83.2959 | Test RMSE 1.4667 R2 0.2547
# Epoch 042 | TrainLoss 82.2312 | Test RMSE 1.5046 R2 0.2157
# Epoch 043 | TrainLoss 83.0685 | Test RMSE 1.4948 R2 0.2259
# Epoch 044 | TrainLoss 84.2146 | Test RMSE 1.5271 R2 0.1920
# Epoch 045 | TrainLoss 85.5701 | Test RMSE 1.5374 R2 0.1811
# Epoch 046 | TrainLoss 83.7014 | Test RMSE 1.4692 R2 0.2521
# Epoch 047 | TrainLoss 83.7438 | Test RMSE 1.4997 R2 0.2208
# Epoch 048 | TrainLoss 83.3731 | Test RMSE 1.4798 R2 0.2414
# Epoch 049 | TrainLoss 84.0500 | Test RMSE 1.4611 R2 0.2604
# Epoch 050 | TrainLoss 81.8350 | Test RMSE 1.4903 R2 0.2306
# Epoch 051 | TrainLoss 84.1160 | Test RMSE 1.4763 R2 0.2450
# Epoch 052 | TrainLoss 83.1924 | Test RMSE 1.4809 R2 0.2402
# Epoch 053 | TrainLoss 86.7048 | Test RMSE 1.5011 R2 0.2194
# Epoch 054 | TrainLoss 84.4072 | Test RMSE 1.4728 R2 0.2486
# Epoch 055 | TrainLoss 81.5926 | Test RMSE 1.4745 R2 0.2467
# Epoch 056 | TrainLoss 82.8122 | Test RMSE 1.4677 R2 0.2537
# Epoch 057 | TrainLoss 84.7930 | Test RMSE 1.4953 R2 0.2254
# Epoch 058 | TrainLoss 84.4003 | Test RMSE 1.4711 R2 0.2502
# Epoch 059 | TrainLoss 81.2493 | Test RMSE 1.4985 R2 0.2221
# Epoch 060 | TrainLoss 83.1598 | Test RMSE 1.4810 R2 0.2401
# Epoch 061 | TrainLoss 82.8281 | Test RMSE 1.4619 R2 0.2595
# Epoch 062 | TrainLoss 83.8436 | Test RMSE 1.4895 R2 0.2313
# Epoch 063 | TrainLoss 82.6917 | Test RMSE 1.4965 R2 0.2242
# Epoch 064 | TrainLoss 84.1627 | Test RMSE 1.4930 R2 0.2278
# Epoch 065 | TrainLoss 83.1233 | Test RMSE 1.4857 R2 0.2353
# Epoch 066 | TrainLoss 84.1829 | Test RMSE 1.4621 R2 0.2594
# Epoch 067 | TrainLoss 81.2652 | Test RMSE 1.4667 R2 0.2548
# Epoch 068 | TrainLoss 81.6417 | Test RMSE 1.4808 R2 0.2404
# Epoch 069 | TrainLoss 83.0529 | Test RMSE 1.4702 R2 0.2511
# Epoch 070 | TrainLoss 81.4873 | Test RMSE 1.5078 R2 0.2124
# Epoch 071 | TrainLoss 82.4853 | Test RMSE 1.4652 R2 0.2563
# Epoch 072 | TrainLoss 81.6151 | Test RMSE 1.4747 R2 0.2465
# Epoch 073 | TrainLoss 81.3210 | Test RMSE 1.4737 R2 0.2476
# Epoch 074 | TrainLoss 82.0141 | Test RMSE 1.5028 R2 0.2176
# Epoch 075 | TrainLoss 81.7544 | Test RMSE 1.4734 R2 0.2478
# Epoch 076 | TrainLoss 81.2557 | Test RMSE 1.4862 R2 0.2348
# Epoch 077 | TrainLoss 82.2980 | Test RMSE 1.4756 R2 0.2457
# Epoch 078 | TrainLoss 82.7467 | Test RMSE 1.5359 R2 0.1828
# Early stopping triggered
#
# [FOLD 4 FINAL]
# MSE: 2.1274
# RMSE: 1.4586
# MAE: 1.0776
# R2: 0.2630
#
# ================ FINAL 5-FOLD RESULT ================
# MSE  : 2.2980 ± 0.3628
# RMSE : 1.5115 ± 0.1153
# MAE  : 1.1466 ± 0.0549
# R2   : 0.2614 ± 0.0279

# %% [markdown]
# MSE  : 2.2667 ± 0.3806
# RMSE : 1.5003 ± 0.1261
# MAE  : 1.1279 ± 0.1055
# R2   : 0.2677 ± 0.0744

# %% [markdown]
# ## TabPFN

# %%
import os
import json
import numpy as np
import pandas as pd
import torch
from tabpfn import TabPFNRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import warnings

import os
import json
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import torch

from tabpfn import TabPFNRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler

# Suppress warnings
warnings.filterwarnings("ignore")
# =========================
# path
# =========================
DATA_DIR = r"data/input"
SPLIT_PATH = os.path.join(DATA_DIR, "Landsat-8/Landsat-8_splits.json")

csv_path = os.path.join(DATA_DIR, "Landsat-8.csv")

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device)

# =========================
# load split
# =========================
def load_split(path):
    with open(path, "r") as f:
        return json.load(f)

# =========================
# metrics
# =========================
def evaluate(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    return mse, rmse, mae, r2

# =========================
# data loading
# =========================
raw = pd.read_csv(csv_path, encoding="gbk")
raw.columns = raw.columns.astype(str).str.strip().str.replace('\ufeff', '', regex=False)

max_feat = max(165, raw.shape[1])
features = raw.iloc[:, :max_feat].copy()

target_col = "溶解氧"

X_df = features.copy()
if target_col in X_df.columns:
    X_df = X_df.drop(columns=[target_col])

X = X_df.apply(pd.to_numeric, errors="coerce")
y = pd.to_numeric(raw[target_col], errors="coerce")

data = pd.concat([X, y], axis=1).dropna()
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# =========================
# group
# =========================
group_size = 1
num_samples = len(y) // group_size

valid_len = num_samples * group_size
X = X[:valid_len]
y = y[:valid_len]

groups = np.repeat(np.arange(num_samples), group_size)

print("samples:", len(y), "features:", X.shape[1])
print("group samples:", num_samples)

# =========================
# load folds
# =========================
folds = load_split(SPLIT_PATH)

# =========================
# result container
# =========================
results = []

# =========================
# 5-fold training 
# =========================
for fold_id in range(5):

    print(f"\n================ FOLD {fold_id} ================")

    train_idx = np.array(folds[fold_id]["train_idx"])
    test_idx = np.array(folds[fold_id]["test_idx"])

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]
    # ===== 加标准化 =====
    from sklearn.preprocessing import StandardScaler

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # =========================
    # model
    # =========================
    model = TabPFNRegressor(
        n_estimators=32,
        device=device
    )

    # =========================
    # train
    # =========================
    model.fit(X_train, y_train)

    # =========================
    # predict
    # =========================
    pred_train = model.predict(X_train)
    pred_test = model.predict(X_test)

    # =========================
    # evaluate
    # =========================
    train_metrics = evaluate(y_train, pred_train)
    test_metrics = evaluate(y_test, pred_test)

    print(f"[Train] MSE={train_metrics[0]:.4f} RMSE={train_metrics[1]:.4f} MAE={train_metrics[2]:.4f} R2={train_metrics[3]:.4f}")
    print(f"[Test ] MSE={test_metrics[0]:.4f} RMSE={test_metrics[1]:.4f} MAE={test_metrics[2]:.4f} R2={test_metrics[3]:.4f}")

    # =========================
    # save fold result
    # =========================
    results.append(test_metrics)

    # Save predictions
    save_dir = os.path.join(DATA_DIR, "Landsat-8/TabPFN")
    os.makedirs(save_dir, exist_ok=True)

    np.save(os.path.join(save_dir, f"fold_{fold_id}_pred.npy"), pred_test)

# =========================
# final summary
# =========================
results = np.array(results)

print("\n================ FINAL 5-FOLD RESULT ================")
print(f"MSE  : {results[:,0].mean():.4f} ± {results[:,0].std():.4f}")
print(f"RMSE : {results[:,1].mean():.4f} ± {results[:,1].std():.4f}")
print(f"MAE  : {results[:,2].mean():.4f} ± {results[:,2].std():.4f}")
print(f"R2   : {results[:,3].mean():.4f} ± {results[:,3].std():.4f}")
# Out:
# Device: cuda
# samples: 640 features: 6
# group samples: 640
#
# ================ FOLD 0 ================
# [Train] MSE=1.5085RMSE=1.2282 MAE=0.8301 R2=0.5138
# [Test ] MSE=1.6470 RMSE=1.2834 MAE=0.9863 R2=0.4659
#
# ================ FOLD 1 ================
# [Train] MSE=1.2404RMSE=1.1137 MAE=0.7990 R2=0.5763
# [Test ] MSE=2.6128 RMSE=1.6164 MAE=1.0467 R2=0.3090
#
# ================ FOLD 2 ================
# [Train] MSE=1.5254RMSE=1.2351 MAE=0.8444 R2=0.5223
# [Test ] MSE=1.4884 RMSE=1.2200 MAE=0.9038 R2=0.4529
#
# ================ FOLD 3 ================
# [Train] MSE=1.3462RMSE=1.1603 MAE=0.7922 R2=0.5683
# [Test ] MSE=1.8991 RMSE=1.3781 MAE=0.9830 R2=0.3710
#
# ================ FOLD 4 ================
# [Train] MSE=1.6082RMSE=1.2681 MAE=0.8804 R2=0.4898
# [Test ] MSE=1.3490 RMSE=1.1615 MAE=0.8316 R2=0.5326
#
# ================ FINAL 5-FOLD RESULT ================
# MSE  : 1.7993 ± 0.4459
# RMSE : 1.3319 ± 0.1594
# MAE  : 0.9503 ± 0.0747
# R2   : 0.4263 ± 0.0780

# %% [markdown]
# ================ FINAL 5-FOLD RESULT ================
# MSE  : 1.8566 ± 0.2916
# RMSE : 1.3583 ± 0.1076
# MAE  : 0.9647 ± 0.0792
# R2   : 0.3977 ± 0.0758

# %% [markdown]
# ## Transformer

# %%
import os
import json
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import copy
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# =========================
# path
# =========================
DATA_DIR = r"data/input"
CSV_PATH = os.path.join(DATA_DIR, "Landsat-8.csv")
SPLIT_PATH = os.path.join(DATA_DIR, "Landsat-8/Landsat-8_splits.json")

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device)

# =========================
# load split
# =========================
def load_folds(path):
    with open(path, "r") as f:
        return json.load(f)

# =========================
# metrics
# =========================
def evaluate(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    return mse, rmse, mae, r2

# =========================
# Transformer baseline model
# =========================
class TransformerBaseline(nn.Module):
    def __init__(self, d_model=32, nhead=4, num_layers=2):
        super().__init__()

        self.embed = nn.Linear(1, d_model)

        self.pos = nn.Parameter(torch.randn(1, 200, d_model))

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            batch_first=True
        )

        self.encoder = nn.TransformerEncoder(
            encoder_layer,
            num_layers=num_layers
        )

        self.head = nn.Sequential(
            nn.Linear(d_model, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

    def forward(self, x):
        # x: (B, N)
        x = x.unsqueeze(-1)
        x = self.embed(x)

        N = x.size(1)
        x = x + self.pos[:, :N, :].to(x.device)

        x = self.encoder(x)

        x = x.mean(dim=1)

        return self.head(x).squeeze()

# =========================
# load dataset
# =========================
raw = pd.read_csv(CSV_PATH, encoding="gbk")
raw.columns = raw.columns.astype(str).str.strip().str.replace('\ufeff', '', regex=False)

max_feat = min(165, raw.shape[1])
target_col = "溶解氧"

X_df = raw.iloc[:, :max_feat].copy()

if target_col in X_df.columns:
    X_df = X_df.drop(columns=[target_col])

X = X_df.apply(pd.to_numeric, errors="coerce")
y = pd.to_numeric(raw[target_col], errors="coerce")

data = pd.concat([X, y], axis=1).dropna()
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

print("Samples:", len(y), "Features:", X.shape[1])

# =========================
# group
# =========================
group_size = 1
num_samples = len(y) // group_size

valid_len = num_samples * group_size
X = X[:valid_len]
y = y[:valid_len]

print("Group samples:", num_samples)

# =========================
# load folds
# =========================
folds = load_folds(SPLIT_PATH)

# =========================
# training
# =========================
results = []

for fold_id in range(5):

    print(f"\n================ FOLD {fold_id} ================")

    train_idx = np.array(folds[fold_id]["train_idx"])
    test_idx = np.array(folds[fold_id]["test_idx"])

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # tensor
    # =========================
    X_train = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_train = torch.tensor(y_train, dtype=torch.float32).to(device)

    X_test = torch.tensor(X_test, dtype=torch.float32).to(device)
    y_test = torch.tensor(y_test, dtype=torch.float32)
    # =========================
    # model
    # =========================
    model = TransformerBaseline().to(device)
    opt = torch.optim.Adam(model.parameters(), lr=1e-3)
    loss_fn = nn.MSELoss()

    # =========================
    # training loop
    # =========================
    best_loss = float("inf")
    patience = 50
    wait = 0

    for epoch in range(500):

        model.train()

        pred = model(X_train)
        loss = loss_fn(pred, y_train)

        opt.zero_grad()
        loss.backward()
        opt.step()

        model.eval()
        with torch.no_grad():
            pred = model(X_test).cpu().numpy()
        mse, rmse, mae, r2 = evaluate(y_test, pred)
        # early stopping
        if rmse < best_loss:
            best_loss = rmse
            best_model = copy.deepcopy(model.state_dict())
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                print("Early stopping triggered")
                break

    # =========================
    # evaluation
    # =========================
    model.load_state_dict(best_model)

    model.eval()
    with torch.no_grad():
        pred = model(X_test).cpu().numpy()

    mse, rmse, mae, r2 = evaluate(y_test, pred)

    print(f"MSE={mse:.4f}, RMSE={rmse:.4f}, MAE={mae:.4f}, R2={r2:.4f}")

    results.append([mse, rmse, mae, r2])

    # =========================
    # save
    # =========================
    save_dir = os.path.join(DATA_DIR, "Landsat-8/Transformer")
    os.makedirs(save_dir, exist_ok=True)

    np.save(os.path.join(save_dir, f"fold_{fold_id}_pred.npy"), pred)
    torch.save(best_model, os.path.join(save_dir, f"fold_{fold_id}.pth"))

# =========================
# final result
# =========================
results = np.array(results)

print("\n================ FINAL 5-FOLD RESULT ================")
print(f"MSE  : {results[:,0].mean():.4f} ± {results[:,0].std():.4f}")
print(f"RMSE : {results[:,1].mean():.4f} ± {results[:,1].std():.4f}")
print(f"MAE  : {results[:,2].mean():.4f} ± {results[:,2].std():.4f}")
print(f"R2   : {results[:,3].mean():.4f} ± {results[:,3].std():.4f}")
# Out:
# Device: cuda
# Samples: 640 Features: 6
# Group samples: 640
#
# ================ FOLD 0 ================
# Early stopping triggered
# MSE=1.9032, RMSE=1.3796, MAE=1.0609, R2=0.3828
#
# ================ FOLD 1 ================
# Early stopping triggered
# MSE=3.7811, RMSE=1.9445, MAE=1.4212, R2=-0.0000
#
# ================ FOLD 2 ================
# Early stopping triggered
# MSE=1.6046, RMSE=1.2667, MAE=0.9431, R2=0.4102
#
# ================ FOLD 3 ================
# Early stopping triggered
# MSE=2.1438, RMSE=1.4642, MAE=1.0773, R2=0.2900
#
# ================ FOLD 4 ================
# Early stopping triggered
# MSE=1.7590, RMSE=1.3263, MAE=0.9867, R2=0.3906
#
# ================ FINAL 5-FOLD RESULT ================
# MSE  : 2.2383 ± 0.7915
# RMSE : 1.4763 ± 0.2430
# MAE  : 1.0978 ± 0.1689
# R2   : 0.2947 ± 0.1531

# %% [markdown]
# ================ FINAL 5-FOLD RESULT ================
# MSE  : 2.6167 ± 0.5178
# RMSE : 1.6095 ± 0.1619
# MAE  : 1.2367 ± 0.1262
# R2   : 0.1517 ± 0.1475

# %% [markdown]
# ## Residual MLP

# %%
import os
import json
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# =========================
# path
# =========================
DATA_DIR = r"data/input"
CSV_PATH = os.path.join(DATA_DIR, "Landsat-8.csv")
SPLIT_PATH = os.path.join(DATA_DIR, "Landsat-8/Landsat-8_splits.json")

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device)

# =========================
# load folds
# =========================
def load_folds(path):
    with open(path, "r") as f:
        return json.load(f)

# =========================
# metrics
# =========================
def evaluate(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    return mse, rmse, mae, r2

# =========================
# MLP model
# =========================
class ResidualBlock(nn.Module):
    def __init__(self, in_dim, out_dim):
        super().__init__()
        self.fc = nn.Linear(in_dim, out_dim)
        self.relu = nn.ReLU()

        # 如果维度不同，用 projection
        self.proj = nn.Linear(in_dim, out_dim) if in_dim != out_dim else nn.Identity()

    def forward(self, x):
        return self.relu(self.fc(x) + self.proj(x))


class MLP(nn.Module):
    def __init__(self, in_dim):
        super().__init__()

        self.block1 = ResidualBlock(in_dim, 256)
        self.block2 = ResidualBlock(256, 128)
        self.block3 = ResidualBlock(128, 64)
        self.block4 = nn.Linear(64, 1)

    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        return x.squeeze()

# =========================
# load dataset
# =========================
raw = pd.read_csv(CSV_PATH, encoding="gbk")

raw.columns = raw.columns.astype(str).str.strip().str.replace('\ufeff', '', regex=False)

max_feat = min(165, raw.shape[1])
target_col = "溶解氧"

X_df = raw.iloc[:, :max_feat].copy()

if target_col in X_df.columns:
    X_df = X_df.drop(columns=[target_col])

X = X_df.apply(pd.to_numeric, errors="coerce")
y = pd.to_numeric(raw[target_col], errors="coerce")

data = pd.concat([X, y], axis=1).dropna()

X = data.iloc[:, :-1].values.astype(np.float32)
y = data.iloc[:, -1].values.astype(np.float32)

print("Samples:", len(y), "Features:", X.shape[1])

# =========================
# group
# =========================
group_size = 10
num_samples = len(y) // group_size

valid_len = num_samples * group_size
X = X[:valid_len]
y = y[:valid_len]

print("Group samples:", num_samples)

# =========================
# folds
# =========================
folds = load_folds(SPLIT_PATH)

# =========================
# training
# =========================
results = []

for fold_id in range(5):

    print(f"\n================ FOLD {fold_id} ================")

    train_idx = np.array(folds[fold_id]["train_idx"])
    test_idx = np.array(folds[fold_id]["test_idx"])

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # tensor
    # =========================
    X_train = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_train = torch.tensor(y_train, dtype=torch.float32).to(device)

    X_test = torch.tensor(X_test, dtype=torch.float32).to(device)

    # =========================
    # model
    # =========================
    model = MLP(X.shape[1]).to(device)

    opt = torch.optim.Adam(model.parameters(), lr=1e-3)
    loss_fn = nn.MSELoss()

    # =========================
    # training loop
    # =========================
    best_loss = float("inf")
    patience = 50
    wait = 0

    for epoch in range(500):

        model.train()

        pred = model(X_train)
        loss = loss_fn(pred, y_train)

        opt.zero_grad()
        loss.backward()
        opt.step()

        model.eval()
        with torch.no_grad():
            pred = model(X_test).cpu().numpy()
        mse, rmse, mae, r2 = evaluate(y_test, pred)
        # early stopping
        if rmse < best_loss:
            best_loss = rmse
            best_model = copy.deepcopy(model.state_dict())
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                # print("Early stopping triggered")
                break

    # =========================
    # evaluation
    # =========================
    model.load_state_dict(best_model)

    model.eval()
    with torch.no_grad():
        pred = model(X_test).cpu().numpy()

    mse, rmse, mae, r2 = evaluate(y_test, pred)

    print(f"MSE={mse:.4f}, RMSE={rmse:.4f}, MAE={mae:.4f}, R2={r2:.4f}")

    results.append([mse, rmse, mae, r2])
    # =========================
    # save
    # =========================
    save_dir = os.path.join(DATA_DIR, "Landsat-8/MLP")
    os.makedirs(save_dir, exist_ok=True)

    np.save(os.path.join(save_dir, f"fold_{fold_id}_pred.npy"), pred)
    torch.save(best_model, os.path.join(save_dir, f"fold_{fold_id}.pth"))

# =========================
# final result
# =========================
results = np.array(results)

print("\n================ FINAL 5-FOLD RESULT ================")
print(f"MSE  : {results[:,0].mean():.4f} ± {results[:,0].std():.4f}")
print(f"RMSE : {results[:,1].mean():.4f} ± {results[:,1].std():.4f}")
print(f"MAE  : {results[:,2].mean():.4f} ± {results[:,2].std():.4f}")
print(f"R2   : {results[:,3].mean():.4f} ± {results[:,3].std():.4f}")
# Out:
# Device: cuda
# Samples: 640 Features: 6
# Group samples: 64
#
# ================ FOLD 0 ================
# MSE=1.7094, RMSE=1.3075, MAE=0.9984, R2=0.4456
#
# ================ FOLD 1 ================
# MSE=2.7418, RMSE=1.6558, MAE=1.1104, R2=0.2749
#
# ================ FOLD 2 ================
# MSE=1.5486, RMSE=1.2444, MAE=0.9259, R2=0.4308
#
# ================ FOLD 3 ================
# MSE=2.1197, RMSE=1.4559, MAE=1.1011, R2=0.2980
#
# ================ FOLD 4 ================
# MSE=1.6080, RMSE=1.2681, MAE=0.9287, R2=0.4429
#
# ================ FINAL 5-FOLD RESULT ================
# MSE  : 1.9455 ± 0.4453
# RMSE : 1.3863 ± 0.1535
# MAE  : 1.0129 ± 0.0802
# R2   : 0.3784 ± 0.0757

# %% [markdown]
# ================ FINAL 5-FOLD RESULT ================
# MSE  : 1.8440 ± 0.8789
# RMSE : 1.3123 ± 0.3491
# MAE  : 0.9125 ± 0.2773
# R2   : 0.4301 ± 0.2456

# %% [markdown]
# ## XGBoost

# %%
import numpy as np
import pandas as pd
import json
import os
import copy

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GroupKFold
import xgboost as xgb

# =========================
# path config
# =========================
DATA_DIR = r"E:\LYQ\work\250916remote_model\data\input"
CSV_PATH = os.path.join(DATA_DIR, "Landsat-8.csv")
SPLIT_PATH = os.path.join(DATA_DIR, "Landsat-8/Landsat-8_splits.json")

SAVE_DIR = os.path.join(DATA_DIR, "Landsat-8/XGBoost")
os.makedirs(SAVE_DIR, exist_ok=True)

# =========================
# load split
# =========================
def load_split(path):
    with open(path, "r") as f:
        return json.load(f)

# =========================
# evaluation
# =========================
def evaluate(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    return mse, rmse, mae, r2

# =========================
# load data
# =========================
raw = pd.read_csv(CSV_PATH, encoding="gbk")
raw.columns = raw.columns.astype(str).str.strip()

# feature selection
max_feat = min(165, raw.shape[1])
features = raw.iloc[:, :max_feat].copy()

target_col = "溶解氧"

if target_col not in raw.columns:
    raise ValueError(f"Target column {target_col} not found")

X_df = features.copy()
if target_col in X_df.columns:
    X_df = X_df.drop(columns=[target_col])

X = X_df.apply(pd.to_numeric, errors="coerce")
y = pd.to_numeric(raw[target_col], errors="coerce")

data = pd.concat([X, y], axis=1).dropna()

X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

print(f"Samples: {len(y)}, Features: {X.shape[1]}")

# =========================
# group definition (same as PI-Transformer)
# =========================
group_size = 1
num_samples = len(y) // group_size

valid_len = num_samples * group_size
X = X[:valid_len]
y = y[:valid_len]

groups = np.repeat(np.arange(num_samples), group_size)

print(f"Grouped samples: {num_samples}")

# =========================
# load folds
# =========================
folds = load_split(SPLIT_PATH)

# =========================
# training
# =========================
results = []

for fold_id in range(5):

    print(f"\n================ FOLD {fold_id} ================")

    train_idx = np.array(folds[fold_id]["train_idx"])
    test_idx = np.array(folds[fold_id]["test_idx"])

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # model
    # =========================
    model = xgb.XGBRegressor(
        n_estimators=1000,
        max_depth=3,
        learning_rate=0.01,
        subsample=0.7,
        colsample_bytree=0.7,
        reg_lambda=1.0,
        objective="reg:squarederror",
        tree_method="hist",
        random_state=1234
    )

    model.fit(
        X_train, y_train,
        eval_set=[(X_test, y_test)],
        verbose=False
    )

    # =========================
    # prediction
    # =========================
    y_pred = model.predict(X_test)

    mse, rmse, mae, r2 = evaluate(y_test, y_pred)

    print(f"Fold {fold_id} | MSE: {mse:.4f} RMSE: {rmse:.4f} MAE: {mae:.4f} R2: {r2:.4f}")

    # =========================
    # save model
    # =========================
    model_path = os.path.join(SAVE_DIR, f"xgb_fold{fold_id}.json")
    model.save_model(model_path)

    print(f"Saved: {model_path}")

    results.append([mse, rmse, mae, r2])

# =========================
# summary
# =========================
results = np.array(results)

print("\n================ FINAL 5-FOLD RESULT ================")
print(f"MSE : {results[:,0].mean():.4f} ± {results[:,0].std():.4f}")
print(f"RMSE: {results[:,1].mean():.4f} ± {results[:,1].std():.4f}")
print(f"MAE : {results[:,2].mean():.4f} ± {results[:,2].std():.4f}")
print(f"R2  : {results[:,3].mean():.4f} ± {results[:,3].std():.4f}")
# Out:
# Samples: 640, Features: 6
# Grouped samples: 640
#
# ================ FOLD 0 ================
# Fold 0 | MSE: 2.6245 RMSE: 1.6200 MAE: 1.1333 R2: 0.3013
# Saved: E:\LYQ\work\250916remote_model\data\input\Landsat-8/XGBoost\xgb_fold0.json
#
# ================ FOLD 1 ================
# Fold 1 | MSE: 1.8788 RMSE: 1.3707 MAE: 1.0464 R2: 0.2853
# Saved: E:\LYQ\work\250916remote_model\data\input\Landsat-8/XGBoost\xgb_fold1.json
#
# ================ FOLD 2 ================
# Fold 2 | MSE: 2.1717 RMSE: 1.4737 MAE: 1.0355 R2: 0.2286
# Saved: E:\LYQ\work\250916remote_model\data\input\Landsat-8/XGBoost\xgb_fold2.json
#
# ================ FOLD 3 ================
# Fold 3 | MSE: 2.3836 RMSE: 1.5439 MAE: 1.1063 R2: 0.2677
# Saved: E:\LYQ\work\250916remote_model\data\input\Landsat-8/XGBoost\xgb_fold3.json
#
# ================ FOLD 4 ================
# Fold 4 | MSE: 1.9666 RMSE: 1.4024 MAE: 1.0559 R2: 0.3405
# Saved: E:\LYQ\work\250916remote_model\data\input\Landsat-8/XGBoost\xgb_fold4.json
#
# ================ FINAL 5-FOLD RESULT ================
# MSE : 2.2051 ± 0.2728
# RMSE: 1.4821 ± 0.0913
# MAE : 1.0755 ± 0.0377
# R2  : 0.2847 ± 0.0369

# %% [markdown]
# ================ FINAL 5-FOLD RESULT ================
# MSE : 1.4657 ± 0.3457
# RMSE: 1.2020 ± 0.1440
# MAE : 0.8685 ± 0.1244
# R2  : 0.5427 ± 0.0572

# %% [markdown]
# ## Random Forest

# %%
import numpy as np
import pandas as pd
import json
import os
import copy
import joblib

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# =========================
# path config
# =========================
DATA_DIR = r"data\input"
CSV_PATH = os.path.join(DATA_DIR, "Landsat-8.csv")
SPLIT_PATH = os.path.join(DATA_DIR, "Landsat-8/Landsat-8_splits.json")

SAVE_DIR = os.path.join(DATA_DIR, "Landsat-8/RandomForest")
os.makedirs(SAVE_DIR, exist_ok=True)

# =========================
# load split
# =========================
def load_split(path):
    with open(path, "r") as f:
        return json.load(f)

# =========================
# evaluation
# =========================
def evaluate(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    return mse, rmse, mae, r2

# =========================
# load data
# =========================
raw = pd.read_csv(CSV_PATH, encoding="gbk")
raw.columns = raw.columns.astype(str).str.strip()

# =========================
# feature / target
# =========================
max_feat = min(165, raw.shape[1])
features = raw.iloc[:, :max_feat].copy()

target_col = "溶解氧"

if target_col not in raw.columns:
    raise ValueError(f"Target column {target_col} not found")

X_df = features.copy()
if target_col in X_df.columns:
    X_df = X_df.drop(columns=[target_col])

X = X_df.apply(pd.to_numeric, errors="coerce")
y = pd.to_numeric(raw[target_col], errors="coerce")

data = pd.concat([X, y], axis=1).dropna()

X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

print(f"Samples: {len(y)}, Features: {X.shape[1]}")

# =========================
# group definition (same as PI-Transformer)
# =========================
group_size = 10
num_samples = len(y) // group_size

valid_len = num_samples * group_size
X = X[:valid_len]
y = y[:valid_len]

groups = np.repeat(np.arange(num_samples), group_size)

print(f"Grouped samples: {num_samples}")

# =========================
# load splits
# =========================
folds = load_split(SPLIT_PATH)

# =========================
# training
# =========================
results = []

for fold_id in range(5):

    print(f"\n================ FOLD {fold_id} ================")

    train_idx = np.array(folds[fold_id]["train_idx"])
    test_idx = np.array(folds[fold_id]["test_idx"])

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # =========================
    # Random Forest model
    # =========================
    model = RandomForestRegressor(
        n_estimators=500,
        max_depth=None,
        min_samples_split=2,
        min_samples_leaf=1,
        max_features="sqrt",
        bootstrap=True,
        n_jobs=-1,
        random_state=42
    )

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    mse, rmse, mae, r2 = evaluate(y_test, y_pred)

    print(f"Fold {fold_id} | MSE: {mse:.4f} RMSE: {rmse:.4f} MAE: {mae:.4f} R2: {r2:.4f}")

    # =========================
    # save model
    # =========================
    model_path = os.path.join(SAVE_DIR, f"rf_fold{fold_id}.pkl")
    joblib.dump(model, model_path)

    print(f"Saved: {model_path}")

    results.append([mse, rmse, mae, r2])

# =========================
# summary
# =========================
results = np.array(results)

print("\n================ FINAL 5-FOLD RESULT ================")
print(f"MSE : {results[:,0].mean():.4f} ± {results[:,0].std():.4f}")
print(f"RMSE: {results[:,1].mean():.4f} ± {results[:,1].std():.4f}")
print(f"MAE : {results[:,2].mean():.4f} ± {results[:,2].std():.4f}")
print(f"R2  : {results[:,3].mean():.4f} ± {results[:,3].std():.4f}")
# Out:
# Samples: 640, Features: 6
# Grouped samples: 64
#
# ================ FOLD 0 ================
# Fold 0 | MSE: 2.4966 RMSE: 1.5801 MAE: 1.0989 R2: 0.3353
# Saved: data\input\Landsat-8/RandomForest\rf_fold0.pkl
#
# ================ FOLD 1 ================
# Fold 1 | MSE: 1.7889 RMSE: 1.3375 MAE: 1.0137 R2: 0.3195
# Saved: data\input\Landsat-8/RandomForest\rf_fold1.pkl
#
# ================ FOLD 2 ================
# Fold 2 | MSE: 2.1820 RMSE: 1.4772 MAE: 1.0332 R2: 0.2250
# Saved: data\input\Landsat-8/RandomForest\rf_fold2.pkl
#
# ================ FOLD 3 ================
# Fold 3 | MSE: 2.4768 RMSE: 1.5738 MAE: 1.1252 R2: 0.2390
# Saved: data\input\Landsat-8/RandomForest\rf_fold3.pkl
#
# ================ FOLD 4 ================
# Fold 4 | MSE: 2.0055 RMSE: 1.4161 MAE: 1.0559 R2: 0.3274
# Saved: data\input\Landsat-8/RandomForest\rf_fold4.pkl
#
# ================ FINAL 5-FOLD RESULT ================
# MSE : 2.1900 ± 0.2725
# RMSE: 1.4769 ± 0.0929
# MAE : 1.0654 ± 0.0412
# R2  : 0.2893 ± 0.0472
