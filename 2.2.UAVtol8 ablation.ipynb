# %% [markdown]
# # UAVtol8

# %% [markdown]
# ## CSF-FPE Transformer（Continuous Spectral Fusion with Positional Encoding）

# %%
import os
import torch
import torch.nn as nn
import pandas as pd
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import json
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import copy
import torch.nn.functional as F

DATA_DIR = r"\data\input"
SPLIT_PATH = os.path.join(DATA_DIR, "UAV/uav_splits.json")
model_save_dir = os.path.join(DATA_DIR, "UAVtol8_ablation/CSF-FPE")
os.makedirs(model_save_dir, exist_ok=True)

# =========================
# ⭐ Dataset selection
# =========================
selected_datasets = ["uav2l8"]

DATASET_CONFIG = {
    "uav": (0, "UAV.csv"),
    "sentinel": (1, "Sentinel-2.csv"),
    "landsat": (2, "Landsat-8.csv"),
    "uav2s2": (3, "UAV_Sentinel_S2A.csv"),
    "uav2l8": (4, "UAV_Landsat8_SRF.csv")
}

# =========================
# 0. Spectral normalization settings
# =========================
GLOBAL_LAMBDA_MIN = 350.0
GLOBAL_LAMBDA_MAX = 1002

def normalize_wavelength(x):
    return (x - GLOBAL_LAMBDA_MIN) / (GLOBAL_LAMBDA_MAX - GLOBAL_LAMBDA_MIN)

def normalize_delta(x):
    return (x - GLOBAL_LAMBDA_MIN) / (GLOBAL_LAMBDA_MAX - GLOBAL_LAMBDA_MIN)

# =========================
# ⭐ split loader
# =========================
def load_split(path, fold_id=0):
    with open(path, "r") as f:
        folds = json.load(f)

    split = folds[fold_id]
    return (
        np.array(split["train_idx"]),
        np.array(split["test_idx"])
    )

# =========================
# Dataset
# =========================
class SpectralDataset(Dataset):
    def __init__(self, file_path, dtype, x_mean, x_std):
        df = pd.read_csv(file_path, encoding='gbk')
        self.dtype = dtype

        temp = df.iloc[:, -2].values.astype(np.float32)
        self.x = df.iloc[:, :-2].values.astype(np.float32)
        self.y = df.iloc[:, -1].values.astype(np.float32)

        # NDWI filter
        if dtype == 1:
            ndwi = (df['B3'] - df['B8']) / (df['B3'] + df['B8'] + 1e-8)
            mask = ndwi > 0.1
            self.x, self.y, temp = self.x[mask], self.y[mask], temp[mask]

        elif dtype == 2:
            ndwi = (df['SR_B3'] - df['SR_B5']) / (df['SR_B3'] + df['SR_B5'] + 1e-8)
            mask = ndwi > 0.1
            self.x, self.y, temp = self.x[mask], self.y[mask], temp[mask]

        # clean
        mask = np.all(self.x >= 0, axis=1)
        self.x, self.y, temp = self.x[mask], self.y[mask], temp[mask]

        # global norm
        self.x = (self.x - x_mean) / (x_std + 1e-6)

        # wavelength
        if dtype == 0:
            self.lambda_ = np.arange(350, 1003, 4).astype(np.float32)
            self.delta = np.full_like(self.lambda_, 4.0)
            self.group_id = np.arange(len(self.x)) // 10

        elif dtype == 1 or dtype == 3:
            bands = [(443,20),(490,65),(560,35),(665,30),(705,15),
                     (740,15),(783,20),(842,115),(865,20),(945,20)]
            self.lambda_ = np.array([b[0] for b in bands], dtype=np.float32)
            self.delta = np.array([b[1] for b in bands], dtype=np.float32)

        elif dtype == 2 or dtype == 4:
            bands = [(443,20),(482,65),(561,75),(655,50),(865,40)]
            self.lambda_ = np.array([b[0] for b in bands], dtype=np.float32)
            self.delta = np.array([b[1] for b in bands], dtype=np.float32)

        self.lambda_ = normalize_wavelength(self.lambda_)
        self.delta = normalize_delta(self.delta)

        self.temp = (temp - temp.mean()) / (temp.std() + 1e-6)

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return {
            "x": torch.tensor(self.x[idx]),
            "lambda": torch.tensor(self.lambda_),
            "delta": torch.tensor(self.delta),
            "y": torch.tensor(self.y[idx]),
            "type": torch.tensor(self.dtype),
            "temp": torch.tensor(self.temp[idx])
        }

# =========================
# Model
# =========================
class SpectralFusionModel(nn.Module):
    def __init__(
            self,
            d_model=64,
            grid_size=64,

            use_projection=True,
            use_fourier_positional_encoding=True,
            use_temp_token=True
    ):
        super().__init__()
        # =========================
        # 1. Ablation switches
        # =========================
        self.use_projection = use_projection
        self.use_fourier_positional_encoding = use_fourier_positional_encoding
        self.use_temp_token = use_temp_token

        #=========================
        # 2. Attention dimensions
        #=========================
        self.d_model = d_model

        # =========================
        # 3. Input embedding
        # =========================
        self.input_embed = nn.Sequential(
            nn.Linear(3, d_model),
            nn.ReLU(),
            nn.Linear(d_model, d_model)
        )

        self.temp_embed = nn.Sequential(
            nn.Linear(1, d_model),
            nn.ReLU(),
            nn.Linear(d_model, d_model)
        )

        # =========================
        # 4.1 Spectral grid (fixed coordinate system)
        # =========================
        self.register_buffer(
            "grid",
            torch.linspace(0, 1, grid_size)
        )
        # =========================
        # 4.2 Learnable spectral diffusion weights
        # =========================
        self.spectral_weight_net = nn.Sequential(
            nn.Linear(4, 32),
            nn.GELU(),
            nn.Linear(32, 16),
            nn.GELU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

        #=========================
        # replace4. MLP for spectral projection
        #=========================
        self.project_mlp = nn.Sequential(
            nn.Linear(d_model,d_model),
            nn.ReLU(),
            nn.Linear(d_model,d_model)
        )

        # =========================
        # 5. Fourier Encoding
        # =========================
        self.fourier_B = nn.Parameter(
            torch.logspace(0, 2, d_model // 2)
        )
        self.fourier_scale = nn.Parameter(torch.ones(1))

        #=========================
        # replace5. MLP for positional encoding
        #=========================
        self.pos_mlp = nn.Sequential(
            nn.Linear(1, d_model),
            nn.ReLU(),
            nn.Linear(d_model, d_model)
        )

        #=========================
        # 6. Feature fusion layer
        #=========================
        self.fusion = nn.Linear(d_model * 2, d_model)

        # =========================
        # 7. Transformer Encoder
        # =========================
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=4,
            batch_first=True
        )
        self.encoder = nn.TransformerEncoder(
            encoder_layer,
            num_layers=2
        )

        # =========================
        # replace7. MLP for Encoder
        # =========================
        self.encoder_mlp = nn.Sequential(
            nn.Linear(d_model,2*d_model),
            nn.GELU(),
            nn.Linear(2*d_model,d_model),
            nn.GELU()
        )

        # =========================
        # 7. Regression head
        # =========================
        self.head = nn.Sequential(
            nn.Linear(d_model, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

    # =========================
    # spectral projection
    # =========================
    def spectral_project(self, z, wl, delta):

        grid = self.grid.to(z.device).unsqueeze(0).unsqueeze(0)

        wl = wl.unsqueeze(-1)
        delta = delta.unsqueeze(-1)

        sigma = delta + 1e-6

        weight = torch.exp(-((wl - grid) ** 2) / (sigma ** 2))
        weight = weight / (weight.sum(dim=1, keepdim=True) + 1e-8)

        return (z.unsqueeze(2) * weight.unsqueeze(-1)).sum(dim=1)
    # =========================
    # Fourier Encoding
    # =========================
    def fourier_encoding(self, x):
        x = x.unsqueeze(-1)  # (B, N, 1)

        proj = x * self.fourier_B * self.fourier_scale

        return torch.cat([
            torch.sin(proj),
            torch.cos(proj)
        ], dim=-1)
    # =========================
    # forward
    # =========================
    def forward(self, x, wl, delta, dtype, temp):

        # -------------------------
        # 1. input embedding
        # -------------------------
        x = x.unsqueeze(-1)
        wl = wl.unsqueeze(-1)
        delta = delta.unsqueeze(-1)

        inp = torch.cat([x, wl, delta], dim=-1)
        z = self.input_embed(inp)

        # -------------------------
        # 2. spectral projection
        # -------------------------
        if self.use_projection:
            z = self.spectral_project(
                z,
                wl.squeeze(-1),
                delta.squeeze(-1)
            )

        else:
            z = F.interpolate(
                z.transpose(1,2),
                size=len(self.grid),
                mode="linear",
                align_corners=False
            ).transpose(1,2)

            z = self.project_mlp(z)

        # -------------------------
        # 3. Fourier positional encoding
        # -------------------------
        grid = self.grid.unsqueeze(0).expand(z.size(0), -1)

        if self.use_fourier_positional_encoding:
            pos = self.fourier_encoding(grid)
            z = torch.cat([z,pos],dim=-1)
            z = self.fusion(z)

        else:
            pos = self.pos_mlp(grid.unsqueeze(-1))
            z = z + pos

        # -------------------------
        # 4. Encoder
        # -------------------------
        B = z.size(0)

        if self.use_temp_token:
            temp = temp
        else:
            temp = torch.rand_like(temp)
        t = self.temp_embed(temp.unsqueeze(-1)).unsqueeze(1)
        z = torch.cat([t,  z], dim=1)          # (B,N+1,d)

        # -------------------------
        # 5. CLS token pooling
        # -------------------------
        if self.use_fourier_positional_encoding:
            z = self.encoder(z)
            z = z[:, 0]  # CLS token
        else:
            z = self.encoder_mlp(z)
            z = z.mean(dim=1)

        # -------------------------
        # 6. regression head
        # -------------------------
        return self.head(z).squeeze()

# =========================
# Loss
# =========================
def r2_aware_loss(pred, target):
    mse = torch.mean((pred - target) ** 2)

    pred_c = pred - pred.mean()
    tgt_c = target - target.mean()

    corr = torch.sum(pred_c * tgt_c) / (
        torch.sqrt(torch.sum(pred_c ** 2)) *
        torch.sqrt(torch.sum(tgt_c ** 2)) + 1e-8
    )

    return mse + 0.5 * (1 - corr)

# =========================
# ⭐ evaluation
# =========================
def evaluate(model, loader, device):
    model.eval()
    y_true, y_pred = [], []

    with torch.no_grad():
        for batch in loader:
            pred = model(
                batch["x"].to(device),
                batch["lambda"].to(device),
                batch["delta"].to(device),
                batch["type"].to(device),
                batch["temp"].to(device)
            )

            y_true.extend(batch["y"].cpu().numpy())
            y_pred.extend(pred.cpu().numpy())

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)

    return mse, rmse, mae, r2

# %%
import os
import copy
import json
import random
import numpy as np
import pandas as pd
import torch
from torch.utils.data import DataLoader, Subset
from itertools import combinations

# =========================
# Ablation configuration generator
# =========================
MODULES = ["projection", "fourier_positional_encoding", "temp_token"]

def generate_ablation_configs():
    configs = {}

    # Full model
    configs["Full"] = {
        "use_projection": True,
        "use_fourier_positional_encoding": True,
        "use_temp_token": True
    }

    # all combinations
    for r in range(1, len(MODULES) + 1):
        for comb in combinations(MODULES, r):

            name = "No_" + "_".join(comb)

            cfg = {
                "use_projection": True,
                "use_fourier_positional_encoding": True,
                "use_temp_token": True
            }

            for m in comb:
                cfg[f"use_{m}"] = False

            configs[name] = cfg

    return configs


ABLATION_CONFIG = generate_ablation_configs()

# =========================
# train function
# =========================
def train_one_experiment(exp_name, cfg):

    device = "cuda" if torch.cuda.is_available() else "cpu"

    print("\n" + "=" * 80)
    print(f"Running Experiment : {exp_name}")
    print("=" * 80)

    paths = [
        (DATASET_CONFIG[name][0],
         os.path.join(DATA_DIR, DATASET_CONFIG[name][1]))
        for name in selected_datasets
    ]

    # =========================
    # normalization
    # =========================
    all_x = []
    for _, path in paths:
        df = pd.read_csv(path, encoding='gbk')
        all_x.append(df.iloc[:, :-2].values.astype(np.float32))

    all_x = np.vstack(all_x)

    x_mean = all_x.mean(axis=0)
    x_std = all_x.std(axis=0) + 1e-6

    dataset = SpectralDataset(
        paths[0][1],
        paths[0][0],
        x_mean,
        x_std
    )

    folds = json.load(open(SPLIT_PATH))

    results = []
    fold_records = []   # ⭐ NEW: store fold-level metrics

    # =========================
    # 5-fold training
    # =========================
    for fold_id in range(5):

        print(f"\n==== {exp_name} Fold {fold_id} ====")

        train_idx = np.array(folds[fold_id]["train_idx"])
        test_idx = np.array(folds[fold_id]["test_idx"])

        train_loader = DataLoader(
            Subset(dataset, train_idx),
            batch_size=16,
            shuffle=True
        )

        test_loader = DataLoader(
            Subset(dataset, test_idx),
            batch_size=16
        )

        model = SpectralFusionModel(**cfg).to(device)

        opt = torch.optim.Adam(model.parameters(), lr=3e-4)

        best_loss = float("inf")
        patience = 50
        wait = 0
        best_model = None

        # =========================
        # training loop
        # =========================
        for epoch in range(500):

            model.train()
            total_loss = 0

            for batch in train_loader:

                pred = model(
                    batch["x"].to(device),
                    batch["lambda"].to(device),
                    batch["delta"].to(device),
                    batch["type"].to(device),
                    batch["temp"].to(device)
                )

                loss = r2_aware_loss(pred, batch["y"].to(device))

                opt.zero_grad()
                loss.backward()
                opt.step()

                total_loss += loss.item()

            mse, rmse, mae, r2 = evaluate(model, test_loader, device)

            print(
                f"Epoch {epoch:03d} | "
                f"TrainLoss {total_loss:.4f} | "
                f"RMSE {rmse:.4f} | R2 {r2:.4f}"
            )

            if rmse < best_loss:
                best_loss = rmse
                best_model = copy.deepcopy(model.state_dict())
                wait = 0

            else:
                wait += 1
                if wait >= patience:
                    print("Early stopping triggered")
                    break

        # =========================
        # final evaluation
        # =========================
        model.load_state_dict(best_model)

        mse, rmse, mae, r2 = evaluate(model, test_loader, device)

        print(f"\n[FOLD {fold_id} FINAL]")
        print(f"MSE : {mse:.4f}")
        print(f"RMSE: {rmse:.4f}")
        print(f"MAE : {mae:.4f}")
        print(f"R2  : {r2:.4f}")

        results.append([mse, rmse, mae, r2])

        # ⭐ NEW: save fold-level record
        fold_records.append({
            "experiment": exp_name,
            "fold": fold_id,
            "mse": mse,
            "rmse": rmse,
            "mae": mae,
            "r2": r2
        })

    # =========================
    # summary
    # =========================
    results = np.array(results)

    print("\n" + "=" * 80)
    print(exp_name)
    print("=" * 80)
    print("FINAL 5-FOLD RESULT")
    print(f"RMSE : {results[:,1].mean():.4f} ± {results[:,1].std():.4f}")
    print(f"MAE  : {results[:,2].mean():.4f} ± {results[:,2].std():.4f}")
    print(f"R2   : {results[:,3].mean():.4f} ± {results[:,3].std():.4f}")

    return {
        "mean": results.mean(axis=0),
        "folds": results,
        "records": fold_records   # ⭐ NEW
    }


# =========================
# seed
# =========================
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


# =========================
# main
# =========================
if __name__ == "__main__":

    set_seed(42)

    final_results = {}
    all_fold_results = []   # ⭐ NEW global storage

    for exp_name, cfg in ABLATION_CONFIG.items():

        result = train_one_experiment(exp_name, cfg)

        final_results[exp_name] = result["mean"]

        # ⭐ collect fold-level results
        all_fold_results.extend(result["records"])

    # =========================
    # print summary table
    # =========================
    print("\n" + "=" * 100)
    print("FINAL ABLATION RESULTS")
    print("=" * 100)

    print(f"{'Experiment':<25}{'MSE':<12}{'RMSE':<12}{'MAE':<12}{'R2':<12}")

    for k, v in final_results.items():
        print(
            f"{k:<25}"
            f"{v[0]:<12.4f}"
            f"{v[1]:<12.4f}"
            f"{v[2]:<12.4f}"
            f"{v[3]:<12.4f}"
        )

    # =========================
    # save mean results
    # =========================
    ablation_df = pd.DataFrame(
        final_results,
        index=["MSE", "RMSE", "MAE", "R2"]
    ).T

    ablation_df.to_csv(
        os.path.join(
            DATA_DIR,
            "UAVtol8_ablation",
            "CSF-FPE",
            "ablation_results.csv"
        )
    )

    # =========================
    # ⭐ SAVE FOLD-LEVEL RESULTS (IMPORTANT)
    # =========================
    fold_df = pd.DataFrame(all_fold_results)

    fold_df.to_csv(
        os.path.join(
            DATA_DIR,
            "UAVtol8_ablation",
            "CSF-FPE",
            "ablation_fold_results.csv"
        ),
        index=False
    )

    print("\nSaved:")
    print("✔ ablation_results.csv")
    print("✔ ablation_fold_results.csv (fold-level, for plots)")
# Out:
# ================================================================================
# Running Experiment : Full
# ================================================================================
#
# ==== Full Fold 0 ====
# Epoch 000 | TrainLoss 1137.7803 | RMSE 5.1201 | R2 -9.0659
# Epoch 001 | TrainLoss 660.8844 | RMSE 3.6645 | R2 -4.1561
# Epoch 002 | TrainLoss 324.8268 | RMSE 2.2628 | R2 -0.9660
# Epoch 003 | TrainLoss 134.6003 | RMSE 1.4545 | R2 0.1877
# Epoch 004 | TrainLoss 67.6352 | RMSE 1.4396 | R2 0.2042
# Epoch 005 | TrainLoss 57.3218 | RMSE 1.3884 | R2 0.2598
# Epoch 006 | TrainLoss 54.4470 | RMSE 1.4245 | R2 0.2209
# Epoch 007 | TrainLoss 52.1720 | RMSE 1.3385 | R2 0.3121
# Epoch 008 | TrainLoss 49.9209 | RMSE 1.3220 | R2 0.3290
# Epoch 009 | TrainLoss 48.3800 | RMSE 1.3759 | R2 0.2731
# Epoch 010 | TrainLoss 46.9818 | RMSE 1.4286 | R2 0.2164
# Epoch 011 | TrainLoss 49.1013 | RMSE 1.4513 | R2 0.1912
# Epoch 012 | TrainLoss 45.5089 | RMSE 1.4894 | R2 0.1483
# Epoch 013 | TrainLoss 45.1019 | RMSE 1.2450 | R2 0.4049
# Epoch 014 | TrainLoss 41.4885 | RMSE 1.3206 | R2 0.3303
# Epoch 015 | TrainLoss 40.2841 | RMSE 1.6867 | R2 -0.0924
# Epoch 016 | TrainLoss 38.8539 | RMSE 1.1456 | R2 0.4961
# Epoch 017 | TrainLoss 38.1008 | RMSE 1.1772 | R2 0.4679
# Epoch 018 | TrainLoss 33.1273 | RMSE 1.4164 | R2 0.2296
# Epoch 019 | TrainLoss 35.4197 | RMSE 1.5722 | R2 0.0509
# Epoch 020 | TrainLoss 33.8355 | RMSE 0.8936 | R2 0.6934
# Epoch 021 | TrainLoss 35.8151 | RMSE 1.0710 | R2 0.5596
# Epoch 022 | TrainLoss 29.6743 | RMSE 1.1306 | R2 0.5092
# Epoch 023 | TrainLoss 27.2538 | RMSE 1.4417 | R2 0.2019
# Epoch 024 | TrainLoss 33.7326 | RMSE 0.9230 | R2 0.6729
# Epoch 025 | TrainLoss 27.7843 | RMSE 1.0327 | R2 0.5905
# Epoch 026 | TrainLoss 25.7870 | RMSE 1.4908 | R2 0.1467
# Epoch 027 | TrainLoss 28.1754 | RMSE 1.3690 | R2 0.2804
# Epoch 028 | TrainLoss 25.4762 | RMSE 1.1523 | R2 0.4902
# Epoch 029 | TrainLoss 19.6526 | RMSE 1.3624 | R2 0.2873
# Epoch 030 | TrainLoss 26.1394 | RMSE 1.2160 | R2 0.4323
# Epoch 031 | TrainLoss 24.2181 | RMSE 1.1685 | R2 0.4757
# Epoch 032 | TrainLoss 20.2811 | RMSE 1.3232 | R2 0.3277
# Epoch 033 | TrainLoss 25.4595 | RMSE 1.4335 | R2 0.2110
# Epoch 034 | TrainLoss 20.2001 | RMSE 1.4111 | R2 0.2354
# Epoch 035 | TrainLoss 18.7954 | RMSE 1.3749 | R2 0.2742
# Epoch 036 | TrainLoss 19.5120 | RMSE 1.3128 | R2 0.3382
# Epoch 037 | TrainLoss 19.2306 | RMSE 1.2239 | R2 0.4249
# Epoch 038 | TrainLoss 19.6094 | RMSE 1.1794 | R2 0.4659
# Epoch 039 | TrainLoss 20.0080 | RMSE 1.2582 | R2 0.3921
# Epoch 040 | TrainLoss 19.5320 | RMSE 1.3741 | R2 0.2750
# Epoch 041 | TrainLoss 18.0475 | RMSE 1.4941 | R2 0.1429
# Epoch 042 | TrainLoss 18.5371 | RMSE 1.3015 | R2 0.3496
# Epoch 043 | TrainLoss 19.5538 | RMSE 1.4003 | R2 0.2471
# Epoch 044 | TrainLoss 14.8863 | RMSE 1.0999 | R2 0.5355
# Epoch 045 | TrainLoss 16.4234 | RMSE 1.3193 | R2 0.3317
# Epoch 046 | TrainLoss 18.7890 | RMSE 1.1405 | R2 0.5006
# Epoch 047 | TrainLoss 15.3980 | RMSE 1.1386 | R2 0.5022
# Epoch 048 | TrainLoss 17.7106 | RMSE 0.9482 | R2 0.6548
# Epoch 049 | TrainLoss 26.6909 | RMSE 1.5059 | R2 0.1293
# Epoch 050 | TrainLoss 19.1621 | RMSE 1.2293 | R2 0.4197
# Epoch 051 | TrainLoss 17.8710 | RMSE 1.2058 | R2 0.4418
# Epoch 052 | TrainLoss 15.0536 | RMSE 1.0086 | R2 0.6094
# Epoch 053 | TrainLoss 18.8092 | RMSE 1.2918 | R2 0.3593
# Epoch 054 | TrainLoss 19.6339 | RMSE 0.9312 | R2 0.6670
# Epoch 055 | TrainLoss 18.3948 | RMSE 1.1240 | R2 0.5149
# Epoch 056 | TrainLoss 17.4228 | RMSE 1.0193 | R2 0.6010
# Epoch 057 | TrainLoss 15.2498 | RMSE 1.1030 | R2 0.5329
# Epoch 058 | TrainLoss 14.9230 | RMSE 1.1161 | R2 0.5217
# Epoch 059 | TrainLoss 22.0416 | RMSE 1.3154 | R2 0.3356
# Epoch 060 | TrainLoss 16.3503 | RMSE 1.2360 | R2 0.4134
# Epoch 061 | TrainLoss 19.5097 | RMSE 1.3588 | R2 0.2910
# Epoch 062 | TrainLoss 13.1180 | RMSE 1.1110 | R2 0.5260
# Epoch 063 | TrainLoss 17.7236 | RMSE 1.1424 | R2 0.4989
# Epoch 064 | TrainLoss 19.3673 | RMSE 1.3654 | R2 0.2842
# Epoch 065 | TrainLoss 15.3962 | RMSE 1.0337 | R2 0.5897
# Epoch 066 | TrainLoss 13.9684 | RMSE 1.0900 | R2 0.5438
# Epoch 067 | TrainLoss 14.7070 | RMSE 1.2373 | R2 0.4122
# Epoch 068 | TrainLoss 13.6196 | RMSE 1.1050 | R2 0.5311
# Epoch 069 | TrainLoss 14.0505 | RMSE 1.0639 | R2 0.5654
# Epoch 070 | TrainLoss 15.3050 | RMSE 1.1901 | R2 0.4561
# Early stopping triggered
#
# [FOLD 0 FINAL]
# MSE : 0.7986
# RMSE: 0.8936
# MAE : 0.6049
# R2  : 0.6934
#
# ==== Full Fold 1 ====
# Epoch 000 | TrainLoss 1077.8279 | RMSE 4.9586 | R2 -6.2022
# Epoch 001 | TrainLoss 611.8162 | RMSE 3.5914 | R2 -2.7782
# Epoch 002 | TrainLoss 298.6736 | RMSE 2.2969 | R2 -0.5454
# Epoch 003 | TrainLoss 128.6248 | RMSE 1.4242 | R2 0.4059
# Epoch 004 | TrainLoss 70.1349 | RMSE 1.3549 | R2 0.4622
# Epoch 005 | TrainLoss 60.3440 | RMSE 1.2256 | R2 0.5600
# Epoch 006 | TrainLoss 55.6808 | RMSE 1.3091 | R2 0.4980
# Epoch 007 | TrainLoss 51.8261 | RMSE 1.1285 | R2 0.6269
# Epoch 008 | TrainLoss 52.8239 | RMSE 1.9901 | R2 -0.1601
# Epoch 009 | TrainLoss 54.8542 | RMSE 1.1470 | R2 0.6146
# Epoch 010 | TrainLoss 52.4095 | RMSE 1.2943 | R2 0.5093
# Epoch 011 | TrainLoss 47.7522 | RMSE 1.2689 | R2 0.5284
# Epoch 012 | TrainLoss 44.6571 | RMSE 1.2132 | R2 0.5688
# Epoch 013 | TrainLoss 44.0252 | RMSE 1.5082 | R2 0.3337
# Epoch 014 | TrainLoss 47.7219 | RMSE 1.2819 | R2 0.5187
# Epoch 015 | TrainLoss 42.7456 | RMSE 1.3943 | R2 0.4305
# Epoch 016 | TrainLoss 41.5493 | RMSE 1.1443 | R2 0.6165
# Epoch 017 | TrainLoss 41.9695 | RMSE 1.0942 | R2 0.6493
# Epoch 018 | TrainLoss 40.8007 | RMSE 0.8891 | R2 0.7684
# Epoch 019 | TrainLoss 39.4446 | RMSE 1.0797 | R2 0.6585
# Epoch 020 | TrainLoss 39.0950 | RMSE 1.6850 | R2 0.1684
# Epoch 021 | TrainLoss 39.0728 | RMSE 0.9895 | R2 0.7132
# Epoch 022 | TrainLoss 34.1761 | RMSE 1.4000 | R2 0.4259
# Epoch 023 | TrainLoss 31.9036 | RMSE 1.0739 | R2 0.6622
# Epoch 024 | TrainLoss 28.3507 | RMSE 1.5572 | R2 0.2897
# Epoch 025 | TrainLoss 31.7743 | RMSE 1.2839 | R2 0.5171
# Epoch 026 | TrainLoss 25.9407 | RMSE 1.0590 | R2 0.6715
# Epoch 027 | TrainLoss 38.8215 | RMSE 1.2132 | R2 0.5688
# Epoch 028 | TrainLoss 26.9837 | RMSE 1.3439 | R2 0.4710
# Epoch 029 | TrainLoss 25.4528 | RMSE 1.1586 | R2 0.6068
# Epoch 030 | TrainLoss 27.7326 | RMSE 1.0289 | R2 0.6899
# Epoch 031 | TrainLoss 27.8216 | RMSE 1.0716 | R2 0.6636
# Epoch 032 | TrainLoss 21.8104 | RMSE 1.3485 | R2 0.4673
# Epoch 033 | TrainLoss 29.6834 | RMSE 1.1358 | R2 0.6221
# Epoch 034 | TrainLoss 28.5149 | RMSE 1.6290 | R2 0.2227
# Epoch 035 | TrainLoss 20.2057 | RMSE 1.1472 | R2 0.6145
# Epoch 036 | TrainLoss 17.9287 | RMSE 1.5950 | R2 0.2548
# Epoch 037 | TrainLoss 28.6971 | RMSE 1.2487 | R2 0.5433
# Epoch 038 | TrainLoss 35.9872 | RMSE 1.0838 | R2 0.6559
# Epoch 039 | TrainLoss 20.8348 | RMSE 1.3632 | R2 0.4557
# Epoch 040 | TrainLoss 17.8491 | RMSE 1.3325 | R2 0.4799
# Epoch 041 | TrainLoss 17.8785 | RMSE 1.3097 | R2 0.4976
# Epoch 042 | TrainLoss 22.0018 | RMSE 1.5606 | R2 0.2866
# Epoch 043 | TrainLoss 38.4946 | RMSE 1.2102 | R2 0.5710
# Epoch 044 | TrainLoss 20.5555 | RMSE 1.6060 | R2 0.2445
# Epoch 045 | TrainLoss 20.2228 | RMSE 1.3237 | R2 0.4867
# Epoch 046 | TrainLoss 34.6994 | RMSE 1.3247 | R2 0.4860
# Epoch 047 | TrainLoss 21.8757 | RMSE 1.4510 | R2 0.3833
# Epoch 048 | TrainLoss 19.1876 | RMSE 1.3945 | R2 0.4304
# Epoch 049 | TrainLoss 20.3943 | RMSE 1.4708 | R2 0.3664
# Epoch 050 | TrainLoss 28.9841 | RMSE 1.3210 | R2 0.4888
# Epoch 051 | TrainLoss 24.5765 | RMSE 1.4749 | R2 0.3628
# Epoch 052 | TrainLoss 15.3358 | RMSE 1.2461 | R2 0.5452
# Epoch 053 | TrainLoss 16.0230 | RMSE 1.5673 | R2 0.2804
# Epoch 054 | TrainLoss 17.4892 | RMSE 1.5515 | R2 0.2949
# Epoch 055 | TrainLoss 13.7898 | RMSE 1.4214 | R2 0.4082
# Epoch 056 | TrainLoss 18.7242 | RMSE 1.5622 | R2 0.2852
# Epoch 057 | TrainLoss 15.4460 | RMSE 1.4958 | R2 0.3446
# Epoch 058 | TrainLoss 15.3493 | RMSE 1.6705 | R2 0.1825
# Epoch 059 | TrainLoss 27.2433 | RMSE 0.9692 | R2 0.7249
# Epoch 060 | TrainLoss 32.7257 | RMSE 0.9681 | R2 0.7255
# Epoch 061 | TrainLoss 18.7539 | RMSE 1.6890 | R2 0.1644
# Epoch 062 | TrainLoss 17.7225 | RMSE 1.3065 | R2 0.5000
# Epoch 063 | TrainLoss 14.6672 | RMSE 1.5596 | R2 0.2875
# Epoch 064 | TrainLoss 15.0341 | RMSE 1.2332 | R2 0.5546
# Epoch 065 | TrainLoss 15.5084 | RMSE 1.5534 | R2 0.2932
# Epoch 066 | TrainLoss 12.3963 | RMSE 1.5790 | R2 0.2697
# Epoch 067 | TrainLoss 16.9781 | RMSE 1.1297 | R2 0.6262
# Epoch 068 | TrainLoss 13.8764 | RMSE 1.6261 | R2 0.2255
# Early stopping triggered
#
# [FOLD 1 FINAL]
# MSE : 0.7906
# RMSE: 0.8891
# MAE : 0.5364
# R2  : 0.7684
#
# ==== Full Fold 2 ====
# Epoch 000 | TrainLoss 922.0668 | RMSE 4.4541 | R2 -7.1253
# Epoch 001 | TrainLoss 452.1553 | RMSE 2.7703 | R2 -2.1432
# Epoch 002 | TrainLoss 184.2141 | RMSE 1.5854 | R2 -0.0295
# Epoch 003 | TrainLoss 87.3447 | RMSE 1.1305 | R2 0.4766
# Epoch 004 | TrainLoss 64.8918 | RMSE 1.1026 | R2 0.5021
# Epoch 005 | TrainLoss 64.8790 | RMSE 1.2394 | R2 0.3708
# Epoch 006 | TrainLoss 60.5512 | RMSE 1.0807 | R2 0.5217
# Epoch 007 | TrainLoss 59.8373 | RMSE 1.1471 | R2 0.4611
# Epoch 008 | TrainLoss 62.4492 | RMSE 1.0012 | R2 0.5894
# Epoch 009 | TrainLoss 64.8203 | RMSE 0.9756 | R2 0.6102
# Epoch 010 | TrainLoss 58.4897 | RMSE 1.0402 | R2 0.5569
# Epoch 011 | TrainLoss 56.5221 | RMSE 0.9373 | R2 0.6402
# Epoch 012 | TrainLoss 57.3200 | RMSE 0.9651 | R2 0.6185
# Epoch 013 | TrainLoss 57.9784 | RMSE 1.0018 | R2 0.5890
# Epoch 014 | TrainLoss 56.3017 | RMSE 1.0283 | R2 0.5669
# Epoch 015 | TrainLoss 54.2860 | RMSE 0.9424 | R2 0.6362
# Epoch 016 | TrainLoss 50.7872 | RMSE 0.8695 | R2 0.6903
# Epoch 017 | TrainLoss 51.3611 | RMSE 1.0416 | R2 0.5556
# Epoch 018 | TrainLoss 55.5277 | RMSE 1.3859 | R2 0.2133
# Epoch 019 | TrainLoss 51.1258 | RMSE 0.9371 | R2 0.6403
# Epoch 020 | TrainLoss 42.2633 | RMSE 0.9619 | R2 0.6211
# Epoch 021 | TrainLoss 39.1440 | RMSE 1.0553 | R2 0.5438
# Epoch 022 | TrainLoss 46.3726 | RMSE 1.1450 | R2 0.4631
# Epoch 023 | TrainLoss 36.5618 | RMSE 1.3565 | R2 0.2464
# Epoch 024 | TrainLoss 38.2148 | RMSE 1.2582 | R2 0.3516
# Epoch 025 | TrainLoss 34.2246 | RMSE 1.2541 | R2 0.3559
# Epoch 026 | TrainLoss 34.1314 | RMSE 1.3522 | R2 0.2511
# Epoch 027 | TrainLoss 35.8581 | RMSE 1.3338 | R2 0.2714
# Epoch 028 | TrainLoss 35.0272 | RMSE 1.1412 | R2 0.4666
# Epoch 029 | TrainLoss 35.1199 | RMSE 0.9169 | R2 0.6557
# Epoch 030 | TrainLoss 29.9563 | RMSE 1.3088 | R2 0.2984
# Epoch 031 | TrainLoss 31.5921 | RMSE 0.9636 | R2 0.6197
# Epoch 032 | TrainLoss 37.1576 | RMSE 0.9465 | R2 0.6331
# Epoch 033 | TrainLoss 30.3868 | RMSE 1.2374 | R2 0.3729
# Epoch 034 | TrainLoss 28.0489 | RMSE 1.1703 | R2 0.4391
# Epoch 035 | TrainLoss 29.3263 | RMSE 1.6192 | R2 -0.0738
# Epoch 036 | TrainLoss 30.4781 | RMSE 1.2324 | R2 0.3779
# Epoch 037 | TrainLoss 26.7058 | RMSE 1.3205 | R2 0.2858
# Epoch 038 | TrainLoss 25.4043 | RMSE 1.1150 | R2 0.4908
# Epoch 039 | TrainLoss 26.8465 | RMSE 1.4835 | R2 0.0987
# Epoch 040 | TrainLoss 22.9862 | RMSE 1.3816 | R2 0.2182
# Epoch 041 | TrainLoss 28.2268 | RMSE 1.4976 | R2 0.0814
# Epoch 042 | TrainLoss 40.9402 | RMSE 0.9468 | R2 0.6328
# Epoch 043 | TrainLoss 33.4481 | RMSE 1.1718 | R2 0.4376
# Epoch 044 | TrainLoss 28.3381 | RMSE 1.4797 | R2 0.1032
# Epoch 045 | TrainLoss 30.8786 | RMSE 1.1945 | R2 0.4156
# Epoch 046 | TrainLoss 25.6099 | RMSE 1.1492 | R2 0.4591
# Epoch 047 | TrainLoss 25.6750 | RMSE 1.2401 | R2 0.3702
# Epoch 048 | TrainLoss 29.3969 | RMSE 1.0606 | R2 0.5393
# Epoch 049 | TrainLoss 27.3734 | RMSE 1.3525 | R2 0.2508
# Epoch 050 | TrainLoss 25.1752 | RMSE 1.1652 | R2 0.4439
# Epoch 051 | TrainLoss 28.8936 | RMSE 1.1452 | R2 0.4628
# Epoch 052 | TrainLoss 20.5540 | RMSE 1.3024 | R2 0.3052
# Epoch 053 | TrainLoss 24.7802 | RMSE 1.3176 | R2 0.2890
# Epoch 054 | TrainLoss 23.6494 | RMSE 1.3992 | R2 0.1982
# Epoch 055 | TrainLoss 20.0083 | RMSE 1.2496 | R2 0.3604
# Epoch 056 | TrainLoss 23.5466 | RMSE 0.8505 | R2 0.7037
# Epoch 057 | TrainLoss 22.7472 | RMSE 1.4360 | R2 0.1555
# Epoch 058 | TrainLoss 20.5117 | RMSE 1.1993 | R2 0.4109
# Epoch 059 | TrainLoss 22.9156 | RMSE 1.1737 | R2 0.4358
# Epoch 060 | TrainLoss 20.2504 | RMSE 0.8705 | R2 0.6896
# Epoch 061 | TrainLoss 24.1542 | RMSE 1.2370 | R2 0.3733
# Epoch 062 | TrainLoss 17.6179 | RMSE 1.4432 | R2 0.1469
# Epoch 063 | TrainLoss 26.4004 | RMSE 1.3614 | R2 0.2409
# Epoch 064 | TrainLoss 17.6899 | RMSE 1.2669 | R2 0.3426
# Epoch 065 | TrainLoss 17.8821 | RMSE 1.0413 | R2 0.5559
# Epoch 066 | TrainLoss 16.5549 | RMSE 1.1687 | R2 0.4406
# Epoch 067 | TrainLoss 17.5008 | RMSE 1.2684 | R2 0.3411
# Epoch 068 | TrainLoss 18.3306 | RMSE 1.1964 | R2 0.4138
# Epoch 069 | TrainLoss 18.5618 | RMSE 1.2845 | R2 0.3242
# Epoch 070 | TrainLoss 21.4639 | RMSE 1.4222 | R2 0.1716
# Epoch 071 | TrainLoss 18.2020 | RMSE 1.1948 | R2 0.4153
# Epoch 072 | TrainLoss 20.6628 | RMSE 1.4190 | R2 0.1753
# Epoch 073 | TrainLoss 17.9171 | RMSE 1.4582 | R2 0.1292
# Epoch 074 | TrainLoss 15.6287 | RMSE 1.3050 | R2 0.3025
# Epoch 075 | TrainLoss 21.9881 | RMSE 1.1028 | R2 0.5019
# Epoch 076 | TrainLoss 16.0706 | RMSE 1.3537 | R2 0.2494
# Epoch 077 | TrainLoss 16.0149 | RMSE 1.1635 | R2 0.4455
# Epoch 078 | TrainLoss 29.7511 | RMSE 1.1130 | R2 0.4926
# Epoch 079 | TrainLoss 25.0915 | RMSE 1.0370 | R2 0.5595
# Epoch 080 | TrainLoss 18.4826 | RMSE 1.0956 | R2 0.5084
# Epoch 081 | TrainLoss 19.2202 | RMSE 1.0026 | R2 0.5883
# Epoch 082 | TrainLoss 16.9827 | RMSE 1.4759 | R2 0.1078
# Epoch 083 | TrainLoss 17.1548 | RMSE 1.5205 | R2 0.0531
# Epoch 084 | TrainLoss 15.7463 | RMSE 1.3432 | R2 0.2611
# Epoch 085 | TrainLoss 18.2022 | RMSE 1.2730 | R2 0.3363
# Epoch 086 | TrainLoss 22.9177 | RMSE 1.2540 | R2 0.3560
# Epoch 087 | TrainLoss 18.6476 | RMSE 1.4138 | R2 0.1814
# Epoch 088 | TrainLoss 21.6818 | RMSE 1.4315 | R2 0.1607
# Epoch 089 | TrainLoss 17.0817 | RMSE 1.0271 | R2 0.5680
# Epoch 090 | TrainLoss 20.9485 | RMSE 1.2615 | R2 0.3483
# Epoch 091 | TrainLoss 14.6669 | RMSE 1.1927 | R2 0.4174
# Epoch 092 | TrainLoss 14.4484 | RMSE 1.2455 | R2 0.3646
# Epoch 093 | TrainLoss 15.7294 | RMSE 1.4617 | R2 0.1249
# Epoch 094 | TrainLoss 14.7524 | RMSE 1.4029 | R2 0.1939
# Epoch 095 | TrainLoss 16.0950 | RMSE 1.1427 | R2 0.4652
# Epoch 096 | TrainLoss 21.1742 | RMSE 1.2407 | R2 0.3695
# Epoch 097 | TrainLoss 16.2411 | RMSE 1.1469 | R2 0.4612
# Epoch 098 | TrainLoss 15.0845 | RMSE 1.4586 | R2 0.1287
# Epoch 099 | TrainLoss 14.7488 | RMSE 1.2281 | R2 0.3823
# Epoch 100 | TrainLoss 15.8908 | RMSE 0.9146 | R2 0.6574
# Epoch 101 | TrainLoss 18.6896 | RMSE 1.2182 | R2 0.3922
# Epoch 102 | TrainLoss 14.2987 | RMSE 1.3269 | R2 0.2789
# Epoch 103 | TrainLoss 13.7759 | RMSE 1.4861 | R2 0.0955
# Epoch 104 | TrainLoss 16.0024 | RMSE 1.2440 | R2 0.3662
# Epoch 105 | TrainLoss 16.5282 | RMSE 1.2975 | R2 0.3104
# Epoch 106 | TrainLoss 18.6909 | RMSE 1.0720 | R2 0.5293
# Early stopping triggered
#
# [FOLD 2 FINAL]
# MSE : 0.7234
# RMSE: 0.8505
# MAE : 0.6368
# R2  : 0.7037
#
# ==== Full Fold 3 ====
# Epoch 000 | TrainLoss 998.6771 | RMSE 5.5712 | R2 -7.9854
# Epoch 001 | TrainLoss 566.9862 | RMSE 4.2110 | R2 -4.1336
# Epoch 002 | TrainLoss 278.1180 | RMSE 2.8767 | R2 -1.3957
# Epoch 003 | TrainLoss 119.9691 | RMSE 1.9314 | R2 -0.0799
# Epoch 004 | TrainLoss 66.4089 | RMSE 1.4492 | R2 0.3920
# Epoch 005 | TrainLoss 58.6453 | RMSE 1.4650 | R2 0.3787
# Epoch 006 | TrainLoss 55.0394 | RMSE 1.4345 | R2 0.4043
# Epoch 007 | TrainLoss 53.0260 | RMSE 1.4224 | R2 0.4143
# Epoch 008 | TrainLoss 51.3919 | RMSE 1.6613 | R2 0.2010
# Epoch 009 | TrainLoss 51.7731 | RMSE 1.3261 | R2 0.4909
# Epoch 010 | TrainLoss 48.3704 | RMSE 1.7484 | R2 0.1151
# Epoch 011 | TrainLoss 48.2759 | RMSE 1.2899 | R2 0.5183
# Epoch 012 | TrainLoss 47.0077 | RMSE 1.3476 | R2 0.4743
# Epoch 013 | TrainLoss 46.3522 | RMSE 1.4961 | R2 0.3520
# Epoch 014 | TrainLoss 43.8030 | RMSE 1.4698 | R2 0.3746
# Epoch 015 | TrainLoss 42.2269 | RMSE 1.1872 | R2 0.5920
# Epoch 016 | TrainLoss 48.6282 | RMSE 1.8480 | R2 0.0113
# Epoch 017 | TrainLoss 39.6607 | RMSE 1.9424 | R2 -0.0922
# Epoch 018 | TrainLoss 38.9203 | RMSE 1.5305 | R2 0.3219
# Epoch 019 | TrainLoss 33.8900 | RMSE 1.2938 | R2 0.5154
# Epoch 020 | TrainLoss 34.0983 | RMSE 1.2371 | R2 0.5569
# Epoch 021 | TrainLoss 31.7203 | RMSE 1.3843 | R2 0.4452
# Epoch 022 | TrainLoss 31.8112 | RMSE 1.6083 | R2 0.2512
# Epoch 023 | TrainLoss 34.7958 | RMSE 2.0622 | R2 -0.2311
# Epoch 024 | TrainLoss 36.1542 | RMSE 1.4939 | R2 0.3539
# Epoch 025 | TrainLoss 33.7959 | RMSE 1.1720 | R2 0.6024
# Epoch 026 | TrainLoss 34.2761 | RMSE 1.4664 | R2 0.3775
# Epoch 027 | TrainLoss 30.8213 | RMSE 1.2387 | R2 0.5558
# Epoch 028 | TrainLoss 30.2724 | RMSE 1.2958 | R2 0.5139
# Epoch 029 | TrainLoss 28.7975 | RMSE 1.4104 | R2 0.4241
# Epoch 030 | TrainLoss 26.3235 | RMSE 1.1767 | R2 0.5991
# Epoch 031 | TrainLoss 27.9683 | RMSE 1.2806 | R2 0.5252
# Epoch 032 | TrainLoss 27.6302 | RMSE 1.3169 | R2 0.4980
# Epoch 033 | TrainLoss 23.0943 | RMSE 1.1889 | R2 0.5908
# Epoch 034 | TrainLoss 29.2490 | RMSE 1.1465 | R2 0.6194
# Epoch 035 | TrainLoss 31.9397 | RMSE 1.1707 | R2 0.6032
# Epoch 036 | TrainLoss 29.6107 | RMSE 1.1649 | R2 0.6072
# Epoch 037 | TrainLoss 26.0069 | RMSE 1.1381 | R2 0.6250
# Epoch 038 | TrainLoss 22.4723 | RMSE 1.2759 | R2 0.5287
# Epoch 039 | TrainLoss 23.4960 | RMSE 1.2454 | R2 0.5510
# Epoch 040 | TrainLoss 19.8285 | RMSE 1.1912 | R2 0.5892
# Epoch 041 | TrainLoss 21.0276 | RMSE 1.0923 | R2 0.6546
# Epoch 042 | TrainLoss 17.0422 | RMSE 1.0661 | R2 0.6710
# Epoch 043 | TrainLoss 17.6028 | RMSE 1.1103 | R2 0.6431
# Epoch 044 | TrainLoss 27.1750 | RMSE 1.0208 | R2 0.6983
# Epoch 045 | TrainLoss 21.9961 | RMSE 1.1110 | R2 0.6427
# Epoch 046 | TrainLoss 17.6760 | RMSE 1.1893 | R2 0.5905
# Epoch 047 | TrainLoss 18.9014 | RMSE 1.1468 | R2 0.6193
# Epoch 048 | TrainLoss 19.1019 | RMSE 1.2336 | R2 0.5594
# Epoch 049 | TrainLoss 18.8810 | RMSE 1.0834 | R2 0.6602
# Epoch 050 | TrainLoss 16.7272 | RMSE 1.0898 | R2 0.6562
# Epoch 051 | TrainLoss 26.8907 | RMSE 1.0490 | R2 0.6814
# Epoch 052 | TrainLoss 30.8091 | RMSE 1.3173 | R2 0.4977
# Epoch 053 | TrainLoss 24.3923 | RMSE 1.1608 | R2 0.6099
# Epoch 054 | TrainLoss 19.8992 | RMSE 1.1463 | R2 0.6196
# Epoch 055 | TrainLoss 17.0873 | RMSE 1.1328 | R2 0.6285
# Epoch 056 | TrainLoss 23.4714 | RMSE 1.1210 | R2 0.6362
# Epoch 057 | TrainLoss 18.4671 | RMSE 1.2014 | R2 0.5822
# Epoch 058 | TrainLoss 14.9851 | RMSE 1.3592 | R2 0.4652
# Epoch 059 | TrainLoss 18.3415 | RMSE 1.1500 | R2 0.6172
# Epoch 060 | TrainLoss 15.8483 | RMSE 1.3752 | R2 0.4525
# Epoch 061 | TrainLoss 18.5476 | RMSE 1.3472 | R2 0.4746
# Epoch 062 | TrainLoss 12.8437 | RMSE 1.3779 | R2 0.4504
# Epoch 063 | TrainLoss 15.9183 | RMSE 1.1698 | R2 0.6038
# Epoch 064 | TrainLoss 16.8160 | RMSE 1.3440 | R2 0.4771
# Epoch 065 | TrainLoss 14.2647 | RMSE 1.3284 | R2 0.4891
# Epoch 066 | TrainLoss 17.0019 | RMSE 1.3965 | R2 0.4354
# Epoch 067 | TrainLoss 15.6833 | RMSE 1.3642 | R2 0.4613
# Epoch 068 | TrainLoss 11.5238 | RMSE 1.2382 | R2 0.5562
# Epoch 069 | TrainLoss 12.5588 | RMSE 1.3630 | R2 0.4622
# Epoch 070 | TrainLoss 10.6891 | RMSE 1.3165 | R2 0.4983
# Epoch 071 | TrainLoss 12.5558 | RMSE 1.2954 | R2 0.5142
# Epoch 072 | TrainLoss 13.4341 | RMSE 1.6265 | R2 0.2341
# Epoch 073 | TrainLoss 11.3096 | RMSE 1.4576 | R2 0.3849
# Epoch 074 | TrainLoss 12.0299 | RMSE 1.3350 | R2 0.4840
# Epoch 075 | TrainLoss 10.1565 | RMSE 1.3064 | R2 0.5059
# Epoch 076 | TrainLoss 13.6205 | RMSE 1.3783 | R2 0.4500
# Epoch 077 | TrainLoss 11.7153 | RMSE 1.3748 | R2 0.4528
# Epoch 078 | TrainLoss 12.3122 | RMSE 1.5015 | R2 0.3474
# Epoch 079 | TrainLoss 15.6217 | RMSE 1.3823 | R2 0.4469
# Epoch 080 | TrainLoss 12.0737 | RMSE 1.5139 | R2 0.3365
# Epoch 081 | TrainLoss 11.7478 | RMSE 1.4686 | R2 0.3756
# Epoch 082 | TrainLoss 9.4915 | RMSE 1.4698 | R2 0.3746
# Epoch 083 | TrainLoss 9.3652 | RMSE 1.4680 | R2 0.3761
# Epoch 084 | TrainLoss 14.0993 | RMSE 1.3366 | R2 0.4828
# Epoch 085 | TrainLoss 11.1565 | RMSE 1.5265 | R2 0.3254
# Epoch 086 | TrainLoss 9.4813 | RMSE 1.3679 | R2 0.4583
# Epoch 087 | TrainLoss 11.3291 | RMSE 1.4180 | R2 0.4179
# Epoch 088 | TrainLoss 12.8327 | RMSE 1.4610 | R2 0.3821
# Epoch 089 | TrainLoss 11.5130 | RMSE 1.5425 | R2 0.3112
# Epoch 090 | TrainLoss 16.1408 | RMSE 1.4537 | R2 0.3883
# Epoch 091 | TrainLoss 11.0386 | RMSE 1.5508 | R2 0.3038
# Epoch 092 | TrainLoss 9.0035 | RMSE 1.4919 | R2 0.3557
# Epoch 093 | TrainLoss 8.5634 | RMSE 1.4984 | R2 0.3500
# Epoch 094 | TrainLoss 8.5738 | RMSE 1.4817 | R2 0.3644
# Early stopping triggered
#
# [FOLD 3 FINAL]
# MSE : 1.0421
# RMSE: 1.0208
# MAE : 0.7166
# R2  : 0.6983
#
# ==== Full Fold 4 ====
# Epoch 000 | TrainLoss 1105.0445 | RMSE 5.4231 | R2 -6.2509
# Epoch 001 | TrainLoss 679.1344 | RMSE 4.1127 | R2 -3.1701
# Epoch 002 | TrainLoss 345.7378 | RMSE 2.7482 | R2 -0.8621
# Epoch 003 | TrainLoss 143.6002 | RMSE 1.7917 | R2 0.2086
# Epoch 004 | TrainLoss 72.4687 | RMSE 1.3292 | R2 0.5644
# Epoch 005 | TrainLoss 57.7276 | RMSE 1.5332 | R2 0.4204
# Epoch 006 | TrainLoss 53.9208 | RMSE 1.4690 | R2 0.4680
# Epoch 007 | TrainLoss 47.8214 | RMSE 1.5294 | R2 0.4233
# Epoch 008 | TrainLoss 50.2876 | RMSE 1.2878 | R2 0.5911
# Epoch 009 | TrainLoss 47.2603 | RMSE 1.6945 | R2 0.2921
# Epoch 010 | TrainLoss 40.4651 | RMSE 1.6768 | R2 0.3068
# Epoch 011 | TrainLoss 45.9984 | RMSE 1.6511 | R2 0.3279
# Epoch 012 | TrainLoss 35.0026 | RMSE 1.7533 | R2 0.2421
# Epoch 013 | TrainLoss 27.5749 | RMSE 1.4440 | R2 0.4859
# Epoch 014 | TrainLoss 28.0310 | RMSE 1.4796 | R2 0.4602
# Epoch 015 | TrainLoss 20.6827 | RMSE 1.8737 | R2 0.1344
# Epoch 016 | TrainLoss 23.1836 | RMSE 2.2566 | R2 -0.2555
# Epoch 017 | TrainLoss 18.3474 | RMSE 2.0661 | R2 -0.0524
# Epoch 018 | TrainLoss 19.8645 | RMSE 1.4829 | R2 0.4579
# Epoch 019 | TrainLoss 19.4103 | RMSE 1.5803 | R2 0.3843
# Epoch 020 | TrainLoss 17.5183 | RMSE 1.9707 | R2 0.0425
# Epoch 021 | TrainLoss 19.1664 | RMSE 1.4361 | R2 0.4915
# Epoch 022 | TrainLoss 17.5317 | RMSE 1.1756 | R2 0.6593
# Epoch 023 | TrainLoss 13.8564 | RMSE 1.5688 | R2 0.3932
# Epoch 024 | TrainLoss 13.3098 | RMSE 1.4990 | R2 0.4460
# Epoch 025 | TrainLoss 13.7487 | RMSE 1.6808 | R2 0.3035
# Epoch 026 | TrainLoss 14.3092 | RMSE 1.2407 | R2 0.6205
# Epoch 027 | TrainLoss 16.9234 | RMSE 1.4490 | R2 0.4823
# Epoch 028 | TrainLoss 13.2638 | RMSE 1.6341 | R2 0.3416
# Epoch 029 | TrainLoss 15.9578 | RMSE 1.2914 | R2 0.5888
# Epoch 030 | TrainLoss 16.1149 | RMSE 2.3139 | R2 -0.3200
# Epoch 031 | TrainLoss 14.9298 | RMSE 2.0332 | R2 -0.0191
# Epoch 032 | TrainLoss 13.4488 | RMSE 2.3216 | R2 -0.3288
# Epoch 033 | TrainLoss 14.4527 | RMSE 2.0529 | R2 -0.0390
# Epoch 034 | TrainLoss 13.6555 | RMSE 1.5238 | R2 0.4276
# Epoch 035 | TrainLoss 14.1761 | RMSE 1.8428 | R2 0.1628
# Epoch 036 | TrainLoss 13.1435 | RMSE 1.7403 | R2 0.2533
# Epoch 037 | TrainLoss 11.4074 | RMSE 1.6365 | R2 0.3397
# Epoch 038 | TrainLoss 13.9910 | RMSE 2.1813 | R2 -0.1731
# Epoch 039 | TrainLoss 14.3854 | RMSE 1.7087 | R2 0.2802
# Epoch 040 | TrainLoss 10.9486 | RMSE 1.6025 | R2 0.3669
# Epoch 041 | TrainLoss 11.0020 | RMSE 1.8842 | R2 0.1247
# Epoch 042 | TrainLoss 11.6938 | RMSE 1.0986 | R2 0.7024
# Epoch 043 | TrainLoss 14.0208 | RMSE 1.7241 | R2 0.2671
# Epoch 044 | TrainLoss 12.2931 | RMSE 1.2785 | R2 0.5970
# Epoch 045 | TrainLoss 10.0906 | RMSE 1.1752 | R2 0.6595
# Epoch 046 | TrainLoss 10.7106 | RMSE 1.7501 | R2 0.2448
# Epoch 047 | TrainLoss 9.2794 | RMSE 1.7886 | R2 0.2113
# Epoch 048 | TrainLoss 9.5677 | RMSE 2.1683 | R2 -0.1591
# Epoch 049 | TrainLoss 8.7014 | RMSE 1.6817 | R2 0.3028
# Epoch 050 | TrainLoss 9.3745 | RMSE 2.0152 | R2 -0.0012
# Epoch 051 | TrainLoss 11.8495 | RMSE 1.5975 | R2 0.3708
# Epoch 052 | TrainLoss 9.9160 | RMSE 1.9178 | R2 0.0933
# Epoch 053 | TrainLoss 8.4801 | RMSE 1.6933 | R2 0.2931
# Epoch 054 | TrainLoss 8.6187 | RMSE 1.4890 | R2 0.4534
# Epoch 055 | TrainLoss 9.0537 | RMSE 1.4447 | R2 0.4854
# Epoch 056 | TrainLoss 10.0319 | RMSE 1.5011 | R2 0.4445
# Epoch 057 | TrainLoss 9.4938 | RMSE 1.9568 | R2 0.0560
# Epoch 058 | TrainLoss 10.4311 | RMSE 2.0470 | R2 -0.0330
# Epoch 059 | TrainLoss 11.7059 | RMSE 2.1910 | R2 -0.1835
# Epoch 060 | TrainLoss 10.6602 | RMSE 1.7513 | R2 0.2438
# Epoch 061 | TrainLoss 8.7866 | RMSE 1.4372 | R2 0.4908
# Epoch 062 | TrainLoss 10.6048 | RMSE 1.3121 | R2 0.5756
# Epoch 063 | TrainLoss 9.9699 | RMSE 1.8544 | R2 0.1522
# Epoch 064 | TrainLoss 10.2565 | RMSE 1.6797 | R2 0.3044
# Epoch 065 | TrainLoss 9.3902 | RMSE 2.0470 | R2 -0.0331
# Epoch 066 | TrainLoss 8.8362 | RMSE 1.9371 | R2 0.0749
# Epoch 067 | TrainLoss 13.3382 | RMSE 1.0161 | R2 0.7454
# Epoch 068 | TrainLoss 13.1714 | RMSE 1.6225 | R2 0.3510
# Epoch 069 | TrainLoss 9.8652 | RMSE 1.8906 | R2 0.1188
# Epoch 070 | TrainLoss 7.9306 | RMSE 1.2067 | R2 0.6410
# Epoch 071 | TrainLoss 7.8332 | RMSE 1.5596 | R2 0.4004
# Epoch 072 | TrainLoss 10.9090 | RMSE 1.2918 | R2 0.5886
# Epoch 073 | TrainLoss 10.9746 | RMSE 2.0726 | R2 -0.0590
# Epoch 074 | TrainLoss 9.8739 | RMSE 1.6511 | R2 0.3279
# Epoch 075 | TrainLoss 8.7300 | RMSE 1.7370 | R2 0.2562
# Epoch 076 | TrainLoss 9.6124 | RMSE 1.7546 | R2 0.2410
# Epoch 077 | TrainLoss 8.5937 | RMSE 1.5169 | R2 0.4327
# Epoch 078 | TrainLoss 8.6377 | RMSE 1.5142 | R2 0.4347
# Epoch 079 | TrainLoss 7.5230 | RMSE 1.7869 | R2 0.2128
# Epoch 080 | TrainLoss 7.5039 | RMSE 1.5108 | R2 0.4373
# Epoch 081 | TrainLoss 7.9471 | RMSE 1.7394 | R2 0.2541
# Epoch 082 | TrainLoss 7.1316 | RMSE 1.6673 | R2 0.3147
# Epoch 083 | TrainLoss 7.9313 | RMSE 1.9003 | R2 0.1097
# Epoch 084 | TrainLoss 6.6909 | RMSE 1.7670 | R2 0.2302
# Epoch 085 | TrainLoss 6.7149 | RMSE 1.4608 | R2 0.4739
# Epoch 086 | TrainLoss 8.2206 | RMSE 1.7305 | R2 0.2617
# Epoch 087 | TrainLoss 6.2731 | RMSE 1.6960 | R2 0.2909
# Epoch 088 | TrainLoss 5.9961 | RMSE 1.7263 | R2 0.2653
# Epoch 089 | TrainLoss 6.4067 | RMSE 1.9449 | R2 0.0674
# Epoch 090 | TrainLoss 7.1653 | RMSE 1.5647 | R2 0.3964
# Epoch 091 | TrainLoss 6.8191 | RMSE 2.0845 | R2 -0.0713
# Epoch 092 | TrainLoss 6.8535 | RMSE 1.9444 | R2 0.0679
# Epoch 093 | TrainLoss 6.0740 | RMSE 1.8144 | R2 0.1884
# Epoch 094 | TrainLoss 5.4686 | RMSE 1.7456 | R2 0.2487
# Epoch 095 | TrainLoss 6.7933 | RMSE 1.8789 | R2 0.1297
# Epoch 096 | TrainLoss 7.5491 | RMSE 1.4919 | R2 0.4513
# Epoch 097 | TrainLoss 7.2669 | RMSE 1.3931 | R2 0.5215
# Epoch 098 | TrainLoss 6.1716 | RMSE 1.9952 | R2 0.0185
# Epoch 099 | TrainLoss 5.4859 | RMSE 1.6089 | R2 0.3618
# Epoch 100 | TrainLoss 5.1228 | RMSE 1.9179 | R2 0.0932
# Epoch 101 | TrainLoss 5.3672 | RMSE 1.7719 | R2 0.2260
# Epoch 102 | TrainLoss 8.0447 | RMSE 1.9985 | R2 0.0153
# Epoch 103 | TrainLoss 8.0815 | RMSE 1.6419 | R2 0.3353
# Epoch 104 | TrainLoss 7.3643 | RMSE 1.6851 | R2 0.2999
# Epoch 105 | TrainLoss 8.1734 | RMSE 1.3787 | R2 0.5313
# Epoch 106 | TrainLoss 7.6410 | RMSE 2.6031 | R2 -0.6705
# Epoch 107 | TrainLoss 8.9718 | RMSE 1.5603 | R2 0.3998
# Epoch 108 | TrainLoss 6.2631 | RMSE 1.8164 | R2 0.1866
# Epoch 109 | TrainLoss 7.4151 | RMSE 1.6669 | R2 0.3150
# Epoch 110 | TrainLoss 4.8749 | RMSE 1.7354 | R2 0.2575
# Epoch 111 | TrainLoss 4.9480 | RMSE 2.3548 | R2 -0.3671
# Epoch 112 | TrainLoss 4.9558 | RMSE 1.7671 | R2 0.2301
# Epoch 113 | TrainLoss 7.4737 | RMSE 1.7084 | R2 0.2805
# Epoch 114 | TrainLoss 6.0094 | RMSE 1.7101 | R2 0.2790
# Epoch 115 | TrainLoss 4.9044 | RMSE 1.7392 | R2 0.2543
# Epoch 116 | TrainLoss 4.3217 | RMSE 1.9088 | R2 0.1018
# Epoch 117 | TrainLoss 4.9823 | RMSE 1.5641 | R2 0.3969
# Early stopping triggered
#
# [FOLD 4 FINAL]
# MSE : 1.0325
# RMSE: 1.0161
# MAE : 0.7989
# R2  : 0.7454
#
# ================================================================================
# Full
# ================================================================================
# FINAL 5-FOLD RESULT
# RMSE : 0.9341 ± 0.0706
# MAE  : 0.6587 ± 0.0909
# R2   : 0.7219 ± 0.0297
#
# ================================================================================
# Running Experiment : No_projection
# ================================================================================
#
# ==== No_projection Fold 0 ====
# Epoch 000 | TrainLoss 1149.6978 | RMSE 5.3057 | R2 -9.8086
# Epoch 001 | TrainLoss 735.9421 | RMSE 3.9376 | R2 -4.9532
# Epoch 002 | TrainLoss 378.2732 | RMSE 2.4496 | R2 -1.3041
# Epoch 003 | TrainLoss 155.4334 | RMSE 1.4933 | R2 0.1438
# Epoch 004 | TrainLoss 73.0139 | RMSE 1.3170 | R2 0.3340
# Epoch 005 | TrainLoss 57.7878 | RMSE 1.4880 | R2 0.1499
# Epoch 006 | TrainLoss 54.0236 | RMSE 1.3560 | R2 0.2940
# Epoch 007 | TrainLoss 51.6786 | RMSE 1.3002 | R2 0.3509
# Epoch 008 | TrainLoss 51.2087 | RMSE 1.4018 | R2 0.2455
# Epoch 009 | TrainLoss 52.2139 | RMSE 1.4132 | R2 0.2332
# Epoch 010 | TrainLoss 50.3253 | RMSE 1.2758 | R2 0.3750
# Epoch 011 | TrainLoss 48.4714 | RMSE 1.4761 | R2 0.1634
# Epoch 012 | TrainLoss 48.4644 | RMSE 1.2115 | R2 0.4364
# Epoch 013 | TrainLoss 46.8511 | RMSE 1.2797 | R2 0.3712
# Epoch 014 | TrainLoss 45.7992 | RMSE 1.2334 | R2 0.4159
# Epoch 015 | TrainLoss 45.6114 | RMSE 1.5109 | R2 0.1235
# Epoch 016 | TrainLoss 50.8716 | RMSE 1.2692 | R2 0.3814
# Epoch 017 | TrainLoss 48.0419 | RMSE 1.4236 | R2 0.2218
# Epoch 018 | TrainLoss 37.9589 | RMSE 1.0776 | R2 0.5541
# Epoch 019 | TrainLoss 34.6161 | RMSE 1.3937 | R2 0.2542
# Epoch 020 | TrainLoss 37.4244 | RMSE 1.3005 | R2 0.3506
# Epoch 021 | TrainLoss 31.9240 | RMSE 1.0219 | R2 0.5990
# Epoch 022 | TrainLoss 29.3303 | RMSE 1.1627 | R2 0.4810
# Epoch 023 | TrainLoss 31.1479 | RMSE 1.3320 | R2 0.3188
# Epoch 024 | TrainLoss 31.0200 | RMSE 1.1297 | R2 0.5100
# Epoch 025 | TrainLoss 31.2677 | RMSE 1.2048 | R2 0.4427
# Epoch 026 | TrainLoss 29.5505 | RMSE 1.2271 | R2 0.4218
# Epoch 027 | TrainLoss 26.7004 | RMSE 1.2081 | R2 0.4396
# Epoch 028 | TrainLoss 24.6453 | RMSE 1.1263 | R2 0.5129
# Epoch 029 | TrainLoss 21.8841 | RMSE 1.1055 | R2 0.5307
# Epoch 030 | TrainLoss 31.7215 | RMSE 0.9198 | R2 0.6752
# Epoch 031 | TrainLoss 26.7230 | RMSE 0.9324 | R2 0.6662
# Epoch 032 | TrainLoss 21.2795 | RMSE 1.0559 | R2 0.5719
# Epoch 033 | TrainLoss 27.3529 | RMSE 1.0617 | R2 0.5672
# Epoch 034 | TrainLoss 26.9443 | RMSE 1.2286 | R2 0.4204
# Epoch 035 | TrainLoss 22.4240 | RMSE 1.0200 | R2 0.6006
# Epoch 036 | TrainLoss 23.4241 | RMSE 1.0033 | R2 0.6135
# Epoch 037 | TrainLoss 22.8358 | RMSE 1.0362 | R2 0.5877
# Epoch 038 | TrainLoss 20.5655 | RMSE 0.9978 | R2 0.6177
# Epoch 039 | TrainLoss 18.4030 | RMSE 1.0143 | R2 0.6050
# Epoch 040 | TrainLoss 19.5043 | RMSE 1.1570 | R2 0.4860
# Epoch 041 | TrainLoss 20.1431 | RMSE 1.0048 | R2 0.6123
# Epoch 042 | TrainLoss 19.6621 | RMSE 0.8814 | R2 0.7017
# Epoch 043 | TrainLoss 20.1068 | RMSE 0.9220 | R2 0.6736
# Epoch 044 | TrainLoss 19.7406 | RMSE 0.9155 | R2 0.6782
# Epoch 045 | TrainLoss 21.4120 | RMSE 0.9120 | R2 0.6806
# Epoch 046 | TrainLoss 17.7855 | RMSE 1.0459 | R2 0.5800
# Epoch 047 | TrainLoss 22.1934 | RMSE 0.9754 | R2 0.6347
# Epoch 048 | TrainLoss 21.6224 | RMSE 0.9009 | R2 0.6883
# Epoch 049 | TrainLoss 17.3410 | RMSE 0.9835 | R2 0.6286
# Epoch 050 | TrainLoss 14.7590 | RMSE 1.0222 | R2 0.5988
# Epoch 051 | TrainLoss 21.0296 | RMSE 1.0506 | R2 0.5762
# Epoch 052 | TrainLoss 17.9943 | RMSE 0.9472 | R2 0.6555
# Epoch 053 | TrainLoss 13.4807 | RMSE 0.8688 | R2 0.7101
# Epoch 054 | TrainLoss 15.7469 | RMSE 0.8784 | R2 0.7037
# Epoch 055 | TrainLoss 12.8553 | RMSE 0.9968 | R2 0.6185
# Epoch 056 | TrainLoss 13.2610 | RMSE 1.0626 | R2 0.5665
# Epoch 057 | TrainLoss 10.4891 | RMSE 1.0362 | R2 0.5877
# Epoch 058 | TrainLoss 13.8067 | RMSE 0.8514 | R2 0.7217
# Epoch 059 | TrainLoss 10.6530 | RMSE 0.9978 | R2 0.6177
# Epoch 060 | TrainLoss 12.8127 | RMSE 1.0435 | R2 0.5819
# Epoch 061 | TrainLoss 19.9849 | RMSE 1.1420 | R2 0.4992
# Epoch 062 | TrainLoss 13.0663 | RMSE 0.9998 | R2 0.6162
# Epoch 063 | TrainLoss 11.1633 | RMSE 1.0310 | R2 0.5919
# Epoch 064 | TrainLoss 10.8746 | RMSE 1.0135 | R2 0.6056
# Epoch 065 | TrainLoss 15.8339 | RMSE 0.9638 | R2 0.6433
# Epoch 066 | TrainLoss 14.1676 | RMSE 0.8566 | R2 0.7182
# Epoch 067 | TrainLoss 11.4572 | RMSE 1.0061 | R2 0.6113
# Epoch 068 | TrainLoss 12.6897 | RMSE 0.9016 | R2 0.6879
# Epoch 069 | TrainLoss 10.1103 | RMSE 1.0470 | R2 0.5791
# Epoch 070 | TrainLoss 13.8731 | RMSE 0.8816 | R2 0.7016
# Epoch 071 | TrainLoss 10.7367 | RMSE 0.9129 | R2 0.6800
# Epoch 072 | TrainLoss 12.2030 | RMSE 0.8579 | R2 0.7174
# Epoch 073 | TrainLoss 10.9671 | RMSE 0.9137 | R2 0.6795
# Epoch 074 | TrainLoss 12.4909 | RMSE 1.0767 | R2 0.5549
# Epoch 075 | TrainLoss 8.7218 | RMSE 0.9272 | R2 0.6699
# Epoch 076 | TrainLoss 14.4833 | RMSE 0.8690 | R2 0.7101
# Epoch 077 | TrainLoss 9.8900 | RMSE 0.8664 | R2 0.7118
# Epoch 078 | TrainLoss 9.5455 | RMSE 0.9906 | R2 0.6232
# Epoch 079 | TrainLoss 9.3849 | RMSE 0.9781 | R2 0.6327
# Epoch 080 | TrainLoss 9.4631 | RMSE 0.8735 | R2 0.7071
# Epoch 081 | TrainLoss 7.6085 | RMSE 0.8874 | R2 0.6976
# Epoch 082 | TrainLoss 8.1878 | RMSE 0.9158 | R2 0.6780
# Epoch 083 | TrainLoss 7.3930 | RMSE 0.9448 | R2 0.6573
# Epoch 084 | TrainLoss 10.3701 | RMSE 0.8456 | R2 0.7255
# Epoch 085 | TrainLoss 8.8307 | RMSE 0.9923 | R2 0.6219
# Epoch 086 | TrainLoss 6.4730 | RMSE 0.8979 | R2 0.6905
# Epoch 087 | TrainLoss 7.2427 | RMSE 0.9365 | R2 0.6632
# Epoch 088 | TrainLoss 10.8759 | RMSE 0.9574 | R2 0.6480
# Epoch 089 | TrainLoss 13.0620 | RMSE 0.8379 | R2 0.7305
# Epoch 090 | TrainLoss 11.4050 | RMSE 0.8992 | R2 0.6895
# Epoch 091 | TrainLoss 13.0392 | RMSE 0.9403 | R2 0.6605
# Epoch 092 | TrainLoss 7.0284 | RMSE 0.9440 | R2 0.6578
# Epoch 093 | TrainLoss 7.1008 | RMSE 1.0233 | R2 0.5979
# Epoch 094 | TrainLoss 8.0437 | RMSE 0.9336 | R2 0.6653
# Epoch 095 | TrainLoss 8.3332 | RMSE 1.0392 | R2 0.5853
# Epoch 096 | TrainLoss 8.5361 | RMSE 0.9082 | R2 0.6833
# Epoch 097 | TrainLoss 6.6175 | RMSE 0.9267 | R2 0.6702
# Epoch 098 | TrainLoss 5.5635 | RMSE 0.9007 | R2 0.6885
# Epoch 099 | TrainLoss 7.7882 | RMSE 0.8582 | R2 0.7172
# Epoch 100 | TrainLoss 7.8917 | RMSE 0.9785 | R2 0.6324
# Epoch 101 | TrainLoss 7.9945 | RMSE 0.8709 | R2 0.7088
# Epoch 102 | TrainLoss 14.0351 | RMSE 1.1530 | R2 0.4896
# Epoch 103 | TrainLoss 10.5800 | RMSE 0.8750 | R2 0.7060
# Epoch 104 | TrainLoss 6.5798 | RMSE 0.9596 | R2 0.6464
# Epoch 105 | TrainLoss 5.7161 | RMSE 0.8602 | R2 0.7159
# Epoch 106 | TrainLoss 5.5046 | RMSE 0.8552 | R2 0.7192
# Epoch 107 | TrainLoss 8.8048 | RMSE 0.8928 | R2 0.6939
# Epoch 108 | TrainLoss 8.6743 | RMSE 0.9732 | R2 0.6363
# Epoch 109 | TrainLoss 6.6773 | RMSE 0.9234 | R2 0.6726
# Epoch 110 | TrainLoss 5.8442 | RMSE 0.9974 | R2 0.6180
# Epoch 111 | TrainLoss 10.0780 | RMSE 0.9649 | R2 0.6425
# Epoch 112 | TrainLoss 16.3684 | RMSE 0.9848 | R2 0.6276
# Epoch 113 | TrainLoss 7.7117 | RMSE 0.9025 | R2 0.6872
# Epoch 114 | TrainLoss 6.8107 | RMSE 0.8817 | R2 0.7015
# Epoch 115 | TrainLoss 6.3673 | RMSE 0.9387 | R2 0.6617
# Epoch 116 | TrainLoss 4.9884 | RMSE 0.9276 | R2 0.6696
# Epoch 117 | TrainLoss 5.1888 | RMSE 0.8675 | R2 0.7111
# Epoch 118 | TrainLoss 5.9927 | RMSE 1.0642 | R2 0.5651
# Epoch 119 | TrainLoss 5.4449 | RMSE 0.8766 | R2 0.7049
# Epoch 120 | TrainLoss 6.0954 | RMSE 0.9602 | R2 0.6460
# Epoch 121 | TrainLoss 4.8061 | RMSE 0.9211 | R2 0.6742
# Epoch 122 | TrainLoss 5.1845 | RMSE 0.9815 | R2 0.6301
# Epoch 123 | TrainLoss 5.7011 | RMSE 0.9118 | R2 0.6808
# Epoch 124 | TrainLoss 8.1421 | RMSE 0.9775 | R2 0.6331
# Epoch 125 | TrainLoss 7.9372 | RMSE 1.0075 | R2 0.6103
# Epoch 126 | TrainLoss 24.7165 | RMSE 0.9967 | R2 0.6186
# Epoch 127 | TrainLoss 12.5926 | RMSE 0.8358 | R2 0.7318
# Epoch 128 | TrainLoss 8.6018 | RMSE 0.9413 | R2 0.6598
# Epoch 129 | TrainLoss 13.2782 | RMSE 0.9811 | R2 0.6304
# Epoch 130 | TrainLoss 13.0246 | RMSE 1.0536 | R2 0.5737
# Epoch 131 | TrainLoss 7.5285 | RMSE 0.8816 | R2 0.7015
# Epoch 132 | TrainLoss 6.0019 | RMSE 0.9832 | R2 0.6288
# Epoch 133 | TrainLoss 7.0780 | RMSE 1.0053 | R2 0.6119
# Epoch 134 | TrainLoss 5.6783 | RMSE 0.9111 | R2 0.6813
# Epoch 135 | TrainLoss 4.3323 | RMSE 1.0048 | R2 0.6123
# Epoch 136 | TrainLoss 5.2301 | RMSE 0.8676 | R2 0.7110
# Epoch 137 | TrainLoss 7.2457 | RMSE 0.9927 | R2 0.6216
# Epoch 138 | TrainLoss 15.0751 | RMSE 1.1042 | R2 0.5319
# Epoch 139 | TrainLoss 28.4849 | RMSE 0.9389 | R2 0.6615
# Epoch 140 | TrainLoss 19.7577 | RMSE 0.8411 | R2 0.7284
# Epoch 141 | TrainLoss 16.7954 | RMSE 0.7855 | R2 0.7631
# Epoch 142 | TrainLoss 10.2718 | RMSE 1.0591 | R2 0.5693
# Epoch 143 | TrainLoss 6.7627 | RMSE 1.0097 | R2 0.6086
# Epoch 144 | TrainLoss 7.7601 | RMSE 0.9109 | R2 0.6814
# Epoch 145 | TrainLoss 5.9410 | RMSE 0.9596 | R2 0.6465
# Epoch 146 | TrainLoss 6.1020 | RMSE 0.8939 | R2 0.6932
# Epoch 147 | TrainLoss 5.5366 | RMSE 0.8750 | R2 0.7061
# Epoch 148 | TrainLoss 4.5967 | RMSE 1.0000 | R2 0.6161
# Epoch 149 | TrainLoss 4.7670 | RMSE 0.9934 | R2 0.6211
# Epoch 150 | TrainLoss 5.2733 | RMSE 0.9581 | R2 0.6476
# Epoch 151 | TrainLoss 5.3641 | RMSE 1.0527 | R2 0.5745
# Epoch 152 | TrainLoss 3.4358 | RMSE 0.9917 | R2 0.6224
# Epoch 153 | TrainLoss 4.5233 | RMSE 0.9576 | R2 0.6479
# Epoch 154 | TrainLoss 5.3163 | RMSE 1.0469 | R2 0.5792
# Epoch 155 | TrainLoss 9.3382 | RMSE 0.9756 | R2 0.6345
# Epoch 156 | TrainLoss 5.8878 | RMSE 0.9356 | R2 0.6639
# Epoch 157 | TrainLoss 4.9949 | RMSE 0.8733 | R2 0.7071
# Epoch 158 | TrainLoss 7.6194 | RMSE 1.0246 | R2 0.5969
# Epoch 159 | TrainLoss 4.6068 | RMSE 0.9754 | R2 0.6347
# Epoch 160 | TrainLoss 3.7660 | RMSE 0.9498 | R2 0.6536
# Epoch 161 | TrainLoss 3.6324 | RMSE 0.9756 | R2 0.6346
# Epoch 162 | TrainLoss 3.5430 | RMSE 0.9880 | R2 0.6252
# Epoch 163 | TrainLoss 3.0901 | RMSE 0.9398 | R2 0.6608
# Epoch 164 | TrainLoss 2.5769 | RMSE 0.9797 | R2 0.6315
# Epoch 165 | TrainLoss 2.8404 | RMSE 0.9831 | R2 0.6289
# Epoch 166 | TrainLoss 3.0975 | RMSE 0.9731 | R2 0.6364
# Epoch 167 | TrainLoss 4.7641 | RMSE 1.0291 | R2 0.5934
# Epoch 168 | TrainLoss 3.2393 | RMSE 0.9432 | R2 0.6584
# Epoch 169 | TrainLoss 6.2233 | RMSE 1.0106 | R2 0.6079
# Epoch 170 | TrainLoss 4.0789 | RMSE 0.8811 | R2 0.7019
# Epoch 171 | TrainLoss 3.8746 | RMSE 0.8784 | R2 0.7037
# Epoch 172 | TrainLoss 7.2095 | RMSE 0.9841 | R2 0.6282
# Epoch 173 | TrainLoss 8.4009 | RMSE 0.9335 | R2 0.6654
# Epoch 174 | TrainLoss 5.3917 | RMSE 1.0032 | R2 0.6136
# Epoch 175 | TrainLoss 4.8775 | RMSE 0.9748 | R2 0.6351
# Epoch 176 | TrainLoss 4.2902 | RMSE 0.9564 | R2 0.6488
# Epoch 177 | TrainLoss 3.5979 | RMSE 0.9023 | R2 0.6874
# Epoch 178 | TrainLoss 3.4471 | RMSE 0.8764 | R2 0.7051
# Epoch 179 | TrainLoss 8.3225 | RMSE 0.9630 | R2 0.6439
# Epoch 180 | TrainLoss 5.1529 | RMSE 0.9369 | R2 0.6629
# Epoch 181 | TrainLoss 5.9964 | RMSE 0.8702 | R2 0.7092
# Epoch 182 | TrainLoss 4.3008 | RMSE 0.9618 | R2 0.6448
# Epoch 183 | TrainLoss 2.9702 | RMSE 1.0055 | R2 0.6118
# Epoch 184 | TrainLoss 2.6987 | RMSE 0.8571 | R2 0.7180
# Epoch 185 | TrainLoss 3.0109 | RMSE 1.0162 | R2 0.6035
# Epoch 186 | TrainLoss 3.0950 | RMSE 0.9299 | R2 0.6680
# Epoch 187 | TrainLoss 5.2579 | RMSE 0.9883 | R2 0.6250
# Epoch 188 | TrainLoss 14.5845 | RMSE 1.0359 | R2 0.5880
# Epoch 189 | TrainLoss 15.3313 | RMSE 1.0353 | R2 0.5885
# Epoch 190 | TrainLoss 5.4244 | RMSE 0.9256 | R2 0.6711
# Epoch 191 | TrainLoss 4.5830 | RMSE 0.9295 | R2 0.6682
# Early stopping triggered
#
# [FOLD 0 FINAL]
# MSE : 0.6170
# RMSE: 0.7855
# MAE : 0.4619
# R2  : 0.7631
#
# ==== No_projection Fold 1 ====
# Epoch 000 | TrainLoss 1169.0972 | RMSE 5.4156 | R2 -7.5910
# Epoch 001 | TrainLoss 757.0473 | RMSE 4.2185 | R2 -4.2126
# Epoch 002 | TrainLoss 425.1527 | RMSE 2.9150 | R2 -1.4890
# Epoch 003 | TrainLoss 197.5028 | RMSE 1.8948 | R2 -0.0516
# Epoch 004 | TrainLoss 89.8064 | RMSE 1.3240 | R2 0.4865
# Epoch 005 | TrainLoss 65.9410 | RMSE 1.3892 | R2 0.4347
# Epoch 006 | TrainLoss 57.6800 | RMSE 1.1809 | R2 0.5915
# Epoch 007 | TrainLoss 59.1633 | RMSE 1.2096 | R2 0.5714
# Epoch 008 | TrainLoss 51.9906 | RMSE 1.3730 | R2 0.4478
# Epoch 009 | TrainLoss 50.9780 | RMSE 1.3505 | R2 0.4658
# Epoch 010 | TrainLoss 49.4534 | RMSE 1.3054 | R2 0.5008
# Epoch 011 | TrainLoss 49.8033 | RMSE 1.1123 | R2 0.6376
# Epoch 012 | TrainLoss 48.7066 | RMSE 1.3104 | R2 0.4970
# Epoch 013 | TrainLoss 48.0386 | RMSE 1.2249 | R2 0.5605
# Epoch 014 | TrainLoss 49.1440 | RMSE 1.1145 | R2 0.6362
# Epoch 015 | TrainLoss 45.2268 | RMSE 1.2043 | R2 0.5752
# Epoch 016 | TrainLoss 47.4743 | RMSE 1.3728 | R2 0.4480
# Epoch 017 | TrainLoss 42.6859 | RMSE 1.5445 | R2 0.3012
# Epoch 018 | TrainLoss 39.8704 | RMSE 1.1327 | R2 0.6242
# Epoch 019 | TrainLoss 39.2435 | RMSE 1.3698 | R2 0.4504
# Epoch 020 | TrainLoss 34.2475 | RMSE 1.4675 | R2 0.3692
# Epoch 021 | TrainLoss 33.4778 | RMSE 1.4773 | R2 0.3607
# Epoch 022 | TrainLoss 26.8144 | RMSE 1.5703 | R2 0.2777
# Epoch 023 | TrainLoss 31.5180 | RMSE 1.1077 | R2 0.6406
# Epoch 024 | TrainLoss 31.9535 | RMSE 1.0694 | R2 0.6650
# Epoch 025 | TrainLoss 24.0490 | RMSE 1.6230 | R2 0.2284
# Epoch 026 | TrainLoss 33.1029 | RMSE 1.0945 | R2 0.6491
# Epoch 027 | TrainLoss 26.1767 | RMSE 1.5444 | R2 0.3013
# Epoch 028 | TrainLoss 22.1169 | RMSE 1.2888 | R2 0.5134
# Epoch 029 | TrainLoss 24.2739 | RMSE 1.6657 | R2 0.1873
# Epoch 030 | TrainLoss 17.4188 | RMSE 1.3220 | R2 0.4881
# Epoch 031 | TrainLoss 18.9533 | RMSE 1.4761 | R2 0.3618
# Epoch 032 | TrainLoss 22.1036 | RMSE 1.6661 | R2 0.1869
# Epoch 033 | TrainLoss 22.7013 | RMSE 1.2039 | R2 0.5755
# Epoch 034 | TrainLoss 17.4916 | RMSE 1.5855 | R2 0.2637
# Epoch 035 | TrainLoss 21.4856 | RMSE 1.0387 | R2 0.6840
# Epoch 036 | TrainLoss 18.8674 | RMSE 1.8486 | R2 -0.0010
# Epoch 037 | TrainLoss 12.4195 | RMSE 1.7060 | R2 0.1474
# Epoch 038 | TrainLoss 27.0067 | RMSE 1.2112 | R2 0.5703
# Epoch 039 | TrainLoss 46.6757 | RMSE 1.2954 | R2 0.5084
# Epoch 040 | TrainLoss 32.4713 | RMSE 1.2333 | R2 0.5544
# Epoch 041 | TrainLoss 29.9790 | RMSE 1.2410 | R2 0.5489
# Epoch 042 | TrainLoss 25.3550 | RMSE 1.2403 | R2 0.5494
# Epoch 043 | TrainLoss 26.6096 | RMSE 1.1956 | R2 0.5813
# Epoch 044 | TrainLoss 25.5000 | RMSE 1.2496 | R2 0.5426
# Epoch 045 | TrainLoss 27.7179 | RMSE 1.1879 | R2 0.5866
# Epoch 046 | TrainLoss 23.5214 | RMSE 1.1931 | R2 0.5830
# Epoch 047 | TrainLoss 19.9465 | RMSE 1.2668 | R2 0.5299
# Epoch 048 | TrainLoss 24.6724 | RMSE 1.2000 | R2 0.5782
# Epoch 049 | TrainLoss 20.7991 | RMSE 1.0706 | R2 0.6642
# Epoch 050 | TrainLoss 19.5557 | RMSE 1.1740 | R2 0.5963
# Epoch 051 | TrainLoss 17.6288 | RMSE 1.2135 | R2 0.5687
# Epoch 052 | TrainLoss 17.2226 | RMSE 1.1450 | R2 0.6160
# Epoch 053 | TrainLoss 17.6040 | RMSE 1.3857 | R2 0.4376
# Epoch 054 | TrainLoss 20.6246 | RMSE 1.1930 | R2 0.5831
# Epoch 055 | TrainLoss 18.9277 | RMSE 1.2930 | R2 0.5103
# Epoch 056 | TrainLoss 16.5326 | RMSE 1.1937 | R2 0.5826
# Epoch 057 | TrainLoss 14.4152 | RMSE 1.3415 | R2 0.4728
# Epoch 058 | TrainLoss 16.7358 | RMSE 1.2538 | R2 0.5395
# Epoch 059 | TrainLoss 17.9768 | RMSE 1.4141 | R2 0.4143
# Epoch 060 | TrainLoss 17.3777 | RMSE 1.5619 | R2 0.2854
# Epoch 061 | TrainLoss 17.9618 | RMSE 1.6699 | R2 0.1831
# Epoch 062 | TrainLoss 24.8726 | RMSE 1.6726 | R2 0.1806
# Epoch 063 | TrainLoss 19.2567 | RMSE 1.5011 | R2 0.3400
# Epoch 064 | TrainLoss 14.7989 | RMSE 1.5735 | R2 0.2748
# Epoch 065 | TrainLoss 16.6055 | RMSE 1.5163 | R2 0.3265
# Epoch 066 | TrainLoss 13.6309 | RMSE 1.5873 | R2 0.2620
# Epoch 067 | TrainLoss 11.9015 | RMSE 1.4404 | R2 0.3922
# Epoch 068 | TrainLoss 11.2147 | RMSE 1.4957 | R2 0.3447
# Epoch 069 | TrainLoss 12.1277 | RMSE 1.7070 | R2 0.1465
# Epoch 070 | TrainLoss 23.3513 | RMSE 1.5539 | R2 0.2927
# Epoch 071 | TrainLoss 15.6537 | RMSE 1.3834 | R2 0.4395
# Epoch 072 | TrainLoss 12.5625 | RMSE 1.5813 | R2 0.2675
# Epoch 073 | TrainLoss 13.6332 | RMSE 1.4738 | R2 0.3638
# Epoch 074 | TrainLoss 11.0729 | RMSE 1.5530 | R2 0.2936
# Epoch 075 | TrainLoss 11.8143 | RMSE 1.8238 | R2 0.0257
# Epoch 076 | TrainLoss 19.1413 | RMSE 1.0450 | R2 0.6801
# Epoch 077 | TrainLoss 17.7778 | RMSE 1.4730 | R2 0.3645
# Epoch 078 | TrainLoss 19.5919 | RMSE 1.6884 | R2 0.1650
# Epoch 079 | TrainLoss 11.8787 | RMSE 1.5753 | R2 0.2731
# Epoch 080 | TrainLoss 9.3256 | RMSE 1.7643 | R2 0.0882
# Epoch 081 | TrainLoss 11.7270 | RMSE 1.3548 | R2 0.4624
# Epoch 082 | TrainLoss 9.2064 | RMSE 1.4941 | R2 0.3461
# Epoch 083 | TrainLoss 8.5712 | RMSE 1.7394 | R2 0.1138
# Epoch 084 | TrainLoss 11.7109 | RMSE 1.6468 | R2 0.2056
# Epoch 085 | TrainLoss 11.7141 | RMSE 1.4743 | R2 0.3634
# Early stopping triggered
#
# [FOLD 1 FINAL]
# MSE : 1.0789
# RMSE: 1.0387
# MAE : 0.8022
# R2  : 0.6840
#
# ==== No_projection Fold 2 ====
# Epoch 000 | TrainLoss 1119.0974 | RMSE 5.3112 | R2 -10.5535
# Epoch 001 | TrainLoss 712.8909 | RMSE 4.0505 | R2 -5.7195
# Epoch 002 | TrainLoss 384.7266 | RMSE 2.5948 | R2 -1.7576
# Epoch 003 | TrainLoss 172.9300 | RMSE 1.4920 | R2 0.0883
# Epoch 004 | TrainLoss 80.8955 | RMSE 1.0508 | R2 0.5478
# Epoch 005 | TrainLoss 64.0369 | RMSE 1.2647 | R2 0.3449
# Epoch 006 | TrainLoss 59.8115 | RMSE 1.0206 | R2 0.5734
# Epoch 007 | TrainLoss 59.4464 | RMSE 1.0387 | R2 0.5581
# Epoch 008 | TrainLoss 57.0774 | RMSE 1.0412 | R2 0.5560
# Epoch 009 | TrainLoss 61.6030 | RMSE 1.6329 | R2 -0.0921
# Epoch 010 | TrainLoss 63.6906 | RMSE 1.5499 | R2 0.0161
# Epoch 011 | TrainLoss 61.9968 | RMSE 1.4652 | R2 0.1207
# Epoch 012 | TrainLoss 62.0078 | RMSE 1.1267 | R2 0.4801
# Epoch 013 | TrainLoss 58.4545 | RMSE 1.0141 | R2 0.5788
# Epoch 014 | TrainLoss 56.7993 | RMSE 0.8593 | R2 0.6976
# Epoch 015 | TrainLoss 57.3872 | RMSE 0.9791 | R2 0.6074
# Epoch 016 | TrainLoss 54.2730 | RMSE 1.0615 | R2 0.5385
# Epoch 017 | TrainLoss 55.2031 | RMSE 1.0156 | R2 0.5776
# Epoch 018 | TrainLoss 55.2113 | RMSE 1.1343 | R2 0.4730
# Epoch 019 | TrainLoss 57.5049 | RMSE 1.0400 | R2 0.5570
# Epoch 020 | TrainLoss 50.9321 | RMSE 0.8961 | R2 0.6711
# Epoch 021 | TrainLoss 51.8822 | RMSE 0.9354 | R2 0.6417
# Epoch 022 | TrainLoss 48.3670 | RMSE 0.9269 | R2 0.6481
# Epoch 023 | TrainLoss 44.4304 | RMSE 0.6094 | R2 0.8479
# Epoch 024 | TrainLoss 44.5421 | RMSE 0.7779 | R2 0.7522
# Epoch 025 | TrainLoss 39.8914 | RMSE 1.1583 | R2 0.4505
# Epoch 026 | TrainLoss 36.2463 | RMSE 0.8059 | R2 0.7340
# Epoch 027 | TrainLoss 34.2511 | RMSE 0.9026 | R2 0.6663
# Epoch 028 | TrainLoss 34.5339 | RMSE 0.7184 | R2 0.7886
# Epoch 029 | TrainLoss 38.7272 | RMSE 0.9570 | R2 0.6249
# Epoch 030 | TrainLoss 36.6424 | RMSE 0.6026 | R2 0.8513
# Epoch 031 | TrainLoss 32.0818 | RMSE 1.0114 | R2 0.5810
# Epoch 032 | TrainLoss 31.6214 | RMSE 1.2262 | R2 0.3842
# Epoch 033 | TrainLoss 31.5803 | RMSE 1.1339 | R2 0.4734
# Epoch 034 | TrainLoss 28.8238 | RMSE 1.0533 | R2 0.5456
# Epoch 035 | TrainLoss 28.5506 | RMSE 0.7425 | R2 0.7742
# Epoch 036 | TrainLoss 25.8827 | RMSE 1.0520 | R2 0.5467
# Epoch 037 | TrainLoss 28.4396 | RMSE 1.0836 | R2 0.5191
# Epoch 038 | TrainLoss 24.4792 | RMSE 0.9349 | R2 0.6420
# Epoch 039 | TrainLoss 27.5994 | RMSE 0.8173 | R2 0.7264
# Epoch 040 | TrainLoss 29.9258 | RMSE 0.5628 | R2 0.8703
# Epoch 041 | TrainLoss 27.2056 | RMSE 1.1929 | R2 0.4172
# Epoch 042 | TrainLoss 27.3003 | RMSE 1.0254 | R2 0.5694
# Epoch 043 | TrainLoss 23.7864 | RMSE 1.0045 | R2 0.5868
# Epoch 044 | TrainLoss 26.1769 | RMSE 0.7100 | R2 0.7936
# Epoch 045 | TrainLoss 18.1422 | RMSE 0.8060 | R2 0.7339
# Epoch 046 | TrainLoss 23.1488 | RMSE 0.7585 | R2 0.7643
# Epoch 047 | TrainLoss 21.3297 | RMSE 0.7416 | R2 0.7748
# Epoch 048 | TrainLoss 27.0001 | RMSE 0.9558 | R2 0.6259
# Epoch 049 | TrainLoss 22.5306 | RMSE 0.7192 | R2 0.7882
# Epoch 050 | TrainLoss 16.6773 | RMSE 1.0983 | R2 0.5059
# Epoch 051 | TrainLoss 26.8573 | RMSE 1.3063 | R2 0.3012
# Epoch 052 | TrainLoss 21.3131 | RMSE 1.3305 | R2 0.2750
# Epoch 053 | TrainLoss 15.2680 | RMSE 1.0592 | R2 0.5405
# Epoch 054 | TrainLoss 14.4267 | RMSE 0.9125 | R2 0.6590
# Epoch 055 | TrainLoss 12.6075 | RMSE 1.0658 | R2 0.5347
# Epoch 056 | TrainLoss 12.2791 | RMSE 0.9982 | R2 0.5919
# Epoch 057 | TrainLoss 30.4855 | RMSE 0.7903 | R2 0.7442
# Epoch 058 | TrainLoss 26.7918 | RMSE 0.9544 | R2 0.6270
# Epoch 059 | TrainLoss 19.2415 | RMSE 0.7733 | R2 0.7551
# Epoch 060 | TrainLoss 18.5855 | RMSE 0.9956 | R2 0.5940
# Epoch 061 | TrainLoss 14.9438 | RMSE 1.1065 | R2 0.4986
# Epoch 062 | TrainLoss 13.1626 | RMSE 0.7475 | R2 0.7711
# Epoch 063 | TrainLoss 16.4743 | RMSE 0.8475 | R2 0.7058
# Epoch 064 | TrainLoss 13.4485 | RMSE 1.1978 | R2 0.4124
# Epoch 065 | TrainLoss 17.3700 | RMSE 0.9219 | R2 0.6519
# Epoch 066 | TrainLoss 17.6507 | RMSE 0.9264 | R2 0.6485
# Epoch 067 | TrainLoss 11.3334 | RMSE 0.9151 | R2 0.6570
# Epoch 068 | TrainLoss 9.7390 | RMSE 0.9398 | R2 0.6383
# Epoch 069 | TrainLoss 11.6741 | RMSE 0.8269 | R2 0.7200
# Epoch 070 | TrainLoss 10.3929 | RMSE 0.8734 | R2 0.6876
# Epoch 071 | TrainLoss 13.0358 | RMSE 0.7703 | R2 0.7570
# Epoch 072 | TrainLoss 14.9100 | RMSE 0.7406 | R2 0.7753
# Epoch 073 | TrainLoss 20.1690 | RMSE 1.0788 | R2 0.5233
# Epoch 074 | TrainLoss 15.9299 | RMSE 1.1262 | R2 0.4805
# Epoch 075 | TrainLoss 13.3457 | RMSE 0.9330 | R2 0.6435
# Epoch 076 | TrainLoss 10.7612 | RMSE 0.7713 | R2 0.7563
# Epoch 077 | TrainLoss 11.4653 | RMSE 1.1999 | R2 0.4104
# Epoch 078 | TrainLoss 14.2225 | RMSE 0.9514 | R2 0.6293
# Epoch 079 | TrainLoss 10.2195 | RMSE 1.0553 | R2 0.5438
# Epoch 080 | TrainLoss 8.7840 | RMSE 0.9241 | R2 0.6503
# Epoch 081 | TrainLoss 9.4459 | RMSE 0.8570 | R2 0.6992
# Epoch 082 | TrainLoss 9.5315 | RMSE 0.7523 | R2 0.7682
# Epoch 083 | TrainLoss 8.7315 | RMSE 0.9193 | R2 0.6538
# Epoch 084 | TrainLoss 9.0426 | RMSE 0.8513 | R2 0.7032
# Epoch 085 | TrainLoss 7.1622 | RMSE 0.9800 | R2 0.6066
# Epoch 086 | TrainLoss 8.9373 | RMSE 0.8634 | R2 0.6947
# Epoch 087 | TrainLoss 8.6126 | RMSE 0.5868 | R2 0.8590
# Epoch 088 | TrainLoss 8.5341 | RMSE 0.7471 | R2 0.7714
# Epoch 089 | TrainLoss 10.8869 | RMSE 0.9733 | R2 0.6120
# Epoch 090 | TrainLoss 12.2725 | RMSE 0.8616 | R2 0.6960
# Early stopping triggered
#
# [FOLD 2 FINAL]
# MSE : 0.3167
# RMSE: 0.5628
# MAE : 0.4453
# R2  : 0.8703
#
# ==== No_projection Fold 3 ====
# ...
# Epoch 052 | TrainLoss 62.2195 | RMSE 1.3609 | R2 0.4575
# Epoch 053 | TrainLoss 61.0495 | RMSE 1.4164 | R2 0.4123
# Epoch 054 | TrainLoss 63.5067 | RMSE 1.3468 | R2 0.4687
# Epoch 055 | TrainLoss 59.1866 | RMSE 1.4118 | R2 0.4162
# Epoch 056 | TrainLoss 61.6490 | RMSE 1.5795 | R2 0.2692
# Epoch 057 | TrainLoss 63.6771 | RMSE 1.4230 | R2 0.4069
# Epoch 058 | TrainLoss 62.4582 | RMSE 1.4091 | R2 0.4184
# Epoch 059 | TrainLoss 61.1077 | RMSE 1.3601 | R2 0.4582
# Epoch 060 | TrainLoss 60.0794 | RMSE 1.4388 | R2 0.3936
# Epoch 061 | TrainLoss 58.6062 | RMSE 1.3550 | R2 0.4622
# Epoch 062 | TrainLoss 58.1249 | RMSE 1.3785 | R2 0.4433
# Epoch 063 | TrainLoss 59.1471 | RMSE 1.4235 | R2 0.4064
# Epoch 064 | TrainLoss 59.0043 | RMSE 1.4078 | R2 0.4194
# Epoch 065 | TrainLoss 57.6324 | RMSE 1.4064 | R2 0.4206
# Epoch 066 | TrainLoss 58.0525 | RMSE 1.3787 | R2 0.4432
# Epoch 067 | TrainLoss 59.8696 | RMSE 1.4155 | R2 0.4131
# Epoch 068 | TrainLoss 56.9270 | RMSE 1.4371 | R2 0.3951
# Epoch 069 | TrainLoss 59.4795 | RMSE 1.3863 | R2 0.4371
# Epoch 070 | TrainLoss 62.2572 | RMSE 1.4028 | R2 0.4236
# Epoch 071 | TrainLoss 58.4981 | RMSE 1.3940 | R2 0.4308
# Epoch 072 | TrainLoss 56.7540 | RMSE 1.4075 | R2 0.4197
# Epoch 073 | TrainLoss 58.1839 | RMSE 1.4615 | R2 0.3743
# Epoch 074 | TrainLoss 57.6773 | RMSE 1.5320 | R2 0.3125
# Epoch 075 | TrainLoss 59.1130 | RMSE 1.3567 | R2 0.4609
# Epoch 076 | TrainLoss 58.9453 | RMSE 1.3321 | R2 0.4802
# Epoch 077 | TrainLoss 57.7106 | RMSE 1.3429 | R2 0.4717
# Epoch 078 | TrainLoss 56.6891 | RMSE 1.3912 | R2 0.4330
# Epoch 079 | TrainLoss 55.7025 | RMSE 1.3807 | R2 0.4416
# Epoch 080 | TrainLoss 58.1476 | RMSE 1.5185 | R2 0.3246
# Epoch 081 | TrainLoss 56.1150 | RMSE 1.3726 | R2 0.4482
# Epoch 082 | TrainLoss 58.8289 | RMSE 1.3869 | R2 0.4366
# Epoch 083 | TrainLoss 57.1286 | RMSE 1.4152 | R2 0.4134
# Epoch 084 | TrainLoss 56.0164 | RMSE 1.4298 | R2 0.4012
# Epoch 085 | TrainLoss 55.2017 | RMSE 1.3457 | R2 0.4695
# Epoch 086 | TrainLoss 54.4174 | RMSE 1.5192 | R2 0.3239
# Epoch 087 | TrainLoss 56.4793 | RMSE 1.3399 | R2 0.4741
# Epoch 088 | TrainLoss 55.9642 | RMSE 1.3204 | R2 0.4893
# Early stopping triggered
#
# [FOLD 1 FINAL]
# MSE : 1.5040
# RMSE: 1.2264
# MAE : 1.0794
# R2  : 0.5595
#
# ==== No_projection_fourier_positional_encoding_temp_token Fold 2 ====
# Epoch 000 | TrainLoss 1780.1317 | RMSE 7.6900 | R2 -23.2206
# Epoch 001 | TrainLoss 1696.3931 | RMSE 7.3248 | R2 -20.9747
# Epoch 002 | TrainLoss 1104.4149 | RMSE 2.5607 | R2 -1.6856
# Epoch 003 | TrainLoss 135.3458 | RMSE 1.6810 | R2 -0.1573
# Epoch 004 | TrainLoss 100.7786 | RMSE 1.3581 | R2 0.2445
# Epoch 005 | TrainLoss 91.6815 | RMSE 1.2906 | R2 0.3178
# Epoch 006 | TrainLoss 88.6186 | RMSE 1.3997 | R2 0.1976
# Epoch 007 | TrainLoss 88.7131 | RMSE 1.3480 | R2 0.2557
# Epoch 008 | TrainLoss 85.8369 | RMSE 1.3526 | R2 0.2507
# Epoch 009 | TrainLoss 85.7853 | RMSE 1.4445 | R2 0.1454
# Epoch 010 | TrainLoss 84.4458 | RMSE 1.6255 | R2 -0.0822
# Epoch 011 | TrainLoss 86.4805 | RMSE 1.4460 | R2 0.1436
# Epoch 012 | TrainLoss 82.6853 | RMSE 1.4294 | R2 0.1632
# Epoch 013 | TrainLoss 85.3736 | RMSE 1.4671 | R2 0.1184
# Epoch 014 | TrainLoss 83.9800 | RMSE 1.4474 | R2 0.1420
# Epoch 015 | TrainLoss 83.0989 | RMSE 1.4550 | R2 0.1329
# Epoch 016 | TrainLoss 82.9637 | RMSE 1.5279 | R2 0.0439
# Epoch 017 | TrainLoss 82.1454 | RMSE 1.4980 | R2 0.0809
# Epoch 018 | TrainLoss 81.1259 | RMSE 1.4182 | R2 0.1763
# Epoch 019 | TrainLoss 80.7245 | RMSE 1.4469 | R2 0.1426
# Epoch 020 | TrainLoss 80.2318 | RMSE 1.4390 | R2 0.1519
# Epoch 021 | TrainLoss 79.3925 | RMSE 1.4183 | R2 0.1761
# Epoch 022 | TrainLoss 79.9683 | RMSE 1.4555 | R2 0.1323
# Epoch 023 | TrainLoss 78.9173 | RMSE 1.3978 | R2 0.1998
# Epoch 024 | TrainLoss 79.3623 | RMSE 1.5487 | R2 0.0176
# Epoch 025 | TrainLoss 81.3100 | RMSE 1.3786 | R2 0.2217
# Epoch 026 | TrainLoss 77.8554 | RMSE 1.3827 | R2 0.2170
# Epoch 027 | TrainLoss 78.3739 | RMSE 1.4601 | R2 0.1268
# Epoch 028 | TrainLoss 78.4929 | RMSE 1.3657 | R2 0.2361
# Epoch 029 | TrainLoss 78.3062 | RMSE 1.3468 | R2 0.2570
# Epoch 030 | TrainLoss 81.6924 | RMSE 1.4486 | R2 0.1405
# Epoch 031 | TrainLoss 76.3653 | RMSE 1.3263 | R2 0.2795
# Epoch 032 | TrainLoss 76.9756 | RMSE 1.3552 | R2 0.2478
# Epoch 033 | TrainLoss 74.1491 | RMSE 1.3270 | R2 0.2788
# Epoch 034 | TrainLoss 73.0111 | RMSE 1.3251 | R2 0.2809
# Epoch 035 | TrainLoss 71.8696 | RMSE 1.4328 | R2 0.1591
# Epoch 036 | TrainLoss 71.6124 | RMSE 1.2901 | R2 0.3183
# Epoch 037 | TrainLoss 69.4863 | RMSE 1.3427 | R2 0.2617
# Epoch 038 | TrainLoss 70.6471 | RMSE 1.2967 | R2 0.3114
# Epoch 039 | TrainLoss 69.5538 | RMSE 1.3123 | R2 0.2946
# Epoch 040 | TrainLoss 70.2346 | RMSE 1.3774 | R2 0.2230
# Epoch 041 | TrainLoss 73.3830 | RMSE 1.3341 | R2 0.2710
# Epoch 042 | TrainLoss 71.6523 | RMSE 1.3276 | R2 0.2781
# Epoch 043 | TrainLoss 66.6320 | RMSE 1.3635 | R2 0.2386
# Epoch 044 | TrainLoss 67.0854 | RMSE 1.2797 | R2 0.3292
# Epoch 045 | TrainLoss 67.1485 | RMSE 1.2761 | R2 0.3331
# Epoch 046 | TrainLoss 67.4453 | RMSE 1.3816 | R2 0.2183
# Epoch 047 | TrainLoss 66.0008 | RMSE 1.3113 | R2 0.2958
# Epoch 048 | TrainLoss 64.5723 | RMSE 1.3177 | R2 0.2888
# Epoch 049 | TrainLoss 63.1898 | RMSE 1.3518 | R2 0.2516
# Epoch 050 | TrainLoss 65.0010 | RMSE 1.3986 | R2 0.1989
# Epoch 051 | TrainLoss 64.1800 | RMSE 1.3339 | R2 0.2713
# Epoch 052 | TrainLoss 61.0725 | RMSE 1.3666 | R2 0.2351
# Epoch 053 | TrainLoss 62.1893 | RMSE 1.3721 | R2 0.2289
# Epoch 054 | TrainLoss 64.8351 | RMSE 1.4809 | R2 0.1018
# Epoch 055 | TrainLoss 63.4157 | RMSE 1.3952 | R2 0.2027
# Epoch 056 | TrainLoss 61.0216 | RMSE 1.4116 | R2 0.1839
# Epoch 057 | TrainLoss 61.5999 | RMSE 1.3285 | R2 0.2772
# Epoch 058 | TrainLoss 60.8814 | RMSE 1.3997 | R2 0.1976
# Epoch 059 | TrainLoss 61.8111 | RMSE 1.4777 | R2 0.1057
# Epoch 060 | TrainLoss 58.9964 | RMSE 1.4537 | R2 0.1345
# Epoch 061 | TrainLoss 60.5787 | RMSE 1.3684 | R2 0.2331
# Epoch 062 | TrainLoss 57.9829 | RMSE 1.3847 | R2 0.2147
# Epoch 063 | TrainLoss 59.0421 | RMSE 1.4485 | R2 0.1407
# Epoch 064 | TrainLoss 58.9925 | RMSE 1.3889 | R2 0.2099
# Epoch 065 | TrainLoss 57.3517 | RMSE 1.3813 | R2 0.2185
# Epoch 066 | TrainLoss 58.2107 | RMSE 1.4081 | R2 0.1879
# Epoch 067 | TrainLoss 59.4834 | RMSE 1.3508 | R2 0.2526
# Epoch 068 | TrainLoss 56.9528 | RMSE 1.4228 | R2 0.1708
# Epoch 069 | TrainLoss 57.7450 | RMSE 1.3836 | R2 0.2160
# Epoch 070 | TrainLoss 57.4752 | RMSE 1.3825 | R2 0.2172
# Epoch 071 | TrainLoss 58.4100 | RMSE 1.4726 | R2 0.1118
# Epoch 072 | TrainLoss 58.4169 | RMSE 1.4734 | R2 0.1109
# Epoch 073 | TrainLoss 58.3613 | RMSE 1.4657 | R2 0.1201
# Epoch 074 | TrainLoss 57.1524 | RMSE 1.3247 | R2 0.2812
# Epoch 075 | TrainLoss 57.3260 | RMSE 1.4104 | R2 0.1853
# Epoch 076 | TrainLoss 57.0757 | RMSE 1.4553 | R2 0.1325
# Epoch 077 | TrainLoss 56.7717 | RMSE 1.4716 | R2 0.1131
# Epoch 078 | TrainLoss 56.6513 | RMSE 1.4427 | R2 0.1475
# Epoch 079 | TrainLoss 57.5303 | RMSE 1.4673 | R2 0.1182
# Epoch 080 | TrainLoss 56.9993 | RMSE 1.5477 | R2 0.0189
# Epoch 081 | TrainLoss 57.8335 | RMSE 1.4067 | R2 0.1896
# Epoch 082 | TrainLoss 57.1676 | RMSE 1.4528 | R2 0.1356
# Epoch 083 | TrainLoss 58.9678 | RMSE 1.4661 | R2 0.1197
# Epoch 084 | TrainLoss 57.8173 | RMSE 1.4362 | R2 0.1552
# Epoch 085 | TrainLoss 57.6351 | RMSE 1.4405 | R2 0.1501
# Epoch 086 | TrainLoss 57.9248 | RMSE 1.4318 | R2 0.1604
# Epoch 087 | TrainLoss 58.7052 | RMSE 1.4362 | R2 0.1552
# Epoch 088 | TrainLoss 57.0476 | RMSE 1.4655 | R2 0.1203
# Epoch 089 | TrainLoss 58.7490 | RMSE 1.4071 | R2 0.1891
# Epoch 090 | TrainLoss 55.5832 | RMSE 1.4622 | R2 0.1243
# Epoch 091 | TrainLoss 57.6587 | RMSE 1.4466 | R2 0.1429
# Epoch 092 | TrainLoss 59.4242 | RMSE 1.4977 | R2 0.0813
# Epoch 093 | TrainLoss 58.9994 | RMSE 1.4792 | R2 0.1039
# Epoch 094 | TrainLoss 56.6837 | RMSE 1.4214 | R2 0.1726
# Epoch 095 | TrainLoss 56.8849 | RMSE 1.4379 | R2 0.1532
# Early stopping triggered
#
# [FOLD 2 FINAL]
# MSE : 1.6278
# RMSE: 1.2758
# MAE : 1.0479
# R2  : 0.3333
#
# ==== No_projection_fourier_positional_encoding_temp_token Fold 3 ====
# Epoch 000 | TrainLoss 1722.1561 | RMSE 8.2676 | R2 -18.7879
# Epoch 001 | TrainLoss 1562.4370 | RMSE 7.4217 | R2 -14.9459
# Epoch 002 | TrainLoss 615.4200 | RMSE 2.0599 | R2 -0.2284
# Epoch 003 | TrainLoss 97.1513 | RMSE 1.9746 | R2 -0.1287
# Epoch 004 | TrainLoss 71.4479 | RMSE 2.1247 | R2 -0.3069
# Epoch 005 | TrainLoss 69.1416 | RMSE 2.1959 | R2 -0.3960
# Epoch 006 | TrainLoss 67.8664 | RMSE 2.2321 | R2 -0.4424
# Epoch 007 | TrainLoss 66.5441 | RMSE 2.0914 | R2 -0.2662
# Epoch 008 | TrainLoss 66.0115 | RMSE 2.1232 | R2 -0.3050
# Epoch 009 | TrainLoss 66.1006 | RMSE 2.0872 | R2 -0.2612
# Epoch 010 | TrainLoss 65.4117 | RMSE 2.1012 | R2 -0.2782
# Epoch 011 | TrainLoss 65.9330 | RMSE 2.2640 | R2 -0.4838
# Epoch 012 | TrainLoss 63.9608 | RMSE 2.1933 | R2 -0.3926
# Epoch 013 | TrainLoss 64.5004 | RMSE 2.2905 | R2 -0.5188
# Epoch 014 | TrainLoss 64.0075 | RMSE 2.1298 | R2 -0.3131
# Epoch 015 | TrainLoss 62.6798 | RMSE 2.1888 | R2 -0.3869
# Epoch 016 | TrainLoss 62.9562 | RMSE 2.1247 | R2 -0.3069
# Epoch 017 | TrainLoss 62.9166 | RMSE 2.1088 | R2 -0.2874
# Epoch 018 | TrainLoss 62.7343 | RMSE 2.2072 | R2 -0.4104
# Epoch 019 | TrainLoss 64.1623 | RMSE 2.0248 | R2 -0.1869
# Epoch 020 | TrainLoss 61.2838 | RMSE 2.1372 | R2 -0.3223
# Epoch 021 | TrainLoss 60.4434 | RMSE 2.1704 | R2 -0.3637
# Epoch 022 | TrainLoss 60.6310 | RMSE 2.1309 | R2 -0.3145
# Epoch 023 | TrainLoss 60.7424 | RMSE 2.0434 | R2 -0.2088
# Epoch 024 | TrainLoss 61.1282 | RMSE 2.2291 | R2 -0.4384
# Epoch 025 | TrainLoss 59.4250 | RMSE 2.0800 | R2 -0.2525
# Epoch 026 | TrainLoss 61.5430 | RMSE 2.3219 | R2 -0.5608
# Epoch 027 | TrainLoss 61.7252 | RMSE 2.0454 | R2 -0.2112
# Epoch 028 | TrainLoss 60.2481 | RMSE 2.1769 | R2 -0.3719
# Epoch 029 | TrainLoss 61.0234 | RMSE 2.1130 | R2 -0.2925
# Epoch 030 | TrainLoss 60.5292 | RMSE 2.2365 | R2 -0.4480
# Epoch 031 | TrainLoss 59.3790 | RMSE 2.1924 | R2 -0.3915
# Epoch 032 | TrainLoss 59.1435 | RMSE 2.1234 | R2 -0.3053
# Epoch 033 | TrainLoss 58.4984 | RMSE 2.2090 | R2 -0.4127
# Epoch 034 | TrainLoss 58.2206 | RMSE 2.1343 | R2 -0.3188
# Epoch 035 | TrainLoss 57.4394 | RMSE 2.1773 | R2 -0.3724
# Epoch 036 | TrainLoss 58.8765 | RMSE 2.2511 | R2 -0.4670
# Epoch 037 | TrainLoss 57.4603 | RMSE 2.3265 | R2 -0.5669
# Epoch 038 | TrainLoss 59.4456 | RMSE 2.0615 | R2 -0.2303
# Epoch 039 | TrainLoss 58.1619 | RMSE 2.1356 | R2 -0.3204
# Epoch 040 | TrainLoss 57.1460 | RMSE 2.0942 | R2 -0.2697
# Epoch 041 | TrainLoss 57.7551 | RMSE 2.1531 | R2 -0.3421
# Epoch 042 | TrainLoss 56.3445 | RMSE 2.1283 | R2 -0.3114
# Epoch 043 | TrainLoss 56.0575 | RMSE 2.3182 | R2 -0.5557
# Epoch 044 | TrainLoss 57.3891 | RMSE 2.2066 | R2 -0.4095
# Epoch 045 | TrainLoss 55.8419 | RMSE 2.2048 | R2 -0.4073
# Epoch 046 | TrainLoss 55.9072 | RMSE 2.1179 | R2 -0.2985
# Epoch 047 | TrainLoss 56.0674 | RMSE 2.1060 | R2 -0.2839
# Epoch 048 | TrainLoss 55.3478 | RMSE 2.1738 | R2 -0.3680
# Epoch 049 | TrainLoss 55.7598 | RMSE 2.1377 | R2 -0.3229
# Epoch 050 | TrainLoss 55.6975 | RMSE 2.2489 | R2 -0.4641
# Epoch 051 | TrainLoss 56.1761 | RMSE 2.1167 | R2 -0.2971
# Epoch 052 | TrainLoss 54.4099 | RMSE 2.1438 | R2 -0.3305
# Epoch 053 | TrainLoss 55.0882 | RMSE 2.0994 | R2 -0.2760
# Early stopping triggered
#
# [FOLD 3 FINAL]
# MSE : 3.8988
# RMSE: 1.9745
# MAE : 1.6242
# R2  : -0.1287
#
# ==== No_projection_fourier_positional_encoding_temp_token Fold 4 ====
# Epoch 000 | TrainLoss 1811.3186 | RMSE 7.8330 | R2 -14.1267
# Epoch 001 | TrainLoss 1699.8367 | RMSE 7.3704 | R2 -12.3927
# Epoch 002 | TrainLoss 1005.8610 | RMSE 2.4172 | R2 -0.4405
# Epoch 003 | TrainLoss 125.1890 | RMSE 1.9804 | R2 0.0331
# Epoch 004 | TrainLoss 94.5306 | RMSE 1.8409 | R2 0.1645
# Epoch 005 | TrainLoss 88.2947 | RMSE 1.7533 | R2 0.2421
# Epoch 006 | TrainLoss 86.9181 | RMSE 1.6697 | R2 0.3127
# Epoch 007 | TrainLoss 82.8214 | RMSE 1.6027 | R2 0.3667
# Epoch 008 | TrainLoss 80.7259 | RMSE 1.5824 | R2 0.3826
# Epoch 009 | TrainLoss 81.2538 | RMSE 1.7120 | R2 0.2774
# Epoch 010 | TrainLoss 79.5938 | RMSE 1.6479 | R2 0.3305
# Epoch 011 | TrainLoss 77.6641 | RMSE 1.5329 | R2 0.4207
# Epoch 012 | TrainLoss 76.1101 | RMSE 1.6900 | R2 0.2958
# Epoch 013 | TrainLoss 74.1291 | RMSE 1.6542 | R2 0.3253
# Epoch 014 | TrainLoss 74.1454 | RMSE 1.6558 | R2 0.3240
# Epoch 015 | TrainLoss 71.2463 | RMSE 1.6686 | R2 0.3136
# Epoch 016 | TrainLoss 69.7559 | RMSE 1.5686 | R2 0.3934
# Epoch 017 | TrainLoss 68.3487 | RMSE 1.6220 | R2 0.3513
# Epoch 018 | TrainLoss 66.6203 | RMSE 1.5627 | R2 0.3979
# Epoch 019 | TrainLoss 65.5560 | RMSE 1.5728 | R2 0.3902
# Epoch 020 | TrainLoss 64.2798 | RMSE 1.6386 | R2 0.3381
# Epoch 021 | TrainLoss 61.3507 | RMSE 1.7426 | R2 0.2513
# Epoch 022 | TrainLoss 61.0511 | RMSE 1.6979 | R2 0.2893
# Epoch 023 | TrainLoss 61.0523 | RMSE 1.5814 | R2 0.3834
# Epoch 024 | TrainLoss 61.2031 | RMSE 1.9588 | R2 0.0541
# Epoch 025 | TrainLoss 61.2067 | RMSE 1.6535 | R2 0.3259
# Epoch 026 | TrainLoss 57.8356 | RMSE 1.7535 | R2 0.2419
# Epoch 027 | TrainLoss 58.5679 | RMSE 1.8174 | R2 0.1857
# Epoch 028 | TrainLoss 56.5954 | RMSE 1.8435 | R2 0.1621
# Epoch 029 | TrainLoss 55.3148 | RMSE 1.7954 | R2 0.2053
# Epoch 030 | TrainLoss 53.8810 | RMSE 1.7934 | R2 0.2071
# Epoch 031 | TrainLoss 54.4833 | RMSE 1.9449 | R2 0.0674
# Epoch 032 | TrainLoss 53.0965 | RMSE 1.9683 | R2 0.0448
# Epoch 033 | TrainLoss 52.1018 | RMSE 1.8086 | R2 0.1936
# Epoch 034 | TrainLoss 51.3599 | RMSE 1.7445 | R2 0.2497
# Epoch 035 | TrainLoss 51.6788 | RMSE 1.7567 | R2 0.2392
# Epoch 036 | TrainLoss 54.7998 | RMSE 1.8088 | R2 0.1934
# Epoch 037 | TrainLoss 55.0623 | RMSE 1.9700 | R2 0.0432
# Epoch 038 | TrainLoss 53.1032 | RMSE 1.7360 | R2 0.2570
# Epoch 039 | TrainLoss 49.7283 | RMSE 1.8465 | R2 0.1594
# Epoch 040 | TrainLoss 48.8410 | RMSE 1.7888 | R2 0.2111
# Epoch 041 | TrainLoss 48.0760 | RMSE 1.9666 | R2 0.0465
# Epoch 042 | TrainLoss 49.3106 | RMSE 1.8804 | R2 0.1282
# Epoch 043 | TrainLoss 48.3131 | RMSE 1.8568 | R2 0.1500
# Epoch 044 | TrainLoss 50.2500 | RMSE 1.9299 | R2 0.0818
# Epoch 045 | TrainLoss 47.8931 | RMSE 1.9026 | R2 0.1075
# Epoch 046 | TrainLoss 50.9800 | RMSE 2.0197 | R2 -0.0057
# Epoch 047 | TrainLoss 48.7442 | RMSE 2.0099 | R2 0.0040
# Epoch 048 | TrainLoss 47.7459 | RMSE 1.9857 | R2 0.0279
# Epoch 049 | TrainLoss 46.4495 | RMSE 1.9582 | R2 0.0546
# Epoch 050 | TrainLoss 47.1636 | RMSE 1.9947 | R2 0.0191
# Epoch 051 | TrainLoss 46.9124 | RMSE 1.9137 | R2 0.0971
# Epoch 052 | TrainLoss 46.8591 | RMSE 1.8178 | R2 0.1853
# Epoch 053 | TrainLoss 46.7930 | RMSE 1.9035 | R2 0.1067
# Epoch 054 | TrainLoss 47.7066 | RMSE 2.0010 | R2 0.0128
# Epoch 055 | TrainLoss 47.5353 | RMSE 1.7817 | R2 0.2174
# Epoch 056 | TrainLoss 45.5430 | RMSE 1.9733 | R2 0.0400
# Epoch 057 | TrainLoss 45.7558 | RMSE 1.9039 | R2 0.1063
# Epoch 058 | TrainLoss 47.8330 | RMSE 1.8080 | R2 0.1941
# Epoch 059 | TrainLoss 47.1203 | RMSE 1.7620 | R2 0.2345
# Epoch 060 | TrainLoss 46.7039 | RMSE 1.7635 | R2 0.2333
# Epoch 061 | TrainLoss 46.3952 | RMSE 1.8077 | R2 0.1943
# Early stopping triggered
#
# [FOLD 4 FINAL]
# MSE : 2.3500
# RMSE: 1.5330
# MAE : 1.2124
# R2  : 0.4206
#
# ================================================================================
# No_projection_fourier_positional_encoding_temp_token
# ================================================================================
# FINAL 5-FOLD RESULT
# RMSE : 1.4145 ± 0.3181
# MAE  : 1.1708 ± 0.2489
# R2   : 0.3502 ± 0.2550
#
# ====================================================================================================
# FINAL ABLATION RESULTS
# ====================================================================================================
# Experiment               MSE         RMSE        MAE         R2
# Full                     0.8774      0.9341      0.6587      0.7219
# No_projection            0.8866      0.9171      0.6775      0.7345
# No_fourier_positional_encoding1.4797      1.1982      0.9217      0.5417
# No_temp_token            1.4071      1.1760      0.9511      0.5509
# No_projection_fourier_positional_encoding1.6751      1.2640      0.9790      0.4929
# No_projection_temp_token 1.1794      1.0652      0.8163      0.6391
# No_fourier_positional_encoding_temp_token2.0527      1.4012      1.0948      0.3603
# No_projection_fourier_positional_encoding_temp_token2.1021      1.4145      1.1708      0.3502
#
# Saved:
# ✔ ablation_results.csv
# ✔ ablation_fold_results.csv (fold-level, for plots)
