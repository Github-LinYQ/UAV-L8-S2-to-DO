# %% [markdown]
# # UAV

# %% [markdown]
# ## CSF-FPE Transformer（Continuous Spectral Fusion with Positional Encoding）

# %%
import os
import torch
import torch.nn as nn
import pandas as pd
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import json
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import copy
import torch.nn.functional as F

DATA_DIR = r"\data\input"
SPLIT_PATH = os.path.join(DATA_DIR, "UAV/uav_splits.json")

# =========================
# ⭐ Dataset selection
# =========================
selected_datasets = ["uav"]

DATASET_CONFIG = {
    "uav": (0, "UAV.csv"),
    "sentinel": (1, "Sentinel-2.csv"),
    "landsat": (2, "Landsat-8.csv"),
}

# =========================
# 0. Spectral normalization settings
# =========================
GLOBAL_LAMBDA_MIN = 350.0
GLOBAL_LAMBDA_MAX = 1002

def normalize_wavelength(x):
    return (x - GLOBAL_LAMBDA_MIN) / (GLOBAL_LAMBDA_MAX - GLOBAL_LAMBDA_MIN)

def normalize_delta(x):
    return (x - GLOBAL_LAMBDA_MIN) / (GLOBAL_LAMBDA_MAX - GLOBAL_LAMBDA_MIN)

# =========================
# ⭐ Unified split loader
# =========================
def load_split(path, fold_id=0):
    with open(path, "r") as f:
        folds = json.load(f)

    split = folds[fold_id]
    return (
        np.array(split["train_idx"]),
        np.array(split["test_idx"])
    )

# =========================
# Dataset
# =========================
class SpectralDataset(Dataset):
    def __init__(self, file_path, dtype, x_mean, x_std):
        df = pd.read_csv(file_path, encoding='gbk')
        self.dtype = dtype

        temp = df.iloc[:, -2].values.astype(np.float32)
        self.x = df.iloc[:, :-2].values.astype(np.float32)
        self.y = df.iloc[:, -1].values.astype(np.float32)

        # NDWI filter
        if dtype == 1:
            ndwi = (df['B3'] - df['B8']) / (df['B3'] + df['B8'] + 1e-8)
            mask = ndwi > 0.1
            self.x, self.y, temp = self.x[mask], self.y[mask], temp[mask]

        elif dtype == 2:
            ndwi = (df['SR_B3'] - df['SR_B5']) / (df['SR_B3'] + df['SR_B5'] + 1e-8)
            mask = ndwi > 0.1
            self.x, self.y, temp = self.x[mask], self.y[mask], temp[mask]

        # clean
        mask = np.all(self.x >= 0, axis=1)
        self.x, self.y, temp = self.x[mask], self.y[mask], temp[mask]

        # global norm
        self.x = (self.x - x_mean) / (x_std + 1e-6)

        # wavelength
        if dtype == 0:
            self.lambda_ = np.arange(350, 1003, 4).astype(np.float32)
            self.delta = np.full_like(self.lambda_, 4.0)
            self.group_id = np.arange(len(self.x)) // 10

        elif dtype == 1:
            bands = [(443,20),(490,65),(560,35),(665,30),(705,15),(740,15),
                     (783,20),(842,115),(865,20),(945,20)]
            self.lambda_ = np.array([b[0] for b in bands], dtype=np.float32)
            self.delta = np.array([b[1] for b in bands], dtype=np.float32)

        else:
            bands = [(443,20),(482,65),(561,75),(655,50),(865,40)]
            self.lambda_ = np.array([b[0] for b in bands], dtype=np.float32)
            self.delta = np.array([b[1] for b in bands], dtype=np.float32)

        self.lambda_ = normalize_wavelength(self.lambda_)
        self.delta = normalize_delta(self.delta)

        self.temp = (temp - temp.mean()) / (temp.std() + 1e-6)

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return {
            "x": torch.tensor(self.x[idx]),
            "lambda": torch.tensor(self.lambda_),
            "delta": torch.tensor(self.delta),
            "y": torch.tensor(self.y[idx]),
            "type": torch.tensor(self.dtype),
            "temp": torch.tensor(self.temp[idx])
        }

# =========================
# Model
# =========================
class SpectralFusionModel(nn.Module):
    def __init__(
            self,
            d_model=64,
            grid_size=64,

            use_projection=True,
            use_fourier_positional_encoding=True,
            use_temp_token=True
    ):
        super().__init__()
        # =========================
        # 1. Ablation switches
        # =========================
        self.use_projection = use_projection
        self.use_fourier_positional_encoding = use_fourier_positional_encoding
        self.use_temp_token = use_temp_token

        #=========================
        # 2. Attention dimensions
        #=========================
        self.d_model = d_model

        # =========================
        # 3. Input embedding
        # =========================
        self.input_embed = nn.Sequential(
            nn.Linear(3, d_model),
            nn.ReLU(),
            nn.Linear(d_model, d_model)
        )

        self.temp_embed = nn.Sequential(
            nn.Linear(1, d_model),
            nn.ReLU(),
            nn.Linear(d_model, d_model)
        )

        # =========================
        # 4.1 Spectral grid (fixed coordinate system)
        # =========================
        self.register_buffer(
            "grid",
            torch.linspace(0, 1, grid_size)
        )
        # =========================
        # 4.2 Learnable spectral diffusion weights
        # =========================
        self.spectral_weight_net = nn.Sequential(
            nn.Linear(4, 32),
            nn.GELU(),
            nn.Linear(32, 16),
            nn.GELU(),
            nn.Linear(16, 1),
            nn.Sigmoid()
        )

        #=========================
        # replace4. MLP for spectral projection
        #=========================
        self.project_mlp = nn.Sequential(
            nn.Linear(d_model,d_model),
            nn.ReLU(),
            nn.Linear(d_model,d_model)
        )

        # =========================
        # 5. Fourier Encoding
        # =========================
        self.fourier_B = nn.Parameter(
            torch.logspace(0, 2, d_model // 2)
        )
        self.fourier_scale = nn.Parameter(torch.ones(1))

        #=========================
        # replace5. MLP for positional encoding
        #=========================
        self.pos_mlp = nn.Sequential(
            nn.Linear(1, d_model),
            nn.ReLU(),
            nn.Linear(d_model, d_model)
        )

        #=========================
        # 6. Feature fusion layer
        #=========================
        self.fusion = nn.Linear(d_model * 2, d_model)

        # =========================
        # 7. Transformer Encoder
        # =========================
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=4,
            batch_first=True
        )
        self.encoder = nn.TransformerEncoder(
            encoder_layer,
            num_layers=2
        )

        # =========================
        # replace7. MLP for Encoder
        # =========================
        self.encoder_mlp = nn.Sequential(
            nn.Linear(d_model,2*d_model),
            nn.GELU(),
            nn.Linear(2*d_model,d_model),
            nn.GELU()
        )

        # =========================
        # 7. Regression head
        # =========================
        self.head = nn.Sequential(
            nn.Linear(d_model, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

    # =========================
    # spectral projection
    # =========================
    def spectral_project(self, z, wl, delta):

        grid = self.grid.to(z.device).unsqueeze(0).unsqueeze(0)

        wl = wl.unsqueeze(-1)
        delta = delta.unsqueeze(-1)

        sigma = delta + 1e-6

        weight = torch.exp(-((wl - grid) ** 2) / (sigma ** 2))
        weight = weight / (weight.sum(dim=1, keepdim=True) + 1e-8)

        return (z.unsqueeze(2) * weight.unsqueeze(-1)).sum(dim=1)
    # =========================
    # Fourier Encoding
    # =========================
    def fourier_encoding(self, x):
        x = x.unsqueeze(-1)  # (B, N, 1)

        proj = x * self.fourier_B * self.fourier_scale

        return torch.cat([
            torch.sin(proj),
            torch.cos(proj)
        ], dim=-1)
    # =========================
    # forward
    # =========================
    def forward(self, x, wl, delta, dtype, temp):

        # -------------------------
        # 1. input embedding
        # -------------------------
        x = x.unsqueeze(-1)
        wl = wl.unsqueeze(-1)
        delta = delta.unsqueeze(-1)

        inp = torch.cat([x, wl, delta], dim=-1)
        z = self.input_embed(inp)

        # -------------------------
        # 2. spectral projection
        # -------------------------
        if self.use_projection:
            z = self.spectral_project(
                z,
                wl.squeeze(-1),
                delta.squeeze(-1)
            )

        else:
            z = F.interpolate(
                z.transpose(1,2),
                size=len(self.grid),
                mode="linear",
                align_corners=False
            ).transpose(1,2)

            z = self.project_mlp(z)

        # -------------------------
        # 3. Fourier positional encoding
        # -------------------------
        grid = self.grid.unsqueeze(0).expand(z.size(0), -1)

        if self.use_fourier_positional_encoding:
            pos = self.fourier_encoding(grid)
            z = torch.cat([z,pos],dim=-1)
            z = self.fusion(z)

        else:
            pos = self.pos_mlp(grid.unsqueeze(-1))
            z = z + pos

        # -------------------------
        # 4. Encoder
        # -------------------------
        B = z.size(0)

        if self.use_temp_token:
            temp = temp
        else:
            temp = torch.rand_like(temp)
        t = self.temp_embed(temp.unsqueeze(-1)).unsqueeze(1)
        z = torch.cat([t,  z], dim=1)          # (B,N+1,d)

        # -------------------------
        # 5. CLS token pooling
        # -------------------------
        if self.use_fourier_positional_encoding:
            z = self.encoder(z)
            z = z[:, 0]  # CLS token
        else:
            z = self.encoder_mlp(z)
            z = z.mean(dim=1)

        # -------------------------
        # 6. regression head
        # -------------------------
        return self.head(z).squeeze()

# =========================
# Loss
# =========================
def r2_aware_loss(pred, target):
    mse = torch.mean((pred - target) ** 2)

    pred_c = pred - pred.mean()
    tgt_c = target - target.mean()

    corr = torch.sum(pred_c * tgt_c) / (
        torch.sqrt(torch.sum(pred_c ** 2)) *
        torch.sqrt(torch.sum(tgt_c ** 2)) + 1e-8
    )

    return mse + 0.5 * (1 - corr)

# =========================
# ⭐ evaluation
# =========================
def evaluate(model, loader, device):
    model.eval()
    y_true, y_pred = [], []

    with torch.no_grad():
        for batch in loader:
            pred = model(
                batch["x"].to(device),
                batch["lambda"].to(device),
                batch["delta"].to(device),
                batch["type"].to(device),
                batch["temp"].to(device)
            )

            y_true.extend(batch["y"].cpu().numpy())
            y_pred.extend(pred.cpu().numpy())

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)

    return mse, rmse, mae, r2

# %%
import os
import copy
import json
import random
import numpy as np
import pandas as pd
import torch
from torch.utils.data import DataLoader, Subset
from itertools import combinations

# =========================
# Ablation configuration generator
# =========================
MODULES = ["projection", "fourier_positional_encoding", "temp_token"]

def generate_ablation_configs():
    configs = {}

    # Full model
    configs["Full"] = {
        "use_projection": True,
        "use_fourier_positional_encoding": True,
        "use_temp_token": True
    }

    # all combinations
    for r in range(1, len(MODULES) + 1):
        for comb in combinations(MODULES, r):

            name = "No_" + "_".join(comb)

            cfg = {
                "use_projection": True,
                "use_fourier_positional_encoding": True,
                "use_temp_token": True
            }

            for m in comb:
                cfg[f"use_{m}"] = False

            configs[name] = cfg

    return configs


ABLATION_CONFIG = generate_ablation_configs()

# =========================
# train function
# =========================
def train_one_experiment(exp_name, cfg):

    device = "cuda" if torch.cuda.is_available() else "cpu"

    print("\n" + "=" * 80)
    print(f"Running Experiment : {exp_name}")
    print("=" * 80)

    paths = [
        (DATASET_CONFIG[name][0],
         os.path.join(DATA_DIR, DATASET_CONFIG[name][1]))
        for name in selected_datasets
    ]

    # =========================
    # normalization
    # =========================
    all_x = []
    for _, path in paths:
        df = pd.read_csv(path, encoding='gbk')
        all_x.append(df.iloc[:, :-2].values.astype(np.float32))

    all_x = np.vstack(all_x)

    x_mean = all_x.mean(axis=0)
    x_std = all_x.std(axis=0) + 1e-6

    dataset = SpectralDataset(
        paths[0][1],
        paths[0][0],
        x_mean,
        x_std
    )

    folds = json.load(open(SPLIT_PATH))

    results = []
    fold_records = []   # ⭐ NEW: store fold-level metrics

    # =========================
    # 5-fold training
    # =========================
    for fold_id in range(5):

        print(f"\n==== {exp_name} Fold {fold_id} ====")

        train_idx = np.array(folds[fold_id]["train_idx"])
        test_idx = np.array(folds[fold_id]["test_idx"])

        train_loader = DataLoader(
            Subset(dataset, train_idx),
            batch_size=16,
            shuffle=True
        )

        test_loader = DataLoader(
            Subset(dataset, test_idx),
            batch_size=16
        )

        model = SpectralFusionModel(**cfg).to(device)

        opt = torch.optim.Adam(model.parameters(), lr=3e-4)

        best_loss = float("inf")
        patience = 50
        wait = 0
        best_model = None

        # =========================
        # training loop
        # =========================
        for epoch in range(500):

            model.train()
            total_loss = 0

            for batch in train_loader:

                pred = model(
                    batch["x"].to(device),
                    batch["lambda"].to(device),
                    batch["delta"].to(device),
                    batch["type"].to(device),
                    batch["temp"].to(device)
                )

                loss = r2_aware_loss(pred, batch["y"].to(device))

                opt.zero_grad()
                loss.backward()
                opt.step()

                total_loss += loss.item()

            mse, rmse, mae, r2 = evaluate(model, test_loader, device)

            print(
                f"Epoch {epoch:03d} | "
                f"TrainLoss {total_loss:.4f} | "
                f"RMSE {rmse:.4f} | R2 {r2:.4f}"
            )

            if rmse < best_loss:
                best_loss = rmse
                best_model = copy.deepcopy(model.state_dict())
                wait = 0

            else:
                wait += 1
                if wait >= patience:
                    print("Early stopping triggered")
                    break

        # =========================
        # final evaluation
        # =========================
        model.load_state_dict(best_model)

        mse, rmse, mae, r2 = evaluate(model, test_loader, device)

        print(f"\n[FOLD {fold_id} FINAL]")
        print(f"MSE : {mse:.4f}")
        print(f"RMSE: {rmse:.4f}")
        print(f"MAE : {mae:.4f}")
        print(f"R2  : {r2:.4f}")

        results.append([mse, rmse, mae, r2])

        # ⭐ NEW: save fold-level record
        fold_records.append({
            "experiment": exp_name,
            "fold": fold_id,
            "mse": mse,
            "rmse": rmse,
            "mae": mae,
            "r2": r2
        })

    # =========================
    # summary
    # =========================
    results = np.array(results)

    print("\n" + "=" * 80)
    print(exp_name)
    print("=" * 80)
    print("FINAL 5-FOLD RESULT")
    print(f"RMSE : {results[:,1].mean():.4f} ± {results[:,1].std():.4f}")
    print(f"MAE  : {results[:,2].mean():.4f} ± {results[:,2].std():.4f}")
    print(f"R2   : {results[:,3].mean():.4f} ± {results[:,3].std():.4f}")

    return {
        "mean": results.mean(axis=0),
        "folds": results,
        "records": fold_records   # ⭐ NEW
    }


# =========================
# seed
# =========================
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


# =========================
# main
# =========================
if __name__ == "__main__":

    set_seed(42)

    final_results = {}
    all_fold_results = []   # ⭐ NEW global storage

    for exp_name, cfg in ABLATION_CONFIG.items():

        result = train_one_experiment(exp_name, cfg)

        final_results[exp_name] = result["mean"]

        # ⭐ collect fold-level results
        all_fold_results.extend(result["records"])

    # =========================
    # print summary table
    # =========================
    print("\n" + "=" * 100)
    print("FINAL ABLATION RESULTS")
    print("=" * 100)

    print(f"{'Experiment':<25}{'MSE':<12}{'RMSE':<12}{'MAE':<12}{'R2':<12}")

    for k, v in final_results.items():
        print(
            f"{k:<25}"
            f"{v[0]:<12.4f}"
            f"{v[1]:<12.4f}"
            f"{v[2]:<12.4f}"
            f"{v[3]:<12.4f}"
        )

    # =========================
    # save mean results
    # =========================
    ablation_df = pd.DataFrame(
        final_results,
        index=["MSE", "RMSE", "MAE", "R2"]
    ).T

    ablation_df.to_csv(
        os.path.join(
            DATA_DIR,
            "UAV_ablation",
            "CSF-PFE",
            "ablation_results.csv"
        )
    )

    # =========================
    # ⭐ SAVE FOLD-LEVEL RESULTS (IMPORTANT)
    # =========================
    fold_df = pd.DataFrame(all_fold_results)

    fold_df.to_csv(
        os.path.join(
            DATA_DIR,
            "UAV_ablation",
            "CSF-PFE",
            "ablation_fold_results.csv"
        ),
        index=False
    )

    print("\nSaved:")
    print("✔ ablation_results.csv")
    print("✔ ablation_fold_results.csv (fold-level, for plots)")
# Out:
# ================================================================================
# Running Experiment : Full
# ================================================================================
#
# ==== Full Fold 0 ====
# Epoch 000 | TrainLoss 1136.3794 | RMSE 5.1183 | R2 -9.0586
# Epoch 001 | TrainLoss 660.1035 | RMSE 3.6603 | R2 -4.1443
# Epoch 002 | TrainLoss 323.6182 | RMSE 2.2569 | R2 -0.9558
# Epoch 003 | TrainLoss 133.4248 | RMSE 1.4501 | R2 0.1926
# Epoch 004 | TrainLoss 66.7972 | RMSE 1.4371 | R2 0.2070
# Epoch 005 | TrainLoss 56.8032 | RMSE 1.3932 | R2 0.2548
# Epoch 006 | TrainLoss 54.3410 | RMSE 1.4333 | R2 0.2112
# Epoch 007 | TrainLoss 52.9133 | RMSE 1.4011 | R2 0.2462
# Epoch 008 | TrainLoss 51.5510 | RMSE 1.3368 | R2 0.3138
# Epoch 009 | TrainLoss 48.9646 | RMSE 1.4220 | R2 0.2236
# Epoch 010 | TrainLoss 47.2208 | RMSE 1.4590 | R2 0.1826
# Epoch 011 | TrainLoss 50.1454 | RMSE 1.4476 | R2 0.1954
# Epoch 012 | TrainLoss 46.4479 | RMSE 1.4769 | R2 0.1625
# Epoch 013 | TrainLoss 46.1649 | RMSE 1.2115 | R2 0.4365
# Epoch 014 | TrainLoss 42.7960 | RMSE 1.3359 | R2 0.3148
# Epoch 015 | TrainLoss 42.6409 | RMSE 1.6436 | R2 -0.0372
# Epoch 016 | TrainLoss 40.9841 | RMSE 1.0610 | R2 0.5677
# Epoch 017 | TrainLoss 41.2276 | RMSE 1.1843 | R2 0.4615
# Epoch 018 | TrainLoss 35.2516 | RMSE 1.3834 | R2 0.2651
# Epoch 019 | TrainLoss 39.3149 | RMSE 1.5241 | R2 0.1081
# Epoch 020 | TrainLoss 37.0052 | RMSE 0.8853 | R2 0.6990
# Epoch 021 | TrainLoss 38.4492 | RMSE 1.1173 | R2 0.5207
# Epoch 022 | TrainLoss 32.9429 | RMSE 1.2997 | R2 0.3514
# Epoch 023 | TrainLoss 30.9090 | RMSE 1.4634 | R2 0.1778
# Epoch 024 | TrainLoss 38.3960 | RMSE 0.9033 | R2 0.6867
# Epoch 025 | TrainLoss 33.6226 | RMSE 1.0691 | R2 0.5611
# Epoch 026 | TrainLoss 25.6374 | RMSE 1.0688 | R2 0.5614
# Epoch 027 | TrainLoss 27.6187 | RMSE 1.2974 | R2 0.3537
# Epoch 028 | TrainLoss 28.4304 | RMSE 1.1385 | R2 0.5023
# Epoch 029 | TrainLoss 22.7574 | RMSE 1.3345 | R2 0.3162
# Epoch 030 | TrainLoss 23.6952 | RMSE 1.3636 | R2 0.2861
# Epoch 031 | TrainLoss 35.7513 | RMSE 1.0494 | R2 0.5771
# Epoch 032 | TrainLoss 29.2857 | RMSE 1.0574 | R2 0.5707
# Epoch 033 | TrainLoss 24.9074 | RMSE 1.3912 | R2 0.2569
# Epoch 034 | TrainLoss 20.0371 | RMSE 1.2011 | R2 0.4461
# Epoch 035 | TrainLoss 21.8969 | RMSE 1.2606 | R2 0.3898
# Epoch 036 | TrainLoss 20.2845 | RMSE 0.9643 | R2 0.6429
# Epoch 037 | TrainLoss 20.8326 | RMSE 1.1017 | R2 0.5339
# Epoch 038 | TrainLoss 20.7871 | RMSE 1.2255 | R2 0.4234
# Epoch 039 | TrainLoss 21.2031 | RMSE 1.1474 | R2 0.4945
# Epoch 040 | TrainLoss 19.4038 | RMSE 1.3014 | R2 0.3497
# Epoch 041 | TrainLoss 17.7617 | RMSE 1.3756 | R2 0.2734
# Epoch 042 | TrainLoss 19.6963 | RMSE 1.2060 | R2 0.4415
# Epoch 043 | TrainLoss 18.7517 | RMSE 1.2085 | R2 0.4392
# Epoch 044 | TrainLoss 15.4517 | RMSE 1.0192 | R2 0.6012
# Epoch 045 | TrainLoss 16.6357 | RMSE 1.1426 | R2 0.4987
# Epoch 046 | TrainLoss 16.9400 | RMSE 1.0878 | R2 0.5457
# Epoch 047 | TrainLoss 15.5769 | RMSE 1.1587 | R2 0.4845
# Epoch 048 | TrainLoss 17.2478 | RMSE 0.9696 | R2 0.6390
# Epoch 049 | TrainLoss 26.3144 | RMSE 1.4496 | R2 0.1932
# Epoch 050 | TrainLoss 19.4673 | RMSE 1.2471 | R2 0.4029
# Epoch 051 | TrainLoss 18.8362 | RMSE 1.1817 | R2 0.4638
# Epoch 052 | TrainLoss 15.7141 | RMSE 1.0451 | R2 0.5806
# Epoch 053 | TrainLoss 19.1454 | RMSE 1.2610 | R2 0.3894
# Epoch 054 | TrainLoss 20.9749 | RMSE 0.9660 | R2 0.6417
# Epoch 055 | TrainLoss 19.4160 | RMSE 1.2912 | R2 0.3598
# Epoch 056 | TrainLoss 20.0778 | RMSE 0.8648 | R2 0.7128
# Epoch 057 | TrainLoss 16.7897 | RMSE 1.2254 | R2 0.4234
# Epoch 058 | TrainLoss 14.4922 | RMSE 0.9781 | R2 0.6327
# Epoch 059 | TrainLoss 21.4382 | RMSE 1.3276 | R2 0.3233
# Epoch 060 | TrainLoss 16.3174 | RMSE 1.2233 | R2 0.4254
# Epoch 061 | TrainLoss 19.1870 | RMSE 1.2803 | R2 0.3706
# Epoch 062 | TrainLoss 14.2490 | RMSE 1.0286 | R2 0.5937
# Epoch 063 | TrainLoss 16.2455 | RMSE 1.2330 | R2 0.4163
# Epoch 064 | TrainLoss 17.6901 | RMSE 1.3669 | R2 0.2825
# Epoch 065 | TrainLoss 20.0060 | RMSE 0.9232 | R2 0.6728
# Epoch 066 | TrainLoss 15.2778 | RMSE 1.0854 | R2 0.5476
# Epoch 067 | TrainLoss 15.1006 | RMSE 1.1333 | R2 0.5069
# Epoch 068 | TrainLoss 13.4688 | RMSE 1.1384 | R2 0.5024
# Epoch 069 | TrainLoss 14.5810 | RMSE 1.0401 | R2 0.5846
# Epoch 070 | TrainLoss 16.7603 | RMSE 1.1504 | R2 0.4918
# Epoch 071 | TrainLoss 17.3544 | RMSE 1.0684 | R2 0.5617
# Epoch 072 | TrainLoss 13.8932 | RMSE 1.0962 | R2 0.5386
# Epoch 073 | TrainLoss 15.7196 | RMSE 1.2873 | R2 0.3637
# Epoch 074 | TrainLoss 14.0657 | RMSE 1.0125 | R2 0.6064
# Epoch 075 | TrainLoss 13.8544 | RMSE 1.1087 | R2 0.5280
# Epoch 076 | TrainLoss 12.7444 | RMSE 1.0442 | R2 0.5814
# Epoch 077 | TrainLoss 13.3561 | RMSE 1.2401 | R2 0.4095
# Epoch 078 | TrainLoss 16.8205 | RMSE 1.1153 | R2 0.5224
# Epoch 079 | TrainLoss 15.0736 | RMSE 0.9752 | R2 0.6349
# Epoch 080 | TrainLoss 16.2984 | RMSE 1.1673 | R2 0.4768
# Epoch 081 | TrainLoss 13.2257 | RMSE 0.9079 | R2 0.6835
# Epoch 082 | TrainLoss 14.0785 | RMSE 1.0879 | R2 0.5456
# Epoch 083 | TrainLoss 12.8863 | RMSE 1.0628 | R2 0.5663
# Epoch 084 | TrainLoss 14.5733 | RMSE 1.2197 | R2 0.4288
# Epoch 085 | TrainLoss 16.3410 | RMSE 1.0658 | R2 0.5638
# Epoch 086 | TrainLoss 14.3770 | RMSE 0.9632 | R2 0.6438
# Epoch 087 | TrainLoss 15.3348 | RMSE 1.0504 | R2 0.5764
# Epoch 088 | TrainLoss 15.0838 | RMSE 1.0885 | R2 0.5451
# Epoch 089 | TrainLoss 13.4451 | RMSE 1.2860 | R2 0.3650
# Epoch 090 | TrainLoss 14.0583 | RMSE 1.1144 | R2 0.5232
# Epoch 091 | TrainLoss 12.1732 | RMSE 1.0866 | R2 0.5467
# Epoch 092 | TrainLoss 20.7653 | RMSE 1.2802 | R2 0.3708
# Epoch 093 | TrainLoss 13.1575 | RMSE 0.9085 | R2 0.6831
# Epoch 094 | TrainLoss 13.4023 | RMSE 0.8758 | R2 0.7055
# Epoch 095 | TrainLoss 18.5043 | RMSE 1.0689 | R2 0.5613
# Epoch 096 | TrainLoss 14.0031 | RMSE 1.1484 | R2 0.4936
# Epoch 097 | TrainLoss 13.8383 | RMSE 0.8239 | R2 0.7394
# Epoch 098 | TrainLoss 13.3207 | RMSE 0.9510 | R2 0.6527
# Epoch 099 | TrainLoss 14.7972 | RMSE 1.0285 | R2 0.5938
# Epoch 100 | TrainLoss 10.0248 | RMSE 0.9384 | R2 0.6619
# Epoch 101 | TrainLoss 11.8798 | RMSE 1.0517 | R2 0.5753
# Epoch 102 | TrainLoss 11.7105 | RMSE 1.0851 | R2 0.5479
# Epoch 103 | TrainLoss 10.5689 | RMSE 0.9287 | R2 0.6689
# Epoch 104 | TrainLoss 11.2204 | RMSE 1.0447 | R2 0.5809
# Epoch 105 | TrainLoss 10.8343 | RMSE 0.9036 | R2 0.6865
# Epoch 106 | TrainLoss 9.8700 | RMSE 0.9941 | R2 0.6205
# Epoch 107 | TrainLoss 11.1480 | RMSE 0.8929 | R2 0.6939
# Epoch 108 | TrainLoss 10.5601 | RMSE 0.9167 | R2 0.6774
# Epoch 109 | TrainLoss 14.8248 | RMSE 1.0754 | R2 0.5560
# Epoch 110 | TrainLoss 10.9134 | RMSE 1.0411 | R2 0.5838
# Epoch 111 | TrainLoss 9.9144 | RMSE 0.9508 | R2 0.6529
# Epoch 112 | TrainLoss 9.5035 | RMSE 1.0599 | R2 0.5687
# Epoch 113 | TrainLoss 11.0481 | RMSE 0.8624 | R2 0.7144
# Epoch 114 | TrainLoss 12.8365 | RMSE 1.0551 | R2 0.5726
# Epoch 115 | TrainLoss 13.3007 | RMSE 0.8520 | R2 0.7212
# Epoch 116 | TrainLoss 12.0880 | RMSE 0.8101 | R2 0.7480
# Epoch 117 | TrainLoss 9.0433 | RMSE 0.9774 | R2 0.6332
# Epoch 118 | TrainLoss 9.5250 | RMSE 0.9157 | R2 0.6780
# Epoch 119 | TrainLoss 10.6097 | RMSE 0.9326 | R2 0.6661
# Epoch 120 | TrainLoss 9.0676 | RMSE 0.9342 | R2 0.6649
# Epoch 121 | TrainLoss 9.8207 | RMSE 0.9331 | R2 0.6657
# Epoch 122 | TrainLoss 9.9231 | RMSE 0.8743 | R2 0.7065
# Epoch 123 | TrainLoss 8.6593 | RMSE 0.8203 | R2 0.7416
# Epoch 124 | TrainLoss 9.6783 | RMSE 0.9423 | R2 0.6591
# Epoch 125 | TrainLoss 14.4740 | RMSE 0.9854 | R2 0.6271
# Epoch 126 | TrainLoss 12.7785 | RMSE 1.0073 | R2 0.6104
# Epoch 127 | TrainLoss 12.6032 | RMSE 1.0799 | R2 0.5522
# Epoch 128 | TrainLoss 14.6463 | RMSE 1.0966 | R2 0.5383
# Epoch 129 | TrainLoss 11.0265 | RMSE 0.8634 | R2 0.7138
# Epoch 130 | TrainLoss 9.0058 | RMSE 0.8841 | R2 0.6999
# Epoch 131 | TrainLoss 11.0091 | RMSE 1.1457 | R2 0.4960
# Epoch 132 | TrainLoss 12.4545 | RMSE 0.9160 | R2 0.6779
# Epoch 133 | TrainLoss 10.6383 | RMSE 1.1788 | R2 0.4665
# Epoch 134 | TrainLoss 10.0997 | RMSE 1.0653 | R2 0.5643
# Epoch 135 | TrainLoss 8.6851 | RMSE 0.9722 | R2 0.6371
# Epoch 136 | TrainLoss 8.4400 | RMSE 1.1867 | R2 0.4593
# Epoch 137 | TrainLoss 10.4177 | RMSE 0.9147 | R2 0.6788
# Epoch 138 | TrainLoss 8.7668 | RMSE 0.9882 | R2 0.6251
# Epoch 139 | TrainLoss 8.8244 | RMSE 0.9713 | R2 0.6378
# Epoch 140 | TrainLoss 9.0424 | RMSE 0.9397 | R2 0.6610
# Epoch 141 | TrainLoss 10.5976 | RMSE 0.8482 | R2 0.7238
# Epoch 142 | TrainLoss 14.6490 | RMSE 1.0916 | R2 0.5425
# Epoch 143 | TrainLoss 14.4905 | RMSE 0.7592 | R2 0.7787
# Epoch 144 | TrainLoss 9.8271 | RMSE 0.9578 | R2 0.6478
# Epoch 145 | TrainLoss 14.5139 | RMSE 0.8561 | R2 0.7186
# Epoch 146 | TrainLoss 14.0941 | RMSE 0.8473 | R2 0.7244
# Epoch 147 | TrainLoss 11.5492 | RMSE 0.9496 | R2 0.6538
# Epoch 148 | TrainLoss 7.9240 | RMSE 0.9634 | R2 0.6436
# Epoch 149 | TrainLoss 7.6210 | RMSE 0.9315 | R2 0.6668
# Epoch 150 | TrainLoss 9.1510 | RMSE 1.0560 | R2 0.5719
# Epoch 151 | TrainLoss 9.9719 | RMSE 0.9650 | R2 0.6424
# Epoch 152 | TrainLoss 8.7676 | RMSE 0.9073 | R2 0.6839
# Epoch 153 | TrainLoss 8.3616 | RMSE 0.9255 | R2 0.6711
# Epoch 154 | TrainLoss 9.8579 | RMSE 0.9924 | R2 0.6218
# Epoch 155 | TrainLoss 7.5999 | RMSE 1.0883 | R2 0.5453
# Epoch 156 | TrainLoss 7.5272 | RMSE 0.9611 | R2 0.6453
# Epoch 157 | TrainLoss 7.5632 | RMSE 1.0240 | R2 0.5974
# Epoch 158 | TrainLoss 7.7528 | RMSE 0.9813 | R2 0.6303
# Epoch 159 | TrainLoss 10.1324 | RMSE 0.8602 | R2 0.7159
# Epoch 160 | TrainLoss 8.1221 | RMSE 1.0258 | R2 0.5960
# Epoch 161 | TrainLoss 8.6352 | RMSE 0.8884 | R2 0.6970
# Epoch 162 | TrainLoss 8.5893 | RMSE 0.9250 | R2 0.6715
# Epoch 163 | TrainLoss 8.3748 | RMSE 1.0411 | R2 0.5839
# Epoch 164 | TrainLoss 7.3971 | RMSE 0.9737 | R2 0.6360
# Epoch 165 | TrainLoss 7.5270 | RMSE 1.1359 | R2 0.5045
# Epoch 166 | TrainLoss 7.6400 | RMSE 0.9204 | R2 0.6747
# Epoch 167 | TrainLoss 8.4634 | RMSE 0.8661 | R2 0.7120
# Epoch 168 | TrainLoss 7.5692 | RMSE 0.8871 | R2 0.6978
# Epoch 169 | TrainLoss 6.7343 | RMSE 1.0823 | R2 0.5502
# Epoch 170 | TrainLoss 7.1323 | RMSE 0.8485 | R2 0.7236
# Epoch 171 | TrainLoss 7.8616 | RMSE 1.0177 | R2 0.6023
# Epoch 172 | TrainLoss 18.3072 | RMSE 1.1871 | R2 0.4589
# Epoch 173 | TrainLoss 11.3499 | RMSE 1.0922 | R2 0.5420
# Epoch 174 | TrainLoss 7.8649 | RMSE 1.0594 | R2 0.5691
# Epoch 175 | TrainLoss 9.7079 | RMSE 1.0102 | R2 0.6082
# Epoch 176 | TrainLoss 8.8926 | RMSE 0.9995 | R2 0.6164
# Epoch 177 | TrainLoss 8.6430 | RMSE 0.9572 | R2 0.6482
# Epoch 178 | TrainLoss 7.7250 | RMSE 1.1228 | R2 0.5159
# Epoch 179 | TrainLoss 14.1756 | RMSE 1.0941 | R2 0.5404
# Epoch 180 | TrainLoss 11.2270 | RMSE 0.9304 | R2 0.6676
# Epoch 181 | TrainLoss 8.5480 | RMSE 1.0576 | R2 0.5705
# Epoch 182 | TrainLoss 6.6914 | RMSE 0.8620 | R2 0.7147
# Epoch 183 | TrainLoss 8.3529 | RMSE 1.1207 | R2 0.5177
# Epoch 184 | TrainLoss 6.9046 | RMSE 0.9436 | R2 0.6581
# Epoch 185 | TrainLoss 6.9843 | RMSE 0.9444 | R2 0.6575
# Epoch 186 | TrainLoss 6.3258 | RMSE 1.0486 | R2 0.5778
# Epoch 187 | TrainLoss 6.5374 | RMSE 1.0275 | R2 0.5947
# Epoch 188 | TrainLoss 6.7813 | RMSE 1.0052 | R2 0.6120
# Epoch 189 | TrainLoss 5.9282 | RMSE 1.0073 | R2 0.6104
# Epoch 190 | TrainLoss 6.2594 | RMSE 1.0335 | R2 0.5899
# Epoch 191 | TrainLoss 7.5705 | RMSE 1.2237 | R2 0.4250
# Epoch 192 | TrainLoss 7.5213 | RMSE 1.2570 | R2 0.3933
# Epoch 193 | TrainLoss 6.9578 | RMSE 0.9445 | R2 0.6574
# Early stopping triggered
#
# [FOLD 0 FINAL]
# MSE : 0.5763
# RMSE: 0.7592
# MAE : 0.5030
# R2  : 0.7787
#
# ==== Full Fold 1 ====
# Epoch 000 | TrainLoss 1055.1264 | RMSE 5.0291 | R2 -6.4084
# Epoch 001 | TrainLoss 625.4726 | RMSE 3.6097 | R2 -2.8168
# Epoch 002 | TrainLoss 291.5857 | RMSE 2.2395 | R2 -0.4691
# Epoch 003 | TrainLoss 115.3681 | RMSE 1.4564 | R2 0.3787
# Epoch 004 | TrainLoss 65.7429 | RMSE 1.3560 | R2 0.4614
# Epoch 005 | TrainLoss 58.6143 | RMSE 1.4228 | R2 0.4070
# Epoch 006 | TrainLoss 54.5345 | RMSE 1.7600 | R2 0.0926
# Epoch 007 | TrainLoss 56.0911 | RMSE 1.3468 | R2 0.4687
# Epoch 008 | TrainLoss 51.2755 | RMSE 1.4584 | R2 0.3770
# Epoch 009 | TrainLoss 49.5706 | RMSE 1.6445 | R2 0.2079
# Epoch 010 | TrainLoss 49.3808 | RMSE 1.3561 | R2 0.4613
# Epoch 011 | TrainLoss 46.4179 | RMSE 1.1250 | R2 0.6293
# Epoch 012 | TrainLoss 46.6089 | RMSE 1.0316 | R2 0.6883
# Epoch 013 | TrainLoss 48.1819 | RMSE 1.2817 | R2 0.5188
# Epoch 014 | TrainLoss 41.6351 | RMSE 1.7535 | R2 0.0994
# Epoch 015 | TrainLoss 43.5950 | RMSE 1.4991 | R2 0.3417
# Epoch 016 | TrainLoss 46.3759 | RMSE 1.5859 | R2 0.2633
# Epoch 017 | TrainLoss 39.1890 | RMSE 1.3410 | R2 0.4732
# Epoch 018 | TrainLoss 35.9235 | RMSE 1.0095 | R2 0.7015
# Epoch 019 | TrainLoss 34.6416 | RMSE 1.2678 | R2 0.5292
# Epoch 020 | TrainLoss 31.5148 | RMSE 1.2774 | R2 0.5220
# Epoch 021 | TrainLoss 31.1074 | RMSE 0.8589 | R2 0.7839
# Epoch 022 | TrainLoss 36.3614 | RMSE 1.4865 | R2 0.3528
# Epoch 023 | TrainLoss 31.9348 | RMSE 1.4649 | R2 0.3715
# Epoch 024 | TrainLoss 28.1721 | RMSE 1.5260 | R2 0.3179
# Epoch 025 | TrainLoss 30.6453 | RMSE 1.6481 | R2 0.2044
# Epoch 026 | TrainLoss 26.5861 | RMSE 1.4684 | R2 0.3684
# Epoch 027 | TrainLoss 27.0905 | RMSE 1.7493 | R2 0.1036
# Epoch 028 | TrainLoss 27.0478 | RMSE 1.6608 | R2 0.1920
# Epoch 029 | TrainLoss 28.3012 | RMSE 1.4696 | R2 0.3674
# Epoch 030 | TrainLoss 35.5227 | RMSE 1.2559 | R2 0.5380
# Epoch 031 | TrainLoss 23.3663 | RMSE 1.6701 | R2 0.1830
# Epoch 032 | TrainLoss 24.5250 | RMSE 1.5026 | R2 0.3387
# Epoch 033 | TrainLoss 24.5460 | RMSE 1.2721 | R2 0.5260
# Epoch 034 | TrainLoss 21.2651 | RMSE 1.6694 | R2 0.1836
# Epoch 035 | TrainLoss 26.6528 | RMSE 1.6821 | R2 0.1711
# Epoch 036 | TrainLoss 24.2029 | RMSE 1.4000 | R2 0.4259
# Epoch 037 | TrainLoss 22.7844 | RMSE 1.6697 | R2 0.1834
# Epoch 038 | TrainLoss 33.5953 | RMSE 1.6536 | R2 0.1991
# Epoch 039 | TrainLoss 39.4832 | RMSE 1.3818 | R2 0.4407
# Epoch 040 | TrainLoss 35.1220 | RMSE 1.2273 | R2 0.5588
# Epoch 041 | TrainLoss 30.0044 | RMSE 1.2487 | R2 0.5432
# Epoch 042 | TrainLoss 21.1634 | RMSE 1.4985 | R2 0.3422
# Epoch 043 | TrainLoss 16.8774 | RMSE 1.3290 | R2 0.4826
# Epoch 044 | TrainLoss 15.9108 | RMSE 1.4467 | R2 0.3869
# Epoch 045 | TrainLoss 15.3267 | RMSE 1.4835 | R2 0.3554
# Epoch 046 | TrainLoss 18.6042 | RMSE 1.6132 | R2 0.2377
# Epoch 047 | TrainLoss 17.6525 | RMSE 1.6917 | R2 0.1617
# Epoch 048 | TrainLoss 19.4243 | RMSE 1.4316 | R2 0.3997
# Epoch 049 | TrainLoss 18.3644 | RMSE 1.5622 | R2 0.2851
# Epoch 050 | TrainLoss 13.7845 | RMSE 1.6963 | R2 0.1571
# Epoch 051 | TrainLoss 14.3642 | RMSE 1.5947 | R2 0.2551
# Epoch 052 | TrainLoss 17.0865 | RMSE 1.5867 | R2 0.2625
# Epoch 053 | TrainLoss 17.0132 | RMSE 1.0763 | R2 0.6607
# Epoch 054 | TrainLoss 26.0165 | RMSE 1.1553 | R2 0.6091
# Epoch 055 | TrainLoss 25.1622 | RMSE 1.2568 | R2 0.5373
# Epoch 056 | TrainLoss 19.8887 | RMSE 1.6251 | R2 0.2264
# Epoch 057 | TrainLoss 13.3489 | RMSE 1.6305 | R2 0.2213
# Epoch 058 | TrainLoss 11.7488 | RMSE 1.6013 | R2 0.2489
# Epoch 059 | TrainLoss 10.5034 | RMSE 1.6321 | R2 0.2197
# Epoch 060 | TrainLoss 11.4550 | RMSE 1.8050 | R2 0.0456
# Epoch 061 | TrainLoss 11.2626 | RMSE 1.6858 | R2 0.1675
# Epoch 062 | TrainLoss 15.3853 | RMSE 1.6137 | R2 0.2372
# Epoch 063 | TrainLoss 9.8591 | RMSE 1.7464 | R2 0.1066
# Epoch 064 | TrainLoss 10.0101 | RMSE 1.7341 | R2 0.1192
# Epoch 065 | TrainLoss 11.5438 | RMSE 1.7716 | R2 0.0806
# Epoch 066 | TrainLoss 10.8658 | RMSE 1.7146 | R2 0.1388
# Epoch 067 | TrainLoss 10.5210 | RMSE 1.7342 | R2 0.1191
# Epoch 068 | TrainLoss 9.9646 | RMSE 1.6997 | R2 0.1537
# Epoch 069 | TrainLoss 11.0554 | RMSE 1.7000 | R2 0.1535
# Epoch 070 | TrainLoss 11.6834 | RMSE 1.8899 | R2 -0.0463
# Epoch 071 | TrainLoss 13.5964 | RMSE 1.7953 | R2 0.0559
# Early stopping triggered
#
# [FOLD 1 FINAL]
# MSE : 0.7376
# RMSE: 0.8589
# MAE : 0.4856
# R2  : 0.7839
#
# ==== Full Fold 2 ====
# Epoch 000 | TrainLoss 986.6714 | RMSE 4.7696 | R2 -8.3173
# Epoch 001 | TrainLoss 537.0028 | RMSE 3.2435 | R2 -3.3088
# Epoch 002 | TrainLoss 245.8797 | RMSE 1.9348 | R2 -0.5332
# Epoch 003 | TrainLoss 107.5609 | RMSE 1.3007 | R2 0.3071
# Epoch 004 | TrainLoss 66.5928 | RMSE 1.0812 | R2 0.5212
# Epoch 005 | TrainLoss 61.0929 | RMSE 1.0645 | R2 0.5359
# Epoch 006 | TrainLoss 63.2126 | RMSE 1.1301 | R2 0.4769
# Epoch 007 | TrainLoss 61.3800 | RMSE 1.1900 | R2 0.4200
# Epoch 008 | TrainLoss 61.7252 | RMSE 1.0744 | R2 0.5272
# Epoch 009 | TrainLoss 58.9566 | RMSE 1.0153 | R2 0.5778
# Epoch 010 | TrainLoss 60.5244 | RMSE 1.2276 | R2 0.3827
# Epoch 011 | TrainLoss 61.5478 | RMSE 1.0173 | R2 0.5761
# Epoch 012 | TrainLoss 56.5672 | RMSE 1.0554 | R2 0.5438
# Epoch 013 | TrainLoss 53.6130 | RMSE 0.8965 | R2 0.6708
# Epoch 014 | TrainLoss 52.5403 | RMSE 0.9296 | R2 0.6461
# Epoch 015 | TrainLoss 51.2486 | RMSE 0.9438 | R2 0.6352
# Epoch 016 | TrainLoss 52.5249 | RMSE 0.9065 | R2 0.6635
# Epoch 017 | TrainLoss 55.0853 | RMSE 0.7638 | R2 0.7611
# Epoch 018 | TrainLoss 54.5392 | RMSE 0.8337 | R2 0.7153
# Epoch 019 | TrainLoss 49.7339 | RMSE 1.2048 | R2 0.4055
# Epoch 020 | TrainLoss 52.7967 | RMSE 0.6949 | R2 0.8022
# Epoch 021 | TrainLoss 47.4187 | RMSE 0.8923 | R2 0.6739
# Epoch 022 | TrainLoss 45.7044 | RMSE 0.7475 | R2 0.7711
# Epoch 023 | TrainLoss 39.6284 | RMSE 0.7332 | R2 0.7798
# Epoch 024 | TrainLoss 41.3764 | RMSE 1.0434 | R2 0.5541
# Epoch 025 | TrainLoss 37.8258 | RMSE 0.9651 | R2 0.6185
# Epoch 026 | TrainLoss 36.5681 | RMSE 1.0786 | R2 0.5235
# Epoch 027 | TrainLoss 37.0773 | RMSE 0.9557 | R2 0.6259
# Epoch 028 | TrainLoss 43.1670 | RMSE 0.7484 | R2 0.7706
# Epoch 029 | TrainLoss 39.1084 | RMSE 0.8869 | R2 0.6779
# Epoch 030 | TrainLoss 34.7055 | RMSE 0.9683 | R2 0.6160
# Epoch 031 | TrainLoss 35.8902 | RMSE 1.1720 | R2 0.4374
# Epoch 032 | TrainLoss 32.5411 | RMSE 1.0932 | R2 0.5105
# Epoch 033 | TrainLoss 39.0303 | RMSE 1.1300 | R2 0.4770
# Epoch 034 | TrainLoss 34.9226 | RMSE 1.1243 | R2 0.4822
# Epoch 035 | TrainLoss 37.3706 | RMSE 1.1167 | R2 0.4892
# Epoch 036 | TrainLoss 33.4273 | RMSE 1.1910 | R2 0.4190
# Epoch 037 | TrainLoss 31.8322 | RMSE 1.1831 | R2 0.4267
# Epoch 038 | TrainLoss 32.5016 | RMSE 1.0869 | R2 0.5161
# Epoch 039 | TrainLoss 34.9945 | RMSE 1.1230 | R2 0.4835
# Epoch 040 | TrainLoss 34.7736 | RMSE 0.9192 | R2 0.6539
# Epoch 041 | TrainLoss 28.4821 | RMSE 1.2251 | R2 0.3853
# Epoch 042 | TrainLoss 28.2701 | RMSE 1.0632 | R2 0.5371
# Epoch 043 | TrainLoss 30.7225 | RMSE 1.1904 | R2 0.4196
# Epoch 044 | TrainLoss 34.9378 | RMSE 1.2221 | R2 0.3883
# Epoch 045 | TrainLoss 29.8034 | RMSE 1.2157 | R2 0.3947
# Epoch 046 | TrainLoss 29.7156 | RMSE 1.0559 | R2 0.5433
# Epoch 047 | TrainLoss 26.5442 | RMSE 1.1175 | R2 0.4885
# Epoch 048 | TrainLoss 28.1493 | RMSE 1.1766 | R2 0.4330
# Epoch 049 | TrainLoss 24.5213 | RMSE 1.1994 | R2 0.4108
# Epoch 050 | TrainLoss 30.6202 | RMSE 1.3155 | R2 0.2913
# Epoch 051 | TrainLoss 27.0507 | RMSE 1.1896 | R2 0.4204
# Epoch 052 | TrainLoss 23.2373 | RMSE 1.3379 | R2 0.2669
# Epoch 053 | TrainLoss 18.9851 | RMSE 1.2089 | R2 0.4014
# Epoch 054 | TrainLoss 21.4014 | RMSE 1.2684 | R2 0.3410
# Epoch 055 | TrainLoss 25.0964 | RMSE 1.5349 | R2 0.0351
# Epoch 056 | TrainLoss 24.2755 | RMSE 1.4715 | R2 0.1132
# Epoch 057 | TrainLoss 26.8472 | RMSE 1.2360 | R2 0.3743
# Epoch 058 | TrainLoss 20.4450 | RMSE 1.3379 | R2 0.2668
# Epoch 059 | TrainLoss 20.3480 | RMSE 1.4001 | R2 0.1972
# Epoch 060 | TrainLoss 24.4756 | RMSE 1.2261 | R2 0.3843
# Epoch 061 | TrainLoss 22.6057 | RMSE 1.3217 | R2 0.2845
# Epoch 062 | TrainLoss 28.4227 | RMSE 1.1314 | R2 0.4757
# Epoch 063 | TrainLoss 22.6326 | RMSE 1.4266 | R2 0.1665
# Epoch 064 | TrainLoss 39.4447 | RMSE 1.0943 | R2 0.5095
# Epoch 065 | TrainLoss 28.0502 | RMSE 1.1279 | R2 0.4789
# Epoch 066 | TrainLoss 23.3217 | RMSE 1.4137 | R2 0.1815
# Epoch 067 | TrainLoss 29.7928 | RMSE 1.3592 | R2 0.2433
# Epoch 068 | TrainLoss 26.3098 | RMSE 1.5764 | R2 -0.0178
# Epoch 069 | TrainLoss 22.2754 | RMSE 1.2940 | R2 0.3142
# Epoch 070 | TrainLoss 25.6664 | RMSE 1.2198 | R2 0.3905
# Early stopping triggered
#
# [FOLD 2 FINAL]
# MSE : 0.4829
# RMSE: 0.6949
# MAE : 0.6068
# R2  : 0.8022
#
# ==== Full Fold 3 ====
# Epoch 000 | TrainLoss 1002.5842 | RMSE 5.6913 | R2 -8.3772
# Epoch 001 | TrainLoss 605.2845 | RMSE 4.4562 | R2 -4.7487
# Epoch 002 | TrainLoss 322.6558 | RMSE 3.1894 | R2 -1.9448
# Epoch 003 | TrainLoss 148.0063 | RMSE 2.1489 | R2 -0.3368
# Epoch 004 | TrainLoss 75.8616 | RMSE 1.5358 | R2 0.3172
# Epoch 005 | TrainLoss 58.7669 | RMSE 1.4056 | R2 0.4280
# Epoch 006 | TrainLoss 55.2908 | RMSE 1.3864 | R2 0.4435
# Epoch 007 | TrainLoss 53.8012 | RMSE 1.2572 | R2 0.5424
# Epoch 008 | TrainLoss 51.3614 | RMSE 1.2396 | R2 0.5551
# Epoch 009 | TrainLoss 51.3051 | RMSE 1.2675 | R2 0.5349
# Epoch 010 | TrainLoss 48.7724 | RMSE 1.2093 | R2 0.5766
# Epoch 011 | TrainLoss 48.5468 | RMSE 1.4309 | R2 0.4072
# Epoch 012 | TrainLoss 48.1553 | RMSE 1.3326 | R2 0.4859
# Epoch 013 | TrainLoss 44.6024 | RMSE 1.6388 | R2 0.2225
# Epoch 014 | TrainLoss 43.1664 | RMSE 1.2789 | R2 0.5265
# Epoch 015 | TrainLoss 46.2501 | RMSE 1.3505 | R2 0.4720
# Epoch 016 | TrainLoss 36.5346 | RMSE 1.2147 | R2 0.5729
# Epoch 017 | TrainLoss 41.4191 | RMSE 1.3569 | R2 0.4670
# Epoch 018 | TrainLoss 38.6646 | RMSE 1.3195 | R2 0.4960
# Epoch 019 | TrainLoss 37.1260 | RMSE 1.2938 | R2 0.5154
# Epoch 020 | TrainLoss 36.9272 | RMSE 1.4972 | R2 0.3510
# Epoch 021 | TrainLoss 32.8606 | RMSE 1.5890 | R2 0.2691
# Epoch 022 | TrainLoss 33.1899 | RMSE 1.5901 | R2 0.2680
# Epoch 023 | TrainLoss 35.0029 | RMSE 1.2466 | R2 0.5502
# Epoch 024 | TrainLoss 29.8332 | RMSE 1.3939 | R2 0.4375
# Epoch 025 | TrainLoss 28.7135 | RMSE 1.1488 | R2 0.6179
# Epoch 026 | TrainLoss 35.1836 | RMSE 1.2694 | R2 0.5335
# Epoch 027 | TrainLoss 31.1401 | RMSE 1.4752 | R2 0.3700
# Epoch 028 | TrainLoss 30.3858 | RMSE 1.4163 | R2 0.4193
# Epoch 029 | TrainLoss 27.8810 | RMSE 1.5595 | R2 0.2959
# Epoch 030 | TrainLoss 31.0815 | RMSE 1.5219 | R2 0.3295
# Epoch 031 | TrainLoss 32.9882 | RMSE 1.3828 | R2 0.4464
# Epoch 032 | TrainLoss 26.6430 | RMSE 1.3580 | R2 0.4661
# Epoch 033 | TrainLoss 27.3198 | RMSE 1.0999 | R2 0.6498
# Epoch 034 | TrainLoss 29.8347 | RMSE 1.1513 | R2 0.6163
# Epoch 035 | TrainLoss 31.8257 | RMSE 1.4221 | R2 0.4146
# Epoch 036 | TrainLoss 26.2493 | RMSE 1.2900 | R2 0.5182
# Epoch 037 | TrainLoss 27.9512 | RMSE 1.0790 | R2 0.6630
# Epoch 038 | TrainLoss 26.1093 | RMSE 1.1920 | R2 0.5887
# Epoch 039 | TrainLoss 26.5428 | RMSE 1.5176 | R2 0.3333
# Epoch 040 | TrainLoss 24.1024 | RMSE 1.4268 | R2 0.4107
# Epoch 041 | TrainLoss 22.4642 | RMSE 1.2621 | R2 0.5389
# Epoch 042 | TrainLoss 25.6350 | RMSE 1.4016 | R2 0.4313
# Epoch 043 | TrainLoss 25.7058 | RMSE 1.3385 | R2 0.4813
# Epoch 044 | TrainLoss 28.4126 | RMSE 1.2978 | R2 0.5124
# Epoch 045 | TrainLoss 20.9307 | RMSE 1.3339 | R2 0.4849
# Epoch 046 | TrainLoss 19.5237 | RMSE 1.1670 | R2 0.6057
# Epoch 047 | TrainLoss 14.9014 | RMSE 1.1320 | R2 0.6290
# Epoch 048 | TrainLoss 25.2041 | RMSE 1.1944 | R2 0.5870
# Epoch 049 | TrainLoss 20.9758 | RMSE 1.1952 | R2 0.5865
# Epoch 050 | TrainLoss 17.5039 | RMSE 1.4553 | R2 0.3869
# Epoch 051 | TrainLoss 19.6751 | RMSE 1.0460 | R2 0.6833
# Epoch 052 | TrainLoss 16.3351 | RMSE 1.1046 | R2 0.6467
# Epoch 053 | TrainLoss 16.9685 | RMSE 1.2086 | R2 0.5771
# Epoch 054 | TrainLoss 14.3782 | RMSE 1.1076 | R2 0.6449
# Epoch 055 | TrainLoss 27.9991 | RMSE 1.1290 | R2 0.6310
# Epoch 056 | TrainLoss 15.6340 | RMSE 0.9711 | R2 0.7270
# Epoch 057 | TrainLoss 14.9794 | RMSE 1.0891 | R2 0.6566
# Epoch 058 | TrainLoss 18.6413 | RMSE 1.5258 | R2 0.3260
# Epoch 059 | TrainLoss 16.5844 | RMSE 1.1117 | R2 0.6422
# Epoch 060 | TrainLoss 15.5573 | RMSE 1.3700 | R2 0.4566
# Epoch 061 | TrainLoss 19.0513 | RMSE 0.9832 | R2 0.7201
# Epoch 062 | TrainLoss 14.5867 | RMSE 0.9724 | R2 0.7263
# Epoch 063 | TrainLoss 14.4743 | RMSE 1.0023 | R2 0.7092
# Epoch 064 | TrainLoss 15.8171 | RMSE 1.0254 | R2 0.6956
# Epoch 065 | TrainLoss 28.5019 | RMSE 1.2056 | R2 0.5792
# Epoch 066 | TrainLoss 14.4708 | RMSE 0.9509 | R2 0.7382
# Epoch 067 | TrainLoss 20.8959 | RMSE 1.3279 | R2 0.4896
# Epoch 068 | TrainLoss 16.3364 | RMSE 1.0465 | R2 0.6830
# Epoch 069 | TrainLoss 12.0667 | RMSE 1.1184 | R2 0.6379
# Epoch 070 | TrainLoss 11.6650 | RMSE 1.0262 | R2 0.6951
# Epoch 071 | TrainLoss 12.9897 | RMSE 1.0441 | R2 0.6844
# Epoch 072 | TrainLoss 12.9099 | RMSE 1.1028 | R2 0.6479
# Epoch 073 | TrainLoss 12.7693 | RMSE 1.0592 | R2 0.6752
# Epoch 074 | TrainLoss 13.6461 | RMSE 1.1419 | R2 0.6225
# Epoch 075 | TrainLoss 14.4484 | RMSE 1.0277 | R2 0.6942
# Epoch 076 | TrainLoss 12.7812 | RMSE 1.0400 | R2 0.6869
# Epoch 077 | TrainLoss 13.3507 | RMSE 1.1404 | R2 0.6235
# Epoch 078 | TrainLoss 15.5009 | RMSE 1.1185 | R2 0.6378
# Epoch 079 | TrainLoss 14.3348 | RMSE 1.0728 | R2 0.6668
# Epoch 080 | TrainLoss 21.7319 | RMSE 1.2093 | R2 0.5767
# Epoch 081 | TrainLoss 14.5286 | RMSE 1.0579 | R2 0.6760
# Epoch 082 | TrainLoss 12.6242 | RMSE 1.1527 | R2 0.6153
# Epoch 083 | TrainLoss 13.2818 | RMSE 1.1397 | R2 0.6239
# Epoch 084 | TrainLoss 11.5490 | RMSE 1.0655 | R2 0.6713
# Epoch 085 | TrainLoss 10.5993 | RMSE 1.0047 | R2 0.7078
# Epoch 086 | TrainLoss 11.0685 | RMSE 1.1212 | R2 0.6360
# Epoch 087 | TrainLoss 11.8265 | RMSE 1.2147 | R2 0.5728
# Epoch 088 | TrainLoss 12.7758 | RMSE 1.2341 | R2 0.5591
# Epoch 089 | TrainLoss 16.8611 | RMSE 0.9943 | R2 0.7138
# Epoch 090 | TrainLoss 11.9736 | RMSE 1.0194 | R2 0.6992
# Epoch 091 | TrainLoss 11.7531 | RMSE 1.0089 | R2 0.7053
# Epoch 092 | TrainLoss 15.1711 | RMSE 1.1154 | R2 0.6398
# Epoch 093 | TrainLoss 17.1333 | RMSE 1.5562 | R2 0.2989
# Epoch 094 | TrainLoss 14.2771 | RMSE 1.4942 | R2 0.3536
# Epoch 095 | TrainLoss 13.5923 | RMSE 1.2235 | R2 0.5666
# Epoch 096 | TrainLoss 12.7486 | RMSE 1.0505 | R2 0.6805
# Epoch 097 | TrainLoss 11.4401 | RMSE 1.2344 | R2 0.5589
# Epoch 098 | TrainLoss 12.9815 | RMSE 1.1936 | R2 0.5875
# Epoch 099 | TrainLoss 10.2120 | RMSE 1.1477 | R2 0.6187
# Epoch 100 | TrainLoss 14.6691 | RMSE 1.1269 | R2 0.6324
# Epoch 101 | TrainLoss 11.0216 | RMSE 1.1803 | R2 0.5967
# Epoch 102 | TrainLoss 14.0090 | RMSE 1.1391 | R2 0.6244
# Epoch 103 | TrainLoss 16.5879 | RMSE 1.3162 | R2 0.4985
# Epoch 104 | TrainLoss 17.3285 | RMSE 1.1892 | R2 0.5906
# Epoch 105 | TrainLoss 10.1549 | RMSE 1.1832 | R2 0.5947
# Epoch 106 | TrainLoss 9.6040 | RMSE 1.0465 | R2 0.6830
# Epoch 107 | TrainLoss 11.9871 | RMSE 1.1087 | R2 0.6441
# Epoch 108 | TrainLoss 13.1075 | RMSE 1.1013 | R2 0.6489
# Epoch 109 | TrainLoss 11.8542 | RMSE 1.2280 | R2 0.5634
# Epoch 110 | TrainLoss 9.9238 | RMSE 1.1378 | R2 0.6252
# Epoch 111 | TrainLoss 10.0012 | RMSE 1.1920 | R2 0.5887
# Epoch 112 | TrainLoss 9.3463 | RMSE 1.3963 | R2 0.4355
# Epoch 113 | TrainLoss 9.1615 | RMSE 1.2194 | R2 0.5695
# Epoch 114 | TrainLoss 8.6735 | RMSE 1.1782 | R2 0.5982
# Epoch 115 | TrainLoss 14.2639 | RMSE 1.3724 | R2 0.4548
# Epoch 116 | TrainLoss 8.7743 | RMSE 1.1679 | R2 0.6052
# Early stopping triggered
#
# [FOLD 3 FINAL]
# MSE : 0.9042
# RMSE: 0.9509
# MAE : 0.7242
# R2  : 0.7382
#
# ==== Full Fold 4 ====
# Epoch 000 | TrainLoss 1231.1202 | RMSE 5.7452 | R2 -7.1378
# Epoch 001 | TrainLoss 787.8753 | RMSE 4.5301 | R2 -4.0596
# Epoch 002 | TrainLoss 443.0158 | RMSE 3.2029 | R2 -1.5292
# Epoch 003 | TrainLoss 202.2452 | RMSE 2.1114 | R2 -0.0991
# Epoch 004 | TrainLoss 89.9965 | RMSE 1.5281 | R2 0.4243
# Epoch 005 | TrainLoss 63.4055 | RMSE 1.2652 | R2 0.6054
# Epoch 006 | TrainLoss 57.3691 | RMSE 1.2930 | R2 0.5878
# Epoch 007 | TrainLoss 54.5754 | RMSE 1.3632 | R2 0.5419
# Epoch 008 | TrainLoss 50.4987 | RMSE 1.3467 | R2 0.5529
# Epoch 009 | TrainLoss 52.9549 | RMSE 1.4175 | R2 0.5047
# Epoch 010 | TrainLoss 50.0536 | RMSE 1.4171 | R2 0.5049
# Epoch 011 | TrainLoss 47.9667 | RMSE 1.2629 | R2 0.6068
# Epoch 012 | TrainLoss 44.6107 | RMSE 1.5202 | R2 0.4303
# Epoch 013 | TrainLoss 44.9755 | RMSE 1.5385 | R2 0.4164
# Epoch 014 | TrainLoss 48.4098 | RMSE 1.2292 | R2 0.6275
# Epoch 015 | TrainLoss 41.3291 | RMSE 1.0876 | R2 0.7084
# Epoch 016 | TrainLoss 36.1534 | RMSE 1.2137 | R2 0.6368
# Epoch 017 | TrainLoss 37.0850 | RMSE 1.1911 | R2 0.6503
# Epoch 018 | TrainLoss 37.1353 | RMSE 1.3887 | R2 0.5246
# Epoch 019 | TrainLoss 28.9670 | RMSE 1.2428 | R2 0.6192
# Epoch 020 | TrainLoss 29.6117 | RMSE 0.9002 | R2 0.8002
# Epoch 021 | TrainLoss 34.9292 | RMSE 1.2827 | R2 0.5943
# Epoch 022 | TrainLoss 20.4148 | RMSE 2.0361 | R2 -0.0220
# Epoch 023 | TrainLoss 19.6708 | RMSE 1.8213 | R2 0.1822
# Epoch 024 | TrainLoss 22.8411 | RMSE 1.1792 | R2 0.6572
# Epoch 025 | TrainLoss 26.8231 | RMSE 1.8964 | R2 0.1133
# Epoch 026 | TrainLoss 24.3844 | RMSE 1.7789 | R2 0.2199
# Epoch 027 | TrainLoss 17.7202 | RMSE 1.5928 | R2 0.3745
# Epoch 028 | TrainLoss 15.2236 | RMSE 1.2990 | R2 0.5840
# Epoch 029 | TrainLoss 16.7495 | RMSE 1.0842 | R2 0.7102
# Epoch 030 | TrainLoss 15.5235 | RMSE 0.9743 | R2 0.7660
# Epoch 031 | TrainLoss 21.4233 | RMSE 2.3415 | R2 -0.3516
# Epoch 032 | TrainLoss 16.7868 | RMSE 1.2099 | R2 0.6391
# Epoch 033 | TrainLoss 15.7371 | RMSE 1.2435 | R2 0.6188
# Epoch 034 | TrainLoss 15.6112 | RMSE 2.0371 | R2 -0.0231
# Epoch 035 | TrainLoss 12.8691 | RMSE 1.4050 | R2 0.5133
# Epoch 036 | TrainLoss 10.6672 | RMSE 1.7876 | R2 0.2122
# Epoch 037 | TrainLoss 13.2862 | RMSE 1.7752 | R2 0.2230
# Epoch 038 | TrainLoss 14.7470 | RMSE 2.2295 | R2 -0.2255
# Epoch 039 | TrainLoss 23.1810 | RMSE 2.0380 | R2 -0.0240
# Epoch 040 | TrainLoss 15.6623 | RMSE 1.3551 | R2 0.5473
# Epoch 041 | TrainLoss 11.5573 | RMSE 1.4965 | R2 0.4478
# Epoch 042 | TrainLoss 12.2416 | RMSE 1.2695 | R2 0.6027
# Epoch 043 | TrainLoss 13.1640 | RMSE 2.0621 | R2 -0.0484
# Epoch 044 | TrainLoss 11.2928 | RMSE 1.4481 | R2 0.4830
# Epoch 045 | TrainLoss 12.0240 | RMSE 1.5772 | R2 0.3867
# Epoch 046 | TrainLoss 10.2461 | RMSE 1.4527 | R2 0.4797
# Epoch 047 | TrainLoss 10.4010 | RMSE 1.5440 | R2 0.4122
# Epoch 048 | TrainLoss 10.7301 | RMSE 1.7079 | R2 0.2809
# Epoch 049 | TrainLoss 11.0510 | RMSE 1.8110 | R2 0.1914
# Epoch 050 | TrainLoss 10.5198 | RMSE 1.2400 | R2 0.6209
# Epoch 051 | TrainLoss 9.6223 | RMSE 1.2365 | R2 0.6230
# Epoch 052 | TrainLoss 9.2833 | RMSE 1.7997 | R2 0.2014
# Epoch 053 | TrainLoss 9.9135 | RMSE 1.4352 | R2 0.4921
# Epoch 054 | TrainLoss 8.9653 | RMSE 1.5518 | R2 0.4063
# Epoch 055 | TrainLoss 8.2952 | RMSE 1.3143 | R2 0.5741
# Epoch 056 | TrainLoss 8.6654 | RMSE 1.3423 | R2 0.5558
# Epoch 057 | TrainLoss 8.6094 | RMSE 1.7162 | R2 0.2739
# Epoch 058 | TrainLoss 9.6738 | RMSE 1.9873 | R2 0.0263
# Epoch 059 | TrainLoss 11.5910 | RMSE 2.2667 | R2 -0.2667
# Epoch 060 | TrainLoss 9.4455 | RMSE 1.6370 | R2 0.3394
# Epoch 061 | TrainLoss 8.7538 | RMSE 1.8816 | R2 0.1271
# Epoch 062 | TrainLoss 8.7146 | RMSE 1.3143 | R2 0.5741
# Epoch 063 | TrainLoss 8.6682 | RMSE 1.9183 | R2 0.0927
# Epoch 064 | TrainLoss 10.2320 | RMSE 1.9197 | R2 0.0914
# Epoch 065 | TrainLoss 9.2691 | RMSE 1.6404 | R2 0.3366
# Epoch 066 | TrainLoss 8.5137 | RMSE 1.2894 | R2 0.5901
# Epoch 067 | TrainLoss 7.8756 | RMSE 1.7301 | R2 0.2621
# Epoch 068 | TrainLoss 8.3570 | RMSE 1.8854 | R2 0.1237
# Epoch 069 | TrainLoss 8.7101 | RMSE 1.6573 | R2 0.3228
# Epoch 070 | TrainLoss 7.5273 | RMSE 1.6377 | R2 0.3388
# Early stopping triggered
#
# [FOLD 4 FINAL]
# MSE : 0.8104
# RMSE: 0.9002
# MAE : 0.7447
# R2  : 0.8002
#
# ================================================================================
# Full
# ================================================================================
# FINAL 5-FOLD RESULT
# RMSE : 0.8328 ± 0.0934
# MAE  : 0.6129 ± 0.1078
# R2   : 0.7807 ± 0.0231
#
# ================================================================================
# Running Experiment : No_projection
# ================================================================================
#
# ==== No_projection Fold 0 ====
# Epoch 000 | TrainLoss 1112.0949 | RMSE 4.9769 | R2 -8.5105
# Epoch 001 | TrainLoss 614.1485 | RMSE 3.4209 | R2 -3.4934
# Epoch 002 | TrainLoss 278.2324 | RMSE 1.9839 | R2 -0.5112
# Epoch 003 | TrainLoss 102.8003 | RMSE 1.3993 | R2 0.2482
# Epoch 004 | TrainLoss 58.2462 | RMSE 1.5441 | R2 0.0845
# Epoch 005 | TrainLoss 54.6212 | RMSE 1.4628 | R2 0.1784
# Epoch 006 | TrainLoss 54.1079 | RMSE 1.4709 | R2 0.1693
# Epoch 007 | TrainLoss 56.7644 | RMSE 1.6248 | R2 -0.0137
# Epoch 008 | TrainLoss 54.4990 | RMSE 1.3868 | R2 0.2615
# Epoch 009 | TrainLoss 51.7111 | RMSE 1.4184 | R2 0.2275
# Epoch 010 | TrainLoss 50.5060 | RMSE 1.3847 | R2 0.2638
# Epoch 011 | TrainLoss 52.3086 | RMSE 1.2432 | R2 0.4066
# Epoch 012 | TrainLoss 53.3405 | RMSE 1.3123 | R2 0.3388
# Epoch 013 | TrainLoss 49.1816 | RMSE 1.5065 | R2 0.1286
# Epoch 014 | TrainLoss 49.7840 | RMSE 1.3671 | R2 0.2824
# Epoch 015 | TrainLoss 48.9282 | RMSE 1.6391 | R2 -0.0316
# Epoch 016 | TrainLoss 46.8798 | RMSE 1.4062 | R2 0.2407
# Epoch 017 | TrainLoss 44.3398 | RMSE 1.3174 | R2 0.3336
# Epoch 018 | TrainLoss 41.5119 | RMSE 1.2081 | R2 0.4396
# Epoch 019 | TrainLoss 42.5035 | RMSE 1.2890 | R2 0.3620
# Epoch 020 | TrainLoss 43.0462 | RMSE 1.7312 | R2 -0.1508
# Epoch 021 | TrainLoss 44.6720 | RMSE 1.1000 | R2 0.5354
# Epoch 022 | TrainLoss 36.5318 | RMSE 1.2484 | R2 0.4016
# Epoch 023 | TrainLoss 31.7054 | RMSE 1.3514 | R2 0.2988
# Epoch 024 | TrainLoss 42.8940 | RMSE 1.3025 | R2 0.3486
# Epoch 025 | TrainLoss 36.1891 | RMSE 1.5725 | R2 0.0506
# Epoch 026 | TrainLoss 35.5299 | RMSE 1.1753 | R2 0.4696
# Epoch 027 | TrainLoss 30.7252 | RMSE 1.1006 | R2 0.5349
# Epoch 028 | TrainLoss 27.6426 | RMSE 1.1405 | R2 0.5006
# Epoch 029 | TrainLoss 23.2969 | RMSE 1.2548 | R2 0.3955
# Epoch 030 | TrainLoss 28.7896 | RMSE 1.3225 | R2 0.3285
# Epoch 031 | TrainLoss 23.0552 | RMSE 1.2121 | R2 0.4359
# Epoch 032 | TrainLoss 19.4720 | RMSE 1.3367 | R2 0.3139
# Epoch 033 | TrainLoss 18.0686 | RMSE 1.2489 | R2 0.4011
# Epoch 034 | TrainLoss 14.1649 | RMSE 1.2350 | R2 0.4144
# Epoch 035 | TrainLoss 30.8279 | RMSE 1.1471 | R2 0.4947
# Epoch 036 | TrainLoss 32.4586 | RMSE 1.2540 | R2 0.3962
# Epoch 037 | TrainLoss 27.5940 | RMSE 1.2579 | R2 0.3925
# Epoch 038 | TrainLoss 21.5850 | RMSE 1.2417 | R2 0.4080
# Epoch 039 | TrainLoss 16.9177 | RMSE 1.2832 | R2 0.3677
# Epoch 040 | TrainLoss 19.1774 | RMSE 1.1680 | R2 0.4762
# Epoch 041 | TrainLoss 14.7097 | RMSE 1.6103 | R2 0.0044
# Epoch 042 | TrainLoss 16.2137 | RMSE 1.1847 | R2 0.4611
# Epoch 043 | TrainLoss 13.9656 | RMSE 1.0586 | R2 0.5697
# Epoch 044 | TrainLoss 17.3422 | RMSE 1.2001 | R2 0.4470
# Epoch 045 | TrainLoss 11.9311 | RMSE 1.1781 | R2 0.4671
# Epoch 046 | TrainLoss 14.8474 | RMSE 1.3601 | R2 0.2897
# Epoch 047 | TrainLoss 20.0208 | RMSE 1.2066 | R2 0.4410
# Epoch 048 | TrainLoss 10.8136 | RMSE 1.3845 | R2 0.2640
# Epoch 049 | TrainLoss 9.7784 | RMSE 1.4188 | R2 0.2271
# Epoch 050 | TrainLoss 11.2291 | RMSE 1.5032 | R2 0.1324
# Epoch 051 | TrainLoss 11.9081 | RMSE 1.3790 | R2 0.2699
# Epoch 052 | TrainLoss 16.1498 | RMSE 1.3603 | R2 0.2895
# Epoch 053 | TrainLoss 12.2165 | RMSE 1.1728 | R2 0.4719
# Epoch 054 | TrainLoss 8.6045 | RMSE 1.2027 | R2 0.4446
# Epoch 055 | TrainLoss 11.0496 | RMSE 1.1661 | R2 0.4779
# Epoch 056 | TrainLoss 10.2683 | RMSE 1.3446 | R2 0.3058
# Epoch 057 | TrainLoss 8.8091 | RMSE 1.2269 | R2 0.4220
# Epoch 058 | TrainLoss 10.9976 | RMSE 1.3603 | R2 0.2895
# Epoch 059 | TrainLoss 9.6289 | RMSE 1.1775 | R2 0.4677
# Epoch 060 | TrainLoss 7.7306 | RMSE 1.2515 | R2 0.3986
# Epoch 061 | TrainLoss 7.5831 | RMSE 1.1783 | R2 0.4669
# Epoch 062 | TrainLoss 7.0592 | RMSE 1.2948 | R2 0.3563
# Epoch 063 | TrainLoss 7.3928 | RMSE 1.3253 | R2 0.3256
# Epoch 064 | TrainLoss 11.0823 | RMSE 1.2456 | R2 0.4043
# Epoch 065 | TrainLoss 7.9382 | RMSE 1.3920 | R2 0.2561
# Epoch 066 | TrainLoss 8.0558 | RMSE 1.1282 | R2 0.5113
# Epoch 067 | TrainLoss 9.4746 | RMSE 1.3784 | R2 0.2704
# Epoch 068 | TrainLoss 8.5412 | RMSE 1.1812 | R2 0.4642
# Epoch 069 | TrainLoss 14.6389 | RMSE 1.3135 | R2 0.3376
# Epoch 070 | TrainLoss 13.9573 | RMSE 1.4401 | R2 0.2037
# Epoch 071 | TrainLoss 7.1618 | RMSE 1.1934 | R2 0.4531
# Epoch 072 | TrainLoss 7.2984 | RMSE 1.3709 | R2 0.2783
# Epoch 073 | TrainLoss 12.2604 | RMSE 1.3451 | R2 0.3053
# Epoch 074 | TrainLoss 12.7588 | RMSE 1.3709 | R2 0.2784
# Epoch 075 | TrainLoss 8.2192 | RMSE 1.4766 | R2 0.1628
# Epoch 076 | TrainLoss 7.5902 | RMSE 1.3382 | R2 0.3124
# Epoch 077 | TrainLoss 7.3661 | RMSE 1.4984 | R2 0.1379
# Epoch 078 | TrainLoss 6.7440 | RMSE 1.3473 | R2 0.3030
# Epoch 079 | TrainLoss 5.5434 | RMSE 1.3678 | R2 0.2816
# Epoch 080 | TrainLoss 5.4249 | RMSE 1.3919 | R2 0.2561
# Epoch 081 | TrainLoss 9.1821 | RMSE 1.3286 | R2 0.3222
# Epoch 082 | TrainLoss 5.4104 | RMSE 1.0886 | R2 0.5450
# Epoch 083 | TrainLoss 6.8014 | RMSE 1.1517 | R2 0.4907
# Epoch 084 | TrainLoss 6.1406 | RMSE 1.3412 | R2 0.3093
# Epoch 085 | TrainLoss 5.7014 | RMSE 1.3198 | R2 0.3311
# Epoch 086 | TrainLoss 3.9272 | RMSE 1.2022 | R2 0.4451
# Epoch 087 | TrainLoss 3.3998 | RMSE 1.2305 | R2 0.4187
# Epoch 088 | TrainLoss 4.3828 | RMSE 1.3768 | R2 0.2722
# Epoch 089 | TrainLoss 6.2039 | RMSE 1.3371 | R2 0.3135
# Epoch 090 | TrainLoss 6.0148 | RMSE 1.1247 | R2 0.5143
# Epoch 091 | TrainLoss 6.3540 | RMSE 1.3364 | R2 0.3143
# Epoch 092 | TrainLoss 11.0341 | RMSE 1.2872 | R2 0.3638
# Epoch 093 | TrainLoss 5.8084 | RMSE 1.2356 | R2 0.4138
# Early stopping triggered
#
# [FOLD 0 FINAL]
# MSE : 1.1206
# RMSE: 1.0586
# MAE : 0.8014
# R2  : 0.5697
#
# ==== No_projection Fold 1 ====
# Epoch 000 | TrainLoss 1246.8791 | RMSE 5.5821 | R2 -8.1274
# Epoch 001 | TrainLoss 802.0458 | RMSE 4.3445 | R2 -4.5287
# Epoch 002 | TrainLoss 453.6589 | RMSE 3.0013 | R2 -1.6386
# Epoch 003 | TrainLoss 205.6381 | RMSE 1.9009 | R2 -0.0584
# Epoch 004 | TrainLoss 92.7814 | RMSE 1.3651 | R2 0.4541
# Epoch 005 | TrainLoss 62.9281 | RMSE 1.2071 | R2 0.5732
# Epoch 006 | TrainLoss 57.0834 | RMSE 1.3472 | R2 0.4684
# Epoch 007 | TrainLoss 55.6333 | RMSE 1.2227 | R2 0.5621
# Epoch 008 | TrainLoss 51.2484 | RMSE 1.4797 | R2 0.3587
# Epoch 009 | TrainLoss 50.5662 | RMSE 1.1670 | R2 0.6011
# Epoch 010 | TrainLoss 50.0729 | RMSE 1.2775 | R2 0.5219
# Epoch 011 | TrainLoss 52.8056 | RMSE 1.1836 | R2 0.5897
# Epoch 012 | TrainLoss 49.1853 | RMSE 1.1761 | R2 0.5949
# Epoch 013 | TrainLoss 47.5573 | RMSE 1.5552 | R2 0.2915
# Epoch 014 | TrainLoss 48.9521 | RMSE 1.0889 | R2 0.6527
# Epoch 015 | TrainLoss 40.0591 | RMSE 1.1403 | R2 0.6191
# Epoch 016 | TrainLoss 37.4384 | RMSE 1.4651 | R2 0.3712
# Epoch 017 | TrainLoss 37.9982 | RMSE 1.0867 | R2 0.6541
# Epoch 018 | TrainLoss 36.8711 | RMSE 1.5640 | R2 0.2835
# Epoch 019 | TrainLoss 30.4208 | RMSE 1.5723 | R2 0.2759
# Epoch 020 | TrainLoss 31.8996 | RMSE 1.5300 | R2 0.3143
# Epoch 021 | TrainLoss 33.4614 | RMSE 1.8124 | R2 0.0379
# Epoch 022 | TrainLoss 30.1487 | RMSE 1.2103 | R2 0.5709
# Epoch 023 | TrainLoss 29.4757 | RMSE 1.6458 | R2 0.2066
# Epoch 024 | TrainLoss 30.6755 | RMSE 1.6704 | R2 0.1827
# Epoch 025 | TrainLoss 27.5097 | RMSE 1.4266 | R2 0.4039
# Epoch 026 | TrainLoss 25.5878 | RMSE 1.4717 | R2 0.3656
# Epoch 027 | TrainLoss 25.0831 | RMSE 1.7359 | R2 0.1173
# Epoch 028 | TrainLoss 24.5525 | RMSE 1.6433 | R2 0.2090
# Epoch 029 | TrainLoss 19.6421 | RMSE 1.6073 | R2 0.2432
# Epoch 030 | TrainLoss 25.9071 | RMSE 1.8096 | R2 0.0408
# Epoch 031 | TrainLoss 21.5015 | RMSE 1.2694 | R2 0.5280
# Epoch 032 | TrainLoss 26.9558 | RMSE 1.5680 | R2 0.2798
# Epoch 033 | TrainLoss 17.6106 | RMSE 1.7482 | R2 0.1047
# Epoch 034 | TrainLoss 17.2221 | RMSE 1.6863 | R2 0.1670
# Epoch 035 | TrainLoss 27.5444 | RMSE 1.5864 | R2 0.2629
# Epoch 036 | TrainLoss 23.1176 | RMSE 1.4923 | R2 0.3477
# Epoch 037 | TrainLoss 16.7682 | RMSE 1.8732 | R2 -0.0278
# Epoch 038 | TrainLoss 15.7048 | RMSE 1.8600 | R2 -0.0134
# Epoch 039 | TrainLoss 18.5022 | RMSE 1.7819 | R2 0.0699
# Epoch 040 | TrainLoss 17.8135 | RMSE 1.7864 | R2 0.0652
# Epoch 041 | TrainLoss 13.4226 | RMSE 1.8898 | R2 -0.0461
# Epoch 042 | TrainLoss 12.5378 | RMSE 1.5118 | R2 0.3306
# Epoch 043 | TrainLoss 21.1561 | RMSE 1.7152 | R2 0.1382
# Epoch 044 | TrainLoss 14.7476 | RMSE 1.8101 | R2 0.0403
# Epoch 045 | TrainLoss 12.2493 | RMSE 1.5715 | R2 0.2766
# Epoch 046 | TrainLoss 11.3469 | RMSE 1.6355 | R2 0.2164
# Epoch 047 | TrainLoss 10.5547 | RMSE 1.9837 | R2 -0.1527
# Epoch 048 | TrainLoss 7.7247 | RMSE 1.7495 | R2 0.1034
# Epoch 049 | TrainLoss 10.9501 | RMSE 2.0858 | R2 -0.2744
# Epoch 050 | TrainLoss 9.2643 | RMSE 1.8886 | R2 -0.0447
# Epoch 051 | TrainLoss 7.1325 | RMSE 1.6869 | R2 0.1664
# Epoch 052 | TrainLoss 15.6412 | RMSE 1.5125 | R2 0.3299
# Epoch 053 | TrainLoss 13.5250 | RMSE 1.7439 | R2 0.1092
# Epoch 054 | TrainLoss 11.7232 | RMSE 1.9459 | R2 -0.1091
# Epoch 055 | TrainLoss 9.8104 | RMSE 1.9764 | R2 -0.1441
# Epoch 056 | TrainLoss 8.9253 | RMSE 1.8389 | R2 0.0095
# Epoch 057 | TrainLoss 7.5190 | RMSE 2.1467 | R2 -0.3498
# Epoch 058 | TrainLoss 9.4845 | RMSE 1.6165 | R2 0.2346
# Epoch 059 | TrainLoss 29.4290 | RMSE 1.8082 | R2 0.0422
# Epoch 060 | TrainLoss 12.1167 | RMSE 2.0953 | R2 -0.2859
# Epoch 061 | TrainLoss 7.9795 | RMSE 2.1159 | R2 -0.3114
# Epoch 062 | TrainLoss 6.8623 | RMSE 2.0843 | R2 -0.2725
# Epoch 063 | TrainLoss 6.2402 | RMSE 2.0173 | R2 -0.1920
# Epoch 064 | TrainLoss 6.5554 | RMSE 2.0970 | R2 -0.2880
# Epoch 065 | TrainLoss 5.4721 | RMSE 2.1709 | R2 -0.3804
# Epoch 066 | TrainLoss 6.9198 | RMSE 2.1029 | R2 -0.2954
# Epoch 067 | TrainLoss 6.2143 | RMSE 2.0492 | R2 -0.2300
# Early stopping triggered
#
# [FOLD 1 FINAL]
# MSE : 1.1809
# RMSE: 1.0867
# MAE : 0.6998
# R2  : 0.6541
#
# ==== No_projection Fold 2 ====
# Epoch 000 | TrainLoss 996.3357 | RMSE 4.6337 | R2 -7.7939
# Epoch 001 | TrainLoss 509.9665 | RMSE 3.0992 | R2 -2.9339
# Epoch 002 | TrainLoss 236.5474 | RMSE 1.9074 | R2 -0.4901
# Epoch 003 | TrainLoss 111.6808 | RMSE 1.1965 | R2 0.4136
# Epoch 004 | TrainLoss 67.4948 | RMSE 1.3169 | R2 0.2897
# Epoch 005 | TrainLoss 60.2991 | RMSE 1.0909 | R2 0.5126
# Epoch 006 | TrainLoss 61.6397 | RMSE 1.1487 | R2 0.4595
# Epoch 007 | TrainLoss 60.7642 | RMSE 1.1504 | R2 0.4579
# Epoch 008 | TrainLoss 61.1092 | RMSE 1.1763 | R2 0.4333
# Epoch 009 | TrainLoss 59.4910 | RMSE 1.0313 | R2 0.5644
# Epoch 010 | TrainLoss 63.3470 | RMSE 1.1989 | R2 0.4113
# Epoch 011 | TrainLoss 62.0041 | RMSE 1.1288 | R2 0.4781
# Epoch 012 | TrainLoss 57.6680 | RMSE 1.0099 | R2 0.5823
# Epoch 013 | TrainLoss 54.7626 | RMSE 0.9541 | R2 0.6272
# Epoch 014 | TrainLoss 56.0701 | RMSE 0.9920 | R2 0.5970
# Epoch 015 | TrainLoss 57.0010 | RMSE 0.9619 | R2 0.6211
# Epoch 016 | TrainLoss 53.6291 | RMSE 0.9260 | R2 0.6488
# Epoch 017 | TrainLoss 52.2370 | RMSE 0.8682 | R2 0.6912
# Epoch 018 | TrainLoss 51.9306 | RMSE 0.9346 | R2 0.6422
# Epoch 019 | TrainLoss 54.0298 | RMSE 0.9236 | R2 0.6506
# Epoch 020 | TrainLoss 51.3523 | RMSE 0.8779 | R2 0.6844
# Epoch 021 | TrainLoss 44.9607 | RMSE 1.0625 | R2 0.5376
# Epoch 022 | TrainLoss 41.1645 | RMSE 0.9702 | R2 0.6144
# Epoch 023 | TrainLoss 38.5324 | RMSE 0.9214 | R2 0.6523
# Epoch 024 | TrainLoss 34.5045 | RMSE 0.8414 | R2 0.7100
# Epoch 025 | TrainLoss 33.7843 | RMSE 1.1092 | R2 0.4961
# Epoch 026 | TrainLoss 33.0929 | RMSE 1.1202 | R2 0.4861
# Epoch 027 | TrainLoss 30.6794 | RMSE 1.0077 | R2 0.5841
# Epoch 028 | TrainLoss 28.2082 | RMSE 1.0274 | R2 0.5677
# Epoch 029 | TrainLoss 28.1344 | RMSE 1.1271 | R2 0.4797
# Epoch 030 | TrainLoss 30.4430 | RMSE 1.3266 | R2 0.2792
# Epoch 031 | TrainLoss 26.2589 | RMSE 1.0655 | R2 0.5350
# Epoch 032 | TrainLoss 21.4949 | RMSE 1.3196 | R2 0.2868
# Epoch 033 | TrainLoss 31.1838 | RMSE 0.9518 | R2 0.6290
# Epoch 034 | TrainLoss 27.1156 | RMSE 1.1033 | R2 0.5015
# Epoch 035 | TrainLoss 23.4152 | RMSE 1.2717 | R2 0.3377
# Epoch 036 | TrainLoss 21.9336 | RMSE 1.2373 | R2 0.3730
# Epoch 037 | TrainLoss 21.6672 | RMSE 1.3022 | R2 0.3055
# Epoch 038 | TrainLoss 22.0438 | RMSE 1.2875 | R2 0.3210
# Epoch 039 | TrainLoss 20.5607 | RMSE 1.2378 | R2 0.3725
# Epoch 040 | TrainLoss 21.2517 | RMSE 1.4444 | R2 0.1455
# Epoch 041 | TrainLoss 27.5334 | RMSE 1.2474 | R2 0.3627
# Epoch 042 | TrainLoss 20.7119 | RMSE 1.2822 | R2 0.3266
# Epoch 043 | TrainLoss 16.6265 | RMSE 1.4796 | R2 0.1033
# Epoch 044 | TrainLoss 13.1751 | RMSE 1.5221 | R2 0.0512
# Epoch 045 | TrainLoss 16.8859 | RMSE 1.4218 | R2 0.1721
# Epoch 046 | TrainLoss 26.4244 | RMSE 1.5128 | R2 0.0627
# Epoch 047 | TrainLoss 17.9067 | RMSE 1.3221 | R2 0.2841
# Epoch 048 | TrainLoss 10.8810 | RMSE 1.4697 | R2 0.1154
# Epoch 049 | TrainLoss 10.5519 | RMSE 1.5194 | R2 0.0545
# Epoch 050 | TrainLoss 9.2767 | RMSE 1.6298 | R2 -0.0879
# Epoch 051 | TrainLoss 9.1181 | RMSE 1.5037 | R2 0.0739
# Epoch 052 | TrainLoss 12.8314 | RMSE 1.3537 | R2 0.2495
# Epoch 053 | TrainLoss 13.0615 | RMSE 1.4980 | R2 0.0809
# Epoch 054 | TrainLoss 15.1811 | RMSE 1.5312 | R2 0.0397
# Epoch 055 | TrainLoss 10.6268 | RMSE 1.3642 | R2 0.2378
# Epoch 056 | TrainLoss 9.9590 | RMSE 1.3963 | R2 0.2014
# Epoch 057 | TrainLoss 10.4667 | RMSE 1.5719 | R2 -0.0119
# Epoch 058 | TrainLoss 7.8232 | RMSE 1.4788 | R2 0.1043
# Epoch 059 | TrainLoss 10.3503 | RMSE 1.4427 | R2 0.1476
# Epoch 060 | TrainLoss 7.1933 | RMSE 1.4462 | R2 0.1434
# Epoch 061 | TrainLoss 6.6237 | RMSE 1.4373 | R2 0.1538
# Epoch 062 | TrainLoss 23.1189 | RMSE 1.5031 | R2 0.0747
# Epoch 063 | TrainLoss 12.6987 | RMSE 1.3900 | R2 0.2086
# Epoch 064 | TrainLoss 8.5188 | RMSE 1.3554 | R2 0.2476
# Epoch 065 | TrainLoss 13.7430 | RMSE 1.3814 | R2 0.2184
# Epoch 066 | TrainLoss 9.8997 | RMSE 1.3893 | R2 0.2094
# Epoch 067 | TrainLoss 16.3300 | RMSE 1.1999 | R2 0.4103
# Epoch 068 | TrainLoss 11.4093 | RMSE 1.2925 | R2 0.3158
# Epoch 069 | TrainLoss 7.9306 | RMSE 1.2960 | R2 0.3120
# Epoch 070 | TrainLoss 5.5974 | RMSE 1.2719 | R2 0.3375
# Epoch 071 | TrainLoss 10.8345 | RMSE 1.2330 | R2 0.3773
# Epoch 072 | TrainLoss 10.2466 | RMSE 1.4091 | R2 0.1868
# Epoch 073 | TrainLoss 8.6748 | RMSE 1.2872 | R2 0.3214
# Epoch 074 | TrainLoss 7.9564 | RMSE 1.1983 | R2 0.4119
# Early stopping triggered
#
# [FOLD 2 FINAL]
# MSE : 0.7080
# RMSE: 0.8414
# MAE : 0.6040
# R2  : 0.7100
#
# ==== No_projection Fold 3 ====
# Epoch 000 | TrainLoss 774.1176 | RMSE 4.6367 | R2 -5.2239
# Epoch 001 | TrainLoss 341.0610 | RMSE 3.0796 | R2 -1.7455
# Epoch 002 | TrainLoss 135.9290 | RMSE 1.9584 | R2 -0.1104
# Epoch 003 | TrainLoss 67.8421 | RMSE 1.3747 | R2 0.4529
# Epoch 004 | TrainLoss 56.5509 | RMSE 1.3539 | R2 0.4694
# Epoch 005 | TrainLoss 56.0161 | RMSE 1.4103 | R2 0.4242
# Epoch 006 | TrainLoss 51.5790 | RMSE 1.5091 | R2 0.3407
# Epoch 007 | TrainLoss 50.0294 | RMSE 1.3947 | R2 0.4369
# Epoch 008 | TrainLoss 48.8321 | RMSE 1.3363 | R2 0.4831
# Epoch 009 | TrainLoss 44.6965 | RMSE 1.3153 | R2 0.4992
# Epoch 010 | TrainLoss 39.6912 | RMSE 1.3781 | R2 0.4502
# Epoch 011 | TrainLoss 33.9644 | RMSE 1.5377 | R2 0.3155
# Epoch 012 | TrainLoss 31.0914 | RMSE 1.4804 | R2 0.3655
# Epoch 013 | TrainLoss 30.5473 | RMSE 1.2940 | R2 0.5152
# Epoch 014 | TrainLoss 27.2541 | RMSE 1.1527 | R2 0.6153
# Epoch 015 | TrainLoss 36.9174 | RMSE 1.8326 | R2 0.0278
# Epoch 016 | TrainLoss 32.6714 | RMSE 1.4015 | R2 0.4314
# Epoch 017 | TrainLoss 26.5581 | RMSE 1.3218 | R2 0.4942
# Epoch 018 | TrainLoss 26.5241 | RMSE 1.4870 | R2 0.3598
# Epoch 019 | TrainLoss 24.0482 | RMSE 1.3620 | R2 0.4630
# Epoch 020 | TrainLoss 26.5114 | RMSE 1.1372 | R2 0.6256
# Epoch 021 | TrainLoss 23.0907 | RMSE 1.2565 | R2 0.5429
# Epoch 022 | TrainLoss 26.8779 | RMSE 1.0267 | R2 0.6949
# Epoch 023 | TrainLoss 24.8763 | RMSE 1.4886 | R2 0.3585
# Epoch 024 | TrainLoss 20.5398 | RMSE 1.4159 | R2 0.4196
# Epoch 025 | TrainLoss 23.3258 | RMSE 1.6241 | R2 0.2364
# Epoch 026 | TrainLoss 25.4808 | RMSE 1.2983 | R2 0.5120
# Epoch 027 | TrainLoss 23.3474 | RMSE 1.6699 | R2 0.1927
# Epoch 028 | TrainLoss 22.3335 | RMSE 1.5149 | R2 0.3356
# Epoch 029 | TrainLoss 21.4420 | RMSE 1.4452 | R2 0.3953
# Epoch 030 | TrainLoss 19.5066 | RMSE 1.2880 | R2 0.5197
# Epoch 031 | TrainLoss 18.1583 | RMSE 1.3100 | R2 0.5032
# Epoch 032 | TrainLoss 15.3391 | RMSE 1.4233 | R2 0.4136
# Epoch 033 | TrainLoss 15.2211 | RMSE 1.4303 | R2 0.4078
# Epoch 034 | TrainLoss 17.1059 | RMSE 1.3738 | R2 0.4537
# Epoch 035 | TrainLoss 22.0896 | RMSE 1.7894 | R2 0.0731
# Epoch 036 | TrainLoss 24.2439 | RMSE 1.3327 | R2 0.4858
# Epoch 037 | TrainLoss 14.4440 | RMSE 1.3351 | R2 0.4840
# Epoch 038 | TrainLoss 22.3727 | RMSE 1.1686 | R2 0.6047
# Epoch 039 | TrainLoss 24.4084 | RMSE 1.2661 | R2 0.5359
# Epoch 040 | TrainLoss 18.8382 | RMSE 1.4388 | R2 0.4007
# Epoch 041 | TrainLoss 18.4965 | RMSE 1.3392 | R2 0.4808
# Epoch 042 | TrainLoss 15.6986 | RMSE 1.5966 | R2 0.2620
# Epoch 043 | TrainLoss 24.7981 | RMSE 1.2558 | R2 0.5435
# Epoch 044 | TrainLoss 18.7104 | RMSE 1.4262 | R2 0.4111
# Epoch 045 | TrainLoss 20.2125 | RMSE 1.2219 | R2 0.5678
# Epoch 046 | TrainLoss 18.0605 | RMSE 1.1694 | R2 0.6041
# Epoch 047 | TrainLoss 18.0480 | RMSE 1.2846 | R2 0.5223
# Epoch 048 | TrainLoss 16.3570 | RMSE 1.4323 | R2 0.4061
# Epoch 049 | TrainLoss 13.5324 | RMSE 1.2394 | R2 0.5553
# Epoch 050 | TrainLoss 16.9936 | RMSE 1.6627 | R2 0.1997
# Epoch 051 | TrainLoss 22.9597 | RMSE 1.5583 | R2 0.2970
# Epoch 052 | TrainLoss 15.1124 | RMSE 1.3548 | R2 0.4686
# Epoch 053 | TrainLoss 15.5225 | RMSE 1.3181 | R2 0.4970
# Epoch 054 | TrainLoss 14.0954 | RMSE 1.3261 | R2 0.4909
# Epoch 055 | TrainLoss 22.0525 | RMSE 1.4354 | R2 0.4036
# Epoch 056 | TrainLoss 21.2623 | RMSE 1.3376 | R2 0.4820
# Epoch 057 | TrainLoss 12.4849 | RMSE 1.3913 | R2 0.4396
# Epoch 058 | TrainLoss 11.1992 | RMSE 1.3784 | R2 0.4500
# Epoch 059 | TrainLoss 10.0686 | RMSE 1.2790 | R2 0.5264
# Epoch 060 | TrainLoss 13.4169 | RMSE 1.4045 | R2 0.4289
# Epoch 061 | TrainLoss 24.3361 | RMSE 1.4020 | R2 0.4309
# Epoch 062 | TrainLoss 14.2419 | RMSE 1.4089 | R2 0.4254
# Epoch 063 | TrainLoss 10.7250 | RMSE 1.3630 | R2 0.4622
# Epoch 064 | TrainLoss 10.7854 | RMSE 1.3962 | R2 0.4356
# Epoch 065 | TrainLoss 9.8982 | RMSE 1.4128 | R2 0.4222
# ...
# Epoch 170 | TrainLoss 48.2695 | RMSE 1.5886 | R2 0.2694
# Epoch 171 | TrainLoss 49.8669 | RMSE 1.6649 | R2 0.1975
# Epoch 172 | TrainLoss 48.7319 | RMSE 1.8551 | R2 0.0038
# Epoch 173 | TrainLoss 50.4946 | RMSE 1.5713 | R2 0.2852
# Epoch 174 | TrainLoss 48.5181 | RMSE 1.6263 | R2 0.2344
# Epoch 175 | TrainLoss 48.6834 | RMSE 1.5387 | R2 0.3146
# Epoch 176 | TrainLoss 47.3306 | RMSE 1.6017 | R2 0.2573
# Epoch 177 | TrainLoss 49.3919 | RMSE 1.5082 | R2 0.3415
# Epoch 178 | TrainLoss 50.1064 | RMSE 1.5663 | R2 0.2898
# Epoch 179 | TrainLoss 50.0896 | RMSE 1.5933 | R2 0.2651
# Epoch 180 | TrainLoss 49.0598 | RMSE 1.5247 | R2 0.3270
# Epoch 181 | TrainLoss 48.5964 | RMSE 1.6957 | R2 0.1675
# Epoch 182 | TrainLoss 48.8454 | RMSE 1.5138 | R2 0.3366
# Epoch 183 | TrainLoss 47.6255 | RMSE 1.5323 | R2 0.3203
# Epoch 184 | TrainLoss 49.7579 | RMSE 1.5202 | R2 0.3309
# Epoch 185 | TrainLoss 47.7144 | RMSE 1.5209 | R2 0.3304
# Epoch 186 | TrainLoss 47.9595 | RMSE 1.6879 | R2 0.1752
# Epoch 187 | TrainLoss 48.9521 | RMSE 1.5420 | R2 0.3117
# Epoch 188 | TrainLoss 48.7224 | RMSE 1.5697 | R2 0.2867
# Epoch 189 | TrainLoss 47.6711 | RMSE 1.5252 | R2 0.3265
# Epoch 190 | TrainLoss 47.8178 | RMSE 1.5492 | R2 0.3052
# Epoch 191 | TrainLoss 51.3775 | RMSE 1.6205 | R2 0.2397
# Epoch 192 | TrainLoss 47.4773 | RMSE 1.5438 | R2 0.3100
# Epoch 193 | TrainLoss 47.6851 | RMSE 1.5521 | R2 0.3026
# Epoch 194 | TrainLoss 47.9288 | RMSE 1.5155 | R2 0.3351
# Epoch 195 | TrainLoss 49.8143 | RMSE 1.5796 | R2 0.2777
# Epoch 196 | TrainLoss 47.6387 | RMSE 1.5355 | R2 0.3174
# Epoch 197 | TrainLoss 47.2777 | RMSE 1.5576 | R2 0.2976
# Epoch 198 | TrainLoss 47.8028 | RMSE 1.5219 | R2 0.3295
# Epoch 199 | TrainLoss 48.5685 | RMSE 1.5172 | R2 0.3336
# Epoch 200 | TrainLoss 47.4539 | RMSE 1.5350 | R2 0.3179
# Epoch 201 | TrainLoss 46.9036 | RMSE 1.5238 | R2 0.3278
# Epoch 202 | TrainLoss 48.1530 | RMSE 1.5121 | R2 0.3381
# Epoch 203 | TrainLoss 47.0510 | RMSE 1.5292 | R2 0.3230
# Epoch 204 | TrainLoss 46.9413 | RMSE 1.6429 | R2 0.2186
# Epoch 205 | TrainLoss 47.6864 | RMSE 1.5562 | R2 0.2989
# Epoch 206 | TrainLoss 47.1787 | RMSE 1.5462 | R2 0.3079
# Epoch 207 | TrainLoss 47.4677 | RMSE 1.5078 | R2 0.3418
# Epoch 208 | TrainLoss 49.2116 | RMSE 1.5050 | R2 0.3443
# Epoch 209 | TrainLoss 48.0392 | RMSE 1.6577 | R2 0.2045
# Epoch 210 | TrainLoss 47.3218 | RMSE 1.5793 | R2 0.2779
# Epoch 211 | TrainLoss 46.8592 | RMSE 1.5897 | R2 0.2684
# Epoch 212 | TrainLoss 50.1708 | RMSE 1.5738 | R2 0.2830
# Epoch 213 | TrainLoss 46.7052 | RMSE 1.4973 | R2 0.3510
# Epoch 214 | TrainLoss 47.3922 | RMSE 1.5859 | R2 0.2719
# Epoch 215 | TrainLoss 46.9452 | RMSE 1.6104 | R2 0.2492
# Epoch 216 | TrainLoss 49.5363 | RMSE 1.6702 | R2 0.1925
# Epoch 217 | TrainLoss 47.3535 | RMSE 1.5082 | R2 0.3415
# Epoch 218 | TrainLoss 46.1283 | RMSE 1.5672 | R2 0.2890
# Epoch 219 | TrainLoss 45.8452 | RMSE 1.5979 | R2 0.2608
# Epoch 220 | TrainLoss 48.3646 | RMSE 1.5546 | R2 0.3003
# Epoch 221 | TrainLoss 45.8081 | RMSE 1.5071 | R2 0.3424
# Epoch 222 | TrainLoss 48.1712 | RMSE 1.5683 | R2 0.2880
# Epoch 223 | TrainLoss 46.9729 | RMSE 1.5037 | R2 0.3454
# Epoch 224 | TrainLoss 46.3404 | RMSE 1.6714 | R2 0.1913
# Epoch 225 | TrainLoss 48.1966 | RMSE 1.5231 | R2 0.3284
# Epoch 226 | TrainLoss 50.2040 | RMSE 1.5412 | R2 0.3123
# Epoch 227 | TrainLoss 48.2693 | RMSE 1.5323 | R2 0.3203
# Epoch 228 | TrainLoss 45.8833 | RMSE 1.5134 | R2 0.3370
# Epoch 229 | TrainLoss 46.2286 | RMSE 1.6223 | R2 0.2380
# Epoch 230 | TrainLoss 46.6057 | RMSE 1.5196 | R2 0.3315
# Epoch 231 | TrainLoss 45.9617 | RMSE 1.4963 | R2 0.3519
# Epoch 232 | TrainLoss 45.7876 | RMSE 1.5589 | R2 0.2965
# Epoch 233 | TrainLoss 46.5397 | RMSE 1.6047 | R2 0.2546
# Epoch 234 | TrainLoss 46.4781 | RMSE 1.5082 | R2 0.3415
# Epoch 235 | TrainLoss 45.9465 | RMSE 1.4930 | R2 0.3547
# Epoch 236 | TrainLoss 46.2118 | RMSE 1.4968 | R2 0.3514
# Epoch 237 | TrainLoss 47.8276 | RMSE 1.6101 | R2 0.2495
# Epoch 238 | TrainLoss 46.4767 | RMSE 1.5024 | R2 0.3465
# Epoch 239 | TrainLoss 46.4622 | RMSE 1.6539 | R2 0.2081
# Epoch 240 | TrainLoss 47.1185 | RMSE 1.5568 | R2 0.2984
# Epoch 241 | TrainLoss 45.9104 | RMSE 1.5116 | R2 0.3385
# Epoch 242 | TrainLoss 47.4089 | RMSE 1.5416 | R2 0.3120
# Epoch 243 | TrainLoss 48.6053 | RMSE 1.4927 | R2 0.3550
# Epoch 244 | TrainLoss 45.3227 | RMSE 1.4877 | R2 0.3593
# Epoch 245 | TrainLoss 46.0667 | RMSE 1.6049 | R2 0.2543
# Epoch 246 | TrainLoss 49.3678 | RMSE 1.5855 | R2 0.2722
# Epoch 247 | TrainLoss 45.9661 | RMSE 1.6285 | R2 0.2322
# Epoch 248 | TrainLoss 46.0691 | RMSE 1.4858 | R2 0.3609
# Epoch 249 | TrainLoss 45.8313 | RMSE 1.4884 | R2 0.3587
# Epoch 250 | TrainLoss 45.3388 | RMSE 1.5761 | R2 0.2809
# Epoch 251 | TrainLoss 46.2499 | RMSE 1.5585 | R2 0.2968
# Epoch 252 | TrainLoss 45.5803 | RMSE 1.4937 | R2 0.3541
# Epoch 253 | TrainLoss 45.1559 | RMSE 1.5005 | R2 0.3482
# Epoch 254 | TrainLoss 46.6917 | RMSE 1.5115 | R2 0.3386
# Epoch 255 | TrainLoss 45.0722 | RMSE 1.5813 | R2 0.2762
# Epoch 256 | TrainLoss 45.3556 | RMSE 1.5112 | R2 0.3388
# Epoch 257 | TrainLoss 45.0527 | RMSE 1.4668 | R2 0.3772
# Epoch 258 | TrainLoss 45.3699 | RMSE 1.4998 | R2 0.3488
# Epoch 259 | TrainLoss 46.1133 | RMSE 1.4820 | R2 0.3642
# Epoch 260 | TrainLoss 46.8651 | RMSE 1.5991 | R2 0.2597
# Epoch 261 | TrainLoss 45.5349 | RMSE 1.5460 | R2 0.3080
# Epoch 262 | TrainLoss 45.6070 | RMSE 1.4855 | R2 0.3612
# Epoch 263 | TrainLoss 45.4768 | RMSE 1.4947 | R2 0.3532
# Epoch 264 | TrainLoss 45.6988 | RMSE 1.5028 | R2 0.3462
# Epoch 265 | TrainLoss 48.0775 | RMSE 1.5893 | R2 0.2688
# Epoch 266 | TrainLoss 46.1708 | RMSE 1.6637 | R2 0.1987
# Epoch 267 | TrainLoss 50.0969 | RMSE 1.5370 | R2 0.3161
# Epoch 268 | TrainLoss 51.4290 | RMSE 1.5139 | R2 0.3365
# Epoch 269 | TrainLoss 45.1064 | RMSE 1.5110 | R2 0.3390
# Epoch 270 | TrainLoss 44.8186 | RMSE 1.5112 | R2 0.3388
# Epoch 271 | TrainLoss 44.7356 | RMSE 1.4964 | R2 0.3517
# Epoch 272 | TrainLoss 46.2564 | RMSE 1.5170 | R2 0.3338
# Epoch 273 | TrainLoss 44.8628 | RMSE 1.5249 | R2 0.3269
# Epoch 274 | TrainLoss 44.1147 | RMSE 1.4881 | R2 0.3589
# Epoch 275 | TrainLoss 45.2166 | RMSE 1.4891 | R2 0.3580
# Epoch 276 | TrainLoss 44.4973 | RMSE 1.5453 | R2 0.3087
# Epoch 277 | TrainLoss 45.4673 | RMSE 1.5036 | R2 0.3455
# Epoch 278 | TrainLoss 46.3875 | RMSE 1.6361 | R2 0.2251
# Epoch 279 | TrainLoss 45.3772 | RMSE 1.4947 | R2 0.3533
# Epoch 280 | TrainLoss 45.6410 | RMSE 1.5149 | R2 0.3356
# Epoch 281 | TrainLoss 44.9413 | RMSE 1.4762 | R2 0.3692
# Epoch 282 | TrainLoss 44.8190 | RMSE 1.5131 | R2 0.3372
# Epoch 283 | TrainLoss 43.8326 | RMSE 1.5217 | R2 0.3296
# Epoch 284 | TrainLoss 44.0682 | RMSE 1.5075 | R2 0.3421
# Epoch 285 | TrainLoss 45.3195 | RMSE 1.6151 | R2 0.2448
# Epoch 286 | TrainLoss 45.6363 | RMSE 1.4616 | R2 0.3816
# Epoch 287 | TrainLoss 46.9464 | RMSE 1.4851 | R2 0.3615
# Epoch 288 | TrainLoss 45.4922 | RMSE 1.5237 | R2 0.3279
# Epoch 289 | TrainLoss 44.2638 | RMSE 1.4681 | R2 0.3760
# Epoch 290 | TrainLoss 45.2880 | RMSE 1.5715 | R2 0.2850
# Epoch 291 | TrainLoss 45.3066 | RMSE 1.5198 | R2 0.3313
# Epoch 292 | TrainLoss 44.0087 | RMSE 1.5352 | R2 0.3177
# Epoch 293 | TrainLoss 45.3073 | RMSE 1.4950 | R2 0.3530
# Epoch 294 | TrainLoss 45.2987 | RMSE 1.4511 | R2 0.3904
# Epoch 295 | TrainLoss 44.6412 | RMSE 1.4625 | R2 0.3808
# Epoch 296 | TrainLoss 48.4436 | RMSE 1.5467 | R2 0.3074
# Epoch 297 | TrainLoss 45.4284 | RMSE 1.4479 | R2 0.3931
# Epoch 298 | TrainLoss 45.3380 | RMSE 1.4959 | R2 0.3522
# Epoch 299 | TrainLoss 44.6491 | RMSE 1.4827 | R2 0.3635
# Epoch 300 | TrainLoss 43.8520 | RMSE 1.4991 | R2 0.3494
# Epoch 301 | TrainLoss 44.3717 | RMSE 1.5000 | R2 0.3487
# Epoch 302 | TrainLoss 44.4575 | RMSE 1.4730 | R2 0.3718
# Epoch 303 | TrainLoss 45.2277 | RMSE 1.5830 | R2 0.2746
# Epoch 304 | TrainLoss 43.8980 | RMSE 1.5224 | R2 0.3291
# Epoch 305 | TrainLoss 46.4164 | RMSE 1.5991 | R2 0.2597
# Epoch 306 | TrainLoss 44.6013 | RMSE 1.4678 | R2 0.3763
# Epoch 307 | TrainLoss 45.4168 | RMSE 1.4856 | R2 0.3611
# Epoch 308 | TrainLoss 45.0425 | RMSE 1.4629 | R2 0.3805
# Epoch 309 | TrainLoss 45.3260 | RMSE 1.6717 | R2 0.1910
# Epoch 310 | TrainLoss 44.7274 | RMSE 1.4934 | R2 0.3543
# Epoch 311 | TrainLoss 47.8358 | RMSE 1.4717 | R2 0.3730
# Epoch 312 | TrainLoss 44.0969 | RMSE 1.5251 | R2 0.3266
# Epoch 313 | TrainLoss 44.4722 | RMSE 1.5183 | R2 0.3326
# Epoch 314 | TrainLoss 43.8098 | RMSE 1.4942 | R2 0.3537
# Epoch 315 | TrainLoss 43.1726 | RMSE 1.6042 | R2 0.2550
# Epoch 316 | TrainLoss 44.2769 | RMSE 1.4720 | R2 0.3727
# Epoch 317 | TrainLoss 43.9545 | RMSE 1.6795 | R2 0.1835
# Epoch 318 | TrainLoss 45.6771 | RMSE 1.4559 | R2 0.3864
# Epoch 319 | TrainLoss 44.7588 | RMSE 1.4833 | R2 0.3631
# Epoch 320 | TrainLoss 45.6495 | RMSE 1.4688 | R2 0.3755
# Epoch 321 | TrainLoss 44.0258 | RMSE 1.5547 | R2 0.3003
# Epoch 322 | TrainLoss 46.3125 | RMSE 1.4868 | R2 0.3600
# Epoch 323 | TrainLoss 47.4255 | RMSE 1.4755 | R2 0.3698
# Epoch 324 | TrainLoss 44.4613 | RMSE 1.5611 | R2 0.2945
# Epoch 325 | TrainLoss 43.6864 | RMSE 1.4790 | R2 0.3667
# Epoch 326 | TrainLoss 44.9138 | RMSE 1.5578 | R2 0.2974
# Epoch 327 | TrainLoss 45.1277 | RMSE 1.4857 | R2 0.3610
# Epoch 328 | TrainLoss 43.4478 | RMSE 1.5600 | R2 0.2955
# Epoch 329 | TrainLoss 42.4393 | RMSE 1.4837 | R2 0.3627
# Epoch 330 | TrainLoss 44.8074 | RMSE 1.5078 | R2 0.3419
# Epoch 331 | TrainLoss 43.6059 | RMSE 1.4644 | R2 0.3792
# Epoch 332 | TrainLoss 45.9321 | RMSE 1.5779 | R2 0.2792
# Epoch 333 | TrainLoss 45.7727 | RMSE 1.6098 | R2 0.2498
# Epoch 334 | TrainLoss 43.7461 | RMSE 1.4765 | R2 0.3689
# Epoch 335 | TrainLoss 43.4571 | RMSE 1.4778 | R2 0.3678
# Epoch 336 | TrainLoss 42.5575 | RMSE 1.5759 | R2 0.2811
# Epoch 337 | TrainLoss 43.2317 | RMSE 1.5227 | R2 0.3288
# Epoch 338 | TrainLoss 42.7759 | RMSE 1.5265 | R2 0.3254
# Epoch 339 | TrainLoss 42.5485 | RMSE 1.5200 | R2 0.3311
# Epoch 340 | TrainLoss 43.5067 | RMSE 1.5175 | R2 0.3333
# Epoch 341 | TrainLoss 43.6572 | RMSE 1.4892 | R2 0.3580
# Epoch 342 | TrainLoss 43.3100 | RMSE 1.4942 | R2 0.3536
# Epoch 343 | TrainLoss 42.5321 | RMSE 1.5192 | R2 0.3319
# Epoch 344 | TrainLoss 43.8582 | RMSE 1.4676 | R2 0.3765
# Epoch 345 | TrainLoss 43.2121 | RMSE 1.5200 | R2 0.3311
# Epoch 346 | TrainLoss 42.5876 | RMSE 1.5883 | R2 0.2696
# Epoch 347 | TrainLoss 44.0876 | RMSE 1.5253 | R2 0.3265
# Early stopping triggered
#
# [FOLD 3 FINAL]
# MSE : 2.0962
# RMSE: 1.4478
# MAE : 1.0262
# R2  : 0.3932
#
# ==== No_projection_fourier_positional_encoding_temp_token Fold 4 ====
# Epoch 000 | TrainLoss 1703.6695 | RMSE 7.5177 | R2 -12.9334
# Epoch 001 | TrainLoss 1323.7999 | RMSE 4.8108 | R2 -4.7060
# Epoch 002 | TrainLoss 189.5308 | RMSE 1.7856 | R2 0.2140
# Epoch 003 | TrainLoss 85.9992 | RMSE 1.6127 | R2 0.3588
# Epoch 004 | TrainLoss 80.4319 | RMSE 1.5479 | R2 0.4093
# Epoch 005 | TrainLoss 78.9255 | RMSE 1.5609 | R2 0.3994
# Epoch 006 | TrainLoss 77.3991 | RMSE 1.5413 | R2 0.4143
# Epoch 007 | TrainLoss 76.9350 | RMSE 1.4911 | R2 0.4519
# Epoch 008 | TrainLoss 76.3847 | RMSE 1.4973 | R2 0.4473
# Epoch 009 | TrainLoss 77.5075 | RMSE 1.4590 | R2 0.4752
# Epoch 010 | TrainLoss 75.2486 | RMSE 1.5682 | R2 0.3937
# Epoch 011 | TrainLoss 75.6919 | RMSE 1.4595 | R2 0.4748
# Epoch 012 | TrainLoss 74.3561 | RMSE 1.4416 | R2 0.4877
# Epoch 013 | TrainLoss 73.4445 | RMSE 1.4720 | R2 0.4658
# Epoch 014 | TrainLoss 74.5094 | RMSE 1.4276 | R2 0.4976
# Epoch 015 | TrainLoss 78.1296 | RMSE 1.5659 | R2 0.3955
# Epoch 016 | TrainLoss 74.4823 | RMSE 1.5411 | R2 0.4144
# Epoch 017 | TrainLoss 74.4145 | RMSE 1.5284 | R2 0.4241
# Epoch 018 | TrainLoss 73.7764 | RMSE 1.4254 | R2 0.4991
# Epoch 019 | TrainLoss 75.0409 | RMSE 1.6474 | R2 0.3309
# Epoch 020 | TrainLoss 75.5614 | RMSE 1.5480 | R2 0.4092
# Epoch 021 | TrainLoss 72.0576 | RMSE 1.4365 | R2 0.4912
# Epoch 022 | TrainLoss 72.7189 | RMSE 1.4472 | R2 0.4837
# Epoch 023 | TrainLoss 71.9585 | RMSE 1.4600 | R2 0.4745
# Epoch 024 | TrainLoss 72.3056 | RMSE 1.4580 | R2 0.4759
# Epoch 025 | TrainLoss 72.7081 | RMSE 1.6896 | R2 0.2962
# Epoch 026 | TrainLoss 71.9066 | RMSE 1.5546 | R2 0.4041
# Epoch 027 | TrainLoss 71.8865 | RMSE 1.4097 | R2 0.5101
# Epoch 028 | TrainLoss 72.6859 | RMSE 1.4353 | R2 0.4921
# Epoch 029 | TrainLoss 69.8697 | RMSE 1.4750 | R2 0.4636
# Epoch 030 | TrainLoss 70.2733 | RMSE 1.4596 | R2 0.4748
# Epoch 031 | TrainLoss 71.4392 | RMSE 1.5981 | R2 0.3703
# Epoch 032 | TrainLoss 71.1494 | RMSE 1.4607 | R2 0.4739
# Epoch 033 | TrainLoss 68.9914 | RMSE 1.4215 | R2 0.5018
# Epoch 034 | TrainLoss 71.7237 | RMSE 1.5647 | R2 0.3964
# Epoch 035 | TrainLoss 69.8743 | RMSE 1.5071 | R2 0.4400
# Epoch 036 | TrainLoss 69.2118 | RMSE 1.4164 | R2 0.5054
# Epoch 037 | TrainLoss 68.9472 | RMSE 1.4408 | R2 0.4882
# Epoch 038 | TrainLoss 68.0600 | RMSE 1.4765 | R2 0.4626
# Epoch 039 | TrainLoss 67.8238 | RMSE 1.4449 | R2 0.4853
# Epoch 040 | TrainLoss 66.8049 | RMSE 1.4293 | R2 0.4963
# Epoch 041 | TrainLoss 66.3043 | RMSE 1.4583 | R2 0.4757
# Epoch 042 | TrainLoss 65.9561 | RMSE 1.4565 | R2 0.4770
# Epoch 043 | TrainLoss 66.7681 | RMSE 1.4388 | R2 0.4896
# Epoch 044 | TrainLoss 66.7127 | RMSE 1.5809 | R2 0.3839
# Epoch 045 | TrainLoss 64.8669 | RMSE 1.5006 | R2 0.4448
# Epoch 046 | TrainLoss 64.0012 | RMSE 1.5275 | R2 0.4247
# Epoch 047 | TrainLoss 64.2753 | RMSE 1.5031 | R2 0.4430
# Epoch 048 | TrainLoss 66.8306 | RMSE 1.5626 | R2 0.3980
# Epoch 049 | TrainLoss 63.9686 | RMSE 1.4384 | R2 0.4899
# Epoch 050 | TrainLoss 62.4309 | RMSE 1.5044 | R2 0.4420
# Epoch 051 | TrainLoss 59.8961 | RMSE 1.5868 | R2 0.3792
# Epoch 052 | TrainLoss 59.7878 | RMSE 1.5473 | R2 0.4098
# Epoch 053 | TrainLoss 58.7796 | RMSE 1.6167 | R2 0.3556
# Epoch 054 | TrainLoss 58.6868 | RMSE 1.5907 | R2 0.3762
# Epoch 055 | TrainLoss 56.8748 | RMSE 1.5324 | R2 0.4210
# Epoch 056 | TrainLoss 55.7203 | RMSE 1.5626 | R2 0.3980
# Epoch 057 | TrainLoss 53.7712 | RMSE 1.4741 | R2 0.4643
# Epoch 058 | TrainLoss 55.0658 | RMSE 1.7796 | R2 0.2192
# Epoch 059 | TrainLoss 54.1607 | RMSE 1.9850 | R2 0.0285
# Epoch 060 | TrainLoss 55.6857 | RMSE 1.7897 | R2 0.2103
# Epoch 061 | TrainLoss 51.9418 | RMSE 1.5613 | R2 0.3990
# Epoch 062 | TrainLoss 50.3053 | RMSE 1.7367 | R2 0.2564
# Epoch 063 | TrainLoss 49.2474 | RMSE 1.6143 | R2 0.3576
# Epoch 064 | TrainLoss 47.5876 | RMSE 1.7192 | R2 0.2713
# Epoch 065 | TrainLoss 46.3009 | RMSE 1.7796 | R2 0.2192
# Epoch 066 | TrainLoss 47.0170 | RMSE 1.6307 | R2 0.3444
# Epoch 067 | TrainLoss 45.2878 | RMSE 1.9517 | R2 0.0609
# Epoch 068 | TrainLoss 45.6888 | RMSE 1.9409 | R2 0.0712
# Epoch 069 | TrainLoss 49.8333 | RMSE 1.7242 | R2 0.2670
# Epoch 070 | TrainLoss 45.7324 | RMSE 1.8048 | R2 0.1969
# Epoch 071 | TrainLoss 44.4924 | RMSE 1.6963 | R2 0.2906
# Epoch 072 | TrainLoss 45.5713 | RMSE 1.8416 | R2 0.1638
# Epoch 073 | TrainLoss 46.4157 | RMSE 1.7939 | R2 0.2066
# Epoch 074 | TrainLoss 45.6707 | RMSE 1.9318 | R2 0.0799
# Epoch 075 | TrainLoss 43.8627 | RMSE 1.6518 | R2 0.3273
# Epoch 076 | TrainLoss 44.9612 | RMSE 1.7140 | R2 0.2757
# Epoch 077 | TrainLoss 42.5391 | RMSE 2.1393 | R2 -0.1283
# Early stopping triggered
#
# [FOLD 4 FINAL]
# MSE : 1.9851
# RMSE: 1.4089
# MAE : 1.0365
# R2  : 0.5106
#
# ================================================================================
# No_projection_fourier_positional_encoding_temp_token
# ================================================================================
# FINAL 5-FOLD RESULT
# RMSE : 1.2239 ± 0.2042
# MAE  : 0.9691 ± 0.1493
# R2   : 0.5255 ± 0.0976
#
# ====================================================================================================
# FINAL ABLATION RESULTS
# ====================================================================================================
# Experiment               MSE         RMSE        MAE         R2
# Full                     0.7023      0.8328      0.6129      0.7807
# No_projection            1.0230      1.0078      0.7367      0.6739
# No_fourier_positional_encoding1.3573      1.1468      0.8810      0.5796
# No_temp_token            1.1606      1.0703      0.8388      0.6358
# No_projection_fourier_positional_encoding1.3822      1.1557      0.8720      0.5786
# No_projection_temp_token 1.1513      1.0487      0.8245      0.6486
# No_fourier_positional_encoding_temp_token1.8344      1.3196      1.0679      0.4349
# No_projection_fourier_positional_encoding_temp_token1.5396      1.2239      0.9691      0.5255
#
# Saved:
# ✔ ablation_results.csv
# ✔ ablation_fold_results.csv (fold-level, for plots)
